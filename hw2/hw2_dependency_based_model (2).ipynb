# %%
import numpy as np
import pandas as pd
import re
import csv
from collections import Counter
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words = set(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yuxinzhang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/yuxinzhang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def load_sentence(file):
    data1 = open(file, "r")
    file1 = data1.read()
    data1.close()
    result_sentences = file1.split("\n")
    df = pd.DataFrame(result_sentences, columns = ["text"])
    return df

# %%
df = load_sentence("data/training/training-data.1m")
df.head()
# Out:
#                                                 text
# 0  The U.S. Centers for Disease Control and Preve...
# 1  When Ms. Winfrey invited Suzanne Somers to sha...
# 2  Elk calling -- a skill that hunters perfected ...
# 3                                           Don 't !
# 4  Fish , ranked 98th in the world , fired 22 ace...

# %%
RE_STRIP_SPECIAL_CHARS = r'[^a-zA-Z0-9\s]'
RE_WHITESPACE = r'[\s]+'
RE_NUMBER = r'[0-9]+'
def extract_token(corpus):
    print('tokenizing sentences')
    result = []
    for sentence in corpus:
        s = sentence.lower()
        s = re.sub(RE_STRIP_SPECIAL_CHARS, '', s)
        # s = re.sub(RE_NUMBER, '<NUMBER>', s)
        s = re.sub(RE_NUMBER, ' ', s)
        tokenized = nltk.word_tokenize(s)
        filtered_sentence = [w for w in tokenized if not w in stop_words]
        result.append(filtered_sentence)
    return result

# %%
res = extract_token(df.text) #collection of tokenized sentence(with preprocess on text)
# Out:
# tokenizing sentences

# %% [markdown]
# ### build V (substituting the lower fequency words), and build the V reference table
# * V: set of non-duplicated words we use in building (w,c) pairs
# * word_counting: dictiorcy for each word and its frquency in the training set, used in negative sampling and remove low-frequency words to deal with unknown

# %%
# def get_vocab(tokens):
#     vocab = []
#     for sentence in tokens:
#         for token in sentence:
#             vocab.append(token)

#     word_counter = Counter(vocab)
#     avg_doc_length = len(vocab) / len(tokens)
#     vocab = set(vocab)
#     return vocab, word_counter, avg_doc_length

# %%
# def build_vocub(remove_threshold, res):
#     vocab, word_counter, avg_doc_length = get_vocab(res)
#     remove_words = []
#     remove_below = remove_threshold

#     for word, count in word_counter.items():
#         if count < remove_below:
#             remove_words.append(word)

#     remove_words = set(remove_words)
#     processed_tokens = []
#     print('substituting words...')

#     for sentence in res:
#         temp = []
#         for word in sentence:
#             if word in remove_words:
#                 temp.append('<UNK>')
#             else:
#                 temp.append(word)
#         processed_tokens.append(temp)
#     vocab, word_counter, avg_doc_length = get_vocab(processed_tokens)
#     vocab_size = len(vocab)
#     print(f'vocab size is {vocab_size}, new average doc length after substituting low freuency token is {avg_doc_length}')
#     return vocab, word_counter, avg_doc_length, remove_words

# %%
# vocab, word_counter, avg_doc_length,remove_words = build_vocub(4, res)

# %%
# word_to_idx = {w: idx for idx, w in enumerate(vocab)}
# idx_to_word = {idx: w for idx, w in enumerate(vocab)}

# %% [markdown]
# ### generate D for sytactic context

# %%
def load_syntex_annotation(file_name):
    data = open(file_name, "r")
    file = data.read()
    data.close()
  # result = np.zeros((len(file),10))
    result_sentences = file.split("\n\n")
    result_tokenize = []
    for i in result_sentences:
        cur_sentence = []
        cur = i.split("\n")
        for j in cur:
            cur_sentence.append(j.split("\t"))
        result_tokenize.append(cur_sentence)
    return result_tokenize[:-1]

# %%
result_tokenize = load_syntex_annotation("data/training/training-data.1m.conll")

# %% [markdown]
# ### generate the syntax_idx for each sentence in training dataset

# %%
def reconstruct(idx):
    return " ".join([i[1] for i in result_tokenize[idx]])

# %%
import csv
def creat_and_save_syntax_idx(df,result_tokenize):
    rebuild_col = [reconstruct(i) for i in range(len(result_tokenize))]
    counter  = 0
    text_to_syntex_idx = {}
    for i in range(len(df.text)):
        try:
            idx = rebuild_col.index(df.text[i])
        # print(idx)
            text_to_syntex_idx[i] = idx
        except:
            continue
        if i %9999 == 0:
            with open('syntax_index_%s.csv'%(i//9999), 'w') as csv_file:  
                writer = csv.writer(csv_file)
                for key, value in text_to_syntex_idx.items():
                    writer.writerow([key, value])
            text_to_syntex_idx = {}
    # file = pd.DataFrame(text_to_syntex_idx )
    text_to_syntex_idx = {}
    with open('index syntax file/syntax_index_%s.csv'%(i), 'w') as csv_file:  
        writer = csv.writer(csv_file)
        for key, value in text_to_syntex_idx.items():
            writer.writerow([key, value])

# %%
# creat_and_save_syntax_idx(df,result_tokenize)

# %%
# file = open('index syntax file/syntax_index_%s.csv')

# %%
#load the syntax_idx
def load_syntex_idx_dict():
    text_to_syntex_idx = {}
    for i in range(100):
        try:
            with open('index syntax file/syntax_index_%s.csv'%(i)) as csv_file:
                reader = csv.reader(csv_file)
                mydict = dict(reader)
                text_to_syntex_idx.update(mydict)
        except:
            continue
    print("%s of the 1 million training text instance is annotated"%len(set(text_to_syntex_idx.keys())))
    return text_to_syntex_idx

# %%
text_to_syntex_idx = load_syntex_idx_dict()
# Out:
# 926555 of the 1 million training text instance is annotated

# %%
def generate_dependency_based(tokens,result_tokenize):
    result = []
    count = 0
    featurized_token=[]
    for idx, sentence in enumerate(tokens):
        if idx % 100000 == 0:
            print("completed %s dependency-based feature extraction"%(idx))
        try:
            cur_annotated_lst = result_tokenize[int(text_to_syntex_idx[str(idx)])]
            ref_col = [int(i[6]) for i in cur_annotated_lst]
            word_lst = [i[1] for i in cur_annotated_lst]
            word_process_lst = []
            for s in word_lst:
                s1 = s.lower()
                s1 = re.sub(RE_STRIP_SPECIAL_CHARS, '', s1)
                s1 = re.sub(RE_NUMBER, ' ', s1)
                if s1 not in stop_words:
                    word_process_lst.append(s1.strip())
                else:
                    word_process_lst.append(' ')
            temp_idx = []
            cur_pair_col =[]
            for idx_token, token in enumerate(sentence):
                cur_word_idx = word_process_lst.index(token)
                refer_idx = int(cur_annotated_lst[cur_word_idx][6])
                if (word_process_lst[refer_idx -1]!= ' ') and (word_process_lst[refer_idx -1]!= ''):
                    cur_pair = [token,word_process_lst[refer_idx -1]]
                    cur_pair_col.append(cur_pair)
                    temp_idx.append(cur_word_idx)
                    temp_idx.append(refer_idx -1)
            
                chosen_idx_col = np.where(np.array(ref_col) == cur_word_idx + 1)[0]
                for j in chosen_idx_col:
                    if (word_process_lst[j] != ' ') and (word_process_lst[j] !=''):
                        cur_pair = [token,word_process_lst[j]]
                        cur_pair_col.append(cur_pair)
                        temp_idx.append(j)
                        temp_idx.append(cur_word_idx)
            vocub_word = [word_process_lst[i] for i in temp_idx]
            result.extend(cur_pair_col)
#             print(vocub_word)
            featurized_token.extend(vocub_word)
            count += 1
           
        except:
            continue
    flatten_result = set([item for sublist in result for item in sublist])
    print(set(featurized_token) -flatten_result )
    print(flatten_result - set(featurized_token))
    #replace element of pairs in result belong to remove_words with'<UNK>' => generalize words on 'Unknown words' with all the context of low-frequency words
    print("%s sentences participated in the dependecy-based feature extraction"%(count))
    
    
    
    return result, featurized_token

# %%
def get_vocab(tokens):
#     vocab = []
#     for sentence in tokens:
#         for token in sentence:
#             vocab.append(token)

    word_counter = Counter(tokens)
#     avg_doc_length = len(vocab) / len(tokens)
    vocab = set(tokens)
    return vocab, word_counter

# %%
def build_vocub(remove_threshold, featurized_token):
    vocab, word_counter= get_vocab(featurized_token)
    remove_words = []
    remove_below = remove_threshold
    for word, count in word_counter.items():
        if count < remove_below:
            remove_words.append(word)

    remove_words = set(remove_words)
    print('substituting %s words'%(len(remove_words)))
    new_featurized_token = []
    for token in featurized_token:
        if token in remove_words:
            new_featurized_token.append('<UNK>')
        else:
            new_featurized_token.append(token)
    new_vocab, new_word_counter = get_vocab(new_featurized_token)
    vocab_size = len(set(new_vocab))
    print(f'vocab size is {vocab_size}')
    return new_vocab, new_word_counter, remove_words,new_featurized_token

# %%
def feature_adjust_unknown(featurized_token, remove_words):
    result = []
    for sentence in featurized_token:
        temp =[]
        for word in sentence:
            if word in remove_words:
                temp.append('<UNK>')
            else:
                temp.append(word)
        result.append(temp)
    return result

# %%
    
result, featurized_token = generate_dependency_based(res,result_tokenize)
# Out:
# completed 0 dependency-based feature extraction
# completed 100000 dependency-based feature extraction
# completed 200000 dependency-based feature extraction
# completed 300000 dependency-based feature extraction
# completed 400000 dependency-based feature extraction
# completed 500000 dependency-based feature extraction
# completed 600000 dependency-based feature extraction
# completed 700000 dependency-based feature extraction
# completed 800000 dependency-based feature extraction
# completed 900000 dependency-based feature extraction
# completed 1000000 dependency-based feature extraction
# set()
# set()
# 924568 sentences participated in the dependecy-based feature extraction

# %%
vocab, word_counter, remove_words,new_featurized_token = build_vocub(2, featurized_token)
# Out:
# substituting 2199 words
# vocab size is 225473

# %%
result_adjusted = feature_adjust_unknown(result, remove_words)

# %%
print("The adjusted training dependecy-based (c,w) pair has size of",len(result_adjusted))
# Out:
# The adjusted training dependecy-based (c,w) pair has size of 15528490

# %%
flatten_result = set([item for sublist in result_adjusted for item in sublist])
print(set(new_featurized_token ) -flatten_result )
print( flatten_result- set(new_featurized_token ) )
# Out:
# set()
# set()

# %%
vocab_size = len(vocab)

# %%
word_to_idx = {w: idx for idx, w in enumerate(vocab)}
idx_to_word = {idx: w for idx, w in enumerate(vocab)}

# %% [markdown]
# * first build a (c,w) pair collection, since not each w exist a pair that's featurized, return the featurized_token
# * using the featurized_token to build the vocab, calculate the frequency of each token and replace the token(smaller than threshold) to be "unknown"\
# * recalculate the vocab and word frequency with substitution(with unknown), and build the word to index dict
# * adjsut the (c,w) pairs with substitution

# %%
# result = generate_dependency_based(res,remove_words)

# %% [markdown]
# ### build (c,w) pair in idx format pairs

# %%
def skipgram_to_idx(dependency_based, idx_dict):
    print('creating dependency_based (w,c) pairs <-> index dictionary')
    result = []
    
    for db in dependency_based:
        result.append([idx_dict[db[0]], idx_dict[db[1]]])

    return result

# %%
# 'nonidentifying' in remove_words

# %%
db_idx= skipgram_to_idx(result_adjusted, word_to_idx)
# Out:
# creating dependency_based (w,c) pairs <-> index dictionary

# %%
#temp save
file_out = pd.DataFrame(result_adjusted)
file_out.to_csv("temp result/dependecy_based_pairs.csv", index = False)

# %%
# 
file_out2 = pd.DataFrame(db_idx)
file_out2.to_csv("temp result/dependecy_based_db_idx_pairs.csv", index = False)

# %% [markdown]
# ## Build the training model

# %%
import torch
from torch import nn
import torch.optim as optim
import pandas as pd
import numpy as np
import os
import sys
from torch.utils.data import TensorDataset, DataLoader

# %%
class SkipgramModel(nn.Module):
    def __init__(self, vocab_size, embed_dim, word_dist):
        super().__init__()
        
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.word_dist = word_dist
        
        # ("orange", "juice", observed=1), ("orange", "king", observed=0) 
        # => "orange" is context word, "juice" & "king" are target words
        self.context_embed = nn.Embedding(vocab_size, embed_dim)
        self.target_embed = nn.Embedding(vocab_size, embed_dim)
        
        self.context_embed.weight.data.uniform_(-1, 1)
        self.target_embed.weight.data.uniform_(-1, 1)
    
    def get_context_row(self, word):
        return self.context_embed(word)
    
    def get_target_row(self, word):
        return self.target_embed(word)
    
    def get_negative_samples(self, batch_size, k):
        negative_samples = torch.multinomial(self.word_dist, batch_size * k, replacement=True)
        device = "cuda" if self.target_embed.weight.is_cuda else "cpu"
        negative_samples = negative_samples.to(device)
        return self.target_embed(negative_samples).view(batch_size, k, self.embed_dim)

# %%
class SkipgramLoss(nn.Module):
    def __init__(self):
        super().__init__()
    
    def forward(self, context_vectors, target_vectors, negative_vectors):
        batch_size, embed_dim = context_vectors.shape
        context_vectors = context_vectors.view(batch_size, embed_dim, 1)
        target_vectors = target_vectors.view(batch_size, 1, embed_dim)
        
        observed_sample_loss = torch.bmm(target_vectors, context_vectors).sigmoid().log()
        observed_sample_loss = observed_sample_loss.squeeze()
        
        negative_sample_loss = torch.bmm(negative_vectors.neg(), context_vectors).sigmoid().log()
        negative_sample_loss = negative_sample_loss.squeeze().sum(1)
        
        return -(observed_sample_loss + negative_sample_loss).mean()

# %%
training_idx= np.array(db_idx) 
print(training_idx.shape)
# Out:
# (15528490, 2)

# %%
def generate_batches(skipgrams, batch_size):
    n_batches = len(skipgrams) // batch_size
    skipgrams = skipgrams[:n_batches*batch_size]
    for i in range(0, len(skipgrams), batch_size):
        context = []
        target = []
        batch = skipgrams[i:i+batch_size]
        for j in range(len(batch)):
            context.append(batch[j][0])
            target.append(batch[j][1])
        yield context, target

# %%
# training_ratio = 0.0001

# selected_idx =  torch.randperm(training_idx.size(0))[:int(training_idx.size(0)*training_ratio)]
training_size = len(db_idx)
selected_dataset = db_idx[:training_size]

print("selected training size %s"%(len(selected_dataset)))
# Out:
# selected training size 15528490

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
word_freq = np.asarray(sorted(word_counter.values(), reverse=True))
unigram_dist = word_freq / word_freq.sum()
negative_sample_dist = torch.from_numpy(unigram_dist**(0.75) / np.sum(unigram_dist**(0.75)))
batch_size = 16384
embed_dim = 300
model = SkipgramModel(vocab_size, embed_dim, negative_sample_dist).to(device)
criterion = SkipgramLoss()
optimizer = optim.Adam(model.parameters())
#, lr=0.0015
print_every = 1
epochs = 50
k = 4


print('training started')
# train for some number of epochs
for e in range(epochs):

    counter=0
    
    # get our input, target batches
    for context_words, target_words in generate_batches(selected_dataset, batch_size):
        context, targets = torch.LongTensor(context_words), torch.LongTensor(target_words)
        context, targets = context.to(device), targets.to(device)

        # input, outpt, and noise vectors
        context_vectors = model.get_context_row(context)
        target_vectors = model.get_target_row(targets)
        negative_vectors = model.get_negative_samples(batch_size, k)

        # negative sampling loss
        loss = criterion(context_vectors, target_vectors, negative_vectors)
#         print(loss)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        counter+=1
        if counter % 10000 == 0:
            print(counter)
        

    # loss stats
    if e % print_every == 0:
        print(f"Epoch: {e+1}/{epochs}")
        print("Loss: ", loss.item()) # avg batch loss at this point in training
# Out:
# training started
# Epoch: 1/50
# Loss:  5.82379150390625
# Epoch: 2/50
# Loss:  2.2779953479766846
# Epoch: 3/50
# Loss:  1.3885846138000488
# Epoch: 4/50
# Loss:  1.0691965818405151
# Epoch: 5/50
# Loss:  0.846772313117981
# Epoch: 6/50
# Loss:  0.7154913544654846
# Epoch: 7/50
# Loss:  0.6229851841926575
# Epoch: 8/50
# Loss:  0.5586779713630676
# Epoch: 9/50
# Loss:  0.4876370429992676
# Epoch: 10/50
# Loss:  0.4392511248588562
# Epoch: 11/50
# Loss:  0.4133267402648926
# Epoch: 12/50
# Loss:  0.3733818531036377
# Epoch: 13/50
# Loss:  0.3544584810733795
# Epoch: 14/50
# Loss:  0.3289410471916199
# Epoch: 15/50
# Loss:  0.3220687210559845
# Epoch: 16/50
# Loss:  0.3017863631248474
# Epoch: 17/50
# Loss:  0.282633900642395
# Epoch: 18/50
# Loss:  0.26394128799438477
# Epoch: 19/50
# Loss:  0.2608067989349365
# Epoch: 20/50
# Loss:  0.2326345592737198
# Epoch: 21/50
# Loss:  0.22943073511123657
# Epoch: 22/50
# Loss:  0.22647219896316528
# Epoch: 23/50
# Loss:  0.21465054154396057
# Epoch: 24/50
# Loss:  0.2051054835319519

# %% [markdown]
# ### output the embedding and check from samples

# %%
def output_embed(embed):
#     print('writing embedding to output file')
    f = open('embedding_4.txt', 'w')
    for idx, word_embed in enumerate(embed):
        word = idx_to_word[idx]
        temp = "".join(word.split()) + ' '
        for value in word_embed:
            temp = temp + str(value) + ' '
        temp += '\n'
        f.write(temp)
    f.close()
    print('completed')

# %%
embeddings = model.context_embed.weight.to('cpu').data.numpy()
output_embed(embeddings)
# Out:
# completed

# %% [markdown]
# ### get the development word pairs similarity

# %%
import numpy as np
import pandas as pd
def preprocess_word(s):
    s1 = s.lower()
    s1 = re.sub(RE_STRIP_SPECIAL_CHARS, '', s1)
    s1 = re.sub(RE_NUMBER, ' ', s1)
    s1 = s1.strip()
    if s1 in stop_words:
        s1 = ''
    else: 
        s1 = s1.strip()
    return s1
def get_dev_similarity(embed_path, output_path):
    def read_embedding(path):
        embedding = {}
        dim = None
        for row in open(path):
            word, *vector = row.split()
#             try:
            embedding[word] = [float(x) for x in vector]
#             except:
#                 continue

            if dim and len(vector) != dim:

                print("Inconsistent embedding dimensions!", file = sys.stderr)
                sys.exit(1)

            dim = len(vector)

        return embedding, dim



    E, dim = read_embedding(embed_path)
    pairs = pd.read_csv("data/similarity/dev_x.csv", index_col = "id")
    cal_similarity = []
    for w1, w2 in zip(pairs.word1, pairs.word2):
        w1 = preprocess_word(w1)
        w2 = preprocess_word(w2)
        if w1 not in E.keys():
            cur1 = '<UNK>'
        else:
            cur1 = w1
        if w2 not in E.keys():
            cur2 = '<UNK>'
        else:
            cur2 = w2
        cal_similarity.append(np.dot(E[cur1], E[cur2]))
    pairs["similarity"] = cal_similarity
    # [np.dot(E[w1], E[w2])
    #     for w1, w2 in zip(pairs.word1, pairs.word2)]
    print(len(cal_similarity))
    del pairs["word1"], pairs["word2"]

    # print("Detected a", dim, "dimension embedding.", file = sys.stderr)
    pairs.to_csv(output_path)

# %%
get_dev_similarity("embedding_4.txt", "prediction_4.csv")
# Out:
# 353

# %% [markdown]
# ### evaluate the development set correlation

# %%
import numpy as np
import pandas as pd
from scipy.stats import spearmanr
def evaluate_correlation(prediction_path):
    pred = pd.read_csv(prediction_path, index_col = "id")
    dev = pd.read_csv("data/similarity/dev_y.csv", index_col = "id")
    pred.columns = ["predicted"]
    dev.columns = ["actual"]
    data = dev.join(pred)
    print("Correlation:", spearmanr(data).correlation)

# %%
evaluate_correlation("prediction_4.csv")
# Out:
# Correlation: 0.3701394023164904

# %%
words = {'acronymic', 'implicational', 'shouter', 'fractures', 'endurable',
'season', 'interplanetary', 'panic', 'fastness', 'disinvestment', 'up-to-date',
'admiralty', 'murder', 'loss', 'rejoinders', 'cash', 'metal', 'exhibit',
'exterminate', 'disinheritance', 'churchs', 'discriminate', 'vulgarism',
'recourse', 'deciphering', 'partible', 'marriage', 'meet', 'houseful',
'unemotional', 'nest', 'sodium', 'carnivore', 'circumscribes', 'listeners',
'continuance', 'cylindrical', 'undeniable', 'preschoolers', 'courteous',
'establishment', 'submerging', 'grow', 'improvised', 'shrink', 'sandbag',
'prudent', 'sexually', 'france', 'moralist', 'affiliation', 'householders',
'evidently', 'provisionally', 'sun', 'monotony', 'trusteeship', 'conversely',
'indirectness', 'transverse', 'seafood', 'incensing', 'immigrating', 'rainless',
'harpsichord', 'rational', 'intentionality', 'hypocrisy', 'common',
'distribute', 'undefined', 'combust', 'religionist', 'occlusion', 'recognition',
'medal', 'partiality', 'wrong', 'paradoxical', 'benchmark', 'episode',
'unbroken', 'brightness', 'unconsolidated', 'payment', 'unmentionables', 'skip',
'school', 'motherless', 'soldier', 'tell', 'seal', 'hole', 'sheikhdoms',
'basic', 'peripheral', 'shower', 'omnipotence', 'retrying', 'boisterously',
'detestable', 'defecation', 'child', 'abandon', 'inversions', 'leagued',
'pretenders', 'soap', 'chance', 'mile', 'deny', 'capitalised', 'terror',
'inventively', 'finance', 'evacuated', 'prostatic', 'bend', 'worthless',
'nation', 'variable', 'refer', 'rank', 'doctor', 'death', 'fret', 'policy',
'back', 'furnace', 'importances', 'affectional', 'canyon', 'bronchus',
'possible', 'civilise', 'interpenetrate', 'villainous', 'production', 'market',
'comportment', 'conjecture', 'algebraist', 'contortionists', 'translocating',
'entrapping', 'defrauding', 'brave', 'artist', 'smile', 'shoulders',
'attributions', 'legalism', 'pervert', 'regiment', 'possibility', 'bachelors',
'citizen', 'decapitated', 'conflict', 'cold', 'return', 'naughtiness',
'careful', 'month', 'hypertext', 'cock', 'hyperextension', 'transforming',
'glittery', 'text', 'procreation', 'pessimist', 'typify', 'alcohol',
'disturbing', 'marginality', 'noticeable', 'preventive', 'charm', 'libelous',
'homosexual', 'bread', 'covariant', 'measurements', 'congeniality',
'self-fulfillment', 'take', 'initiation', 'ranch', 'deposes', 'harmony',
'drafting', 'butter', 'feel', 'instrumentality', 'ingroup', 'heterosexual',
'curious', 'recess', 'anxiety', 'make', 'assembly', 'distrustful', 'asteroidal',
'leading', 'copy', 'corroding', 'solemnity', 'pinpointed', 'manacles',
'brigadier', 'tasteful', 'utility', 'responsible', 'containerful',
'conscientiousness', 'circumcisions', 'unconcern', 'insurgent', 'credit',
'displeased', 'get', 'violating', 'shepherd', 'refered', 'unprecedented',
'gender', 'certificate', 'publication', 'alleviated', 'unsighted', 'dysentery',
'needlepoint', 'abductor', 'deceitful', 'autopilot', 'enunciating', 'excessive',
'boastful', 'coffee', 'culture', 'preparation', 'sell', 'student', 'inexpert',
'subserve', 'desiccating', 'irredeemable', 'constitute', 'evaluate',
'unostentatious', 'performance', 'propagate', 'mushroomed', 'trouble',
'restraint', 'grocery', 'circumvent', 'match', 'book', 'unannounced',
'dreadnought', 'appearance', 'laugh', 'disagree', 'measure', 'subletting',
'body', 'unstuff', 'peace', 'excitations', 'concentration', 'international',
'Japanese', 'advised', 'astronomer', 'sound', 'deforming', 'material',
'fetishism', 'syntaxes', 'inorganic', 'counterfeit', 'devilishly', 'carry',
'mental', 'spot', 'restrainer', 'live', 'socialise', 'reassess', 'scholarship',
'foreclosed', 'prevent', 'missile', 'abuse', 'edible', 'germinate', 'imitate',
'criticality', 'initialise', 'cabbage', 'suspiciousness', 'fruitful', 'respite',
'sign', 'sweet', 'preconceptions', 'badness', 'tax', 'memorialize', 'tableware',
'tube', 'traitorous', 'hire', 'mouth', 'admitting', 'append', 'differentia',
'monotype', 'remind', 'immobile', 'interrelated', 'incommensurable', 'heavy',
'socialites', 'intermingles', 'Wednesday', 'voraciously', 'muster',
'insufficiency', 'england', 'minority', 'language', 'attack', 'undeviating',
'covering', 'replicate', 'unimpressed', 'impressionable', 'defiles', 'reform',
'oxide', 'skillfulness', 'bestowal', 'wheaten', 'real', 'castled', 'falsifier',
'attributable', 'mercantile', 'implausible', 'journey', 'site', 'gem',
'disturbances', 'enfolded', 'astonish', 'algebraic', 'available', 'rounded',
'repulses', 'vulnerable', 'unmelted', 'walloper', 'pedaler', 'cut',
'wilderness', 'sport', 'squishing', 'nakedness', 'district', 'inheritor',
'intragroup', 'transmigrating', 'argue', 'involvement', 'autoregulation',
'health', 'apparition', 'eventful', 'fauna', 'choose', 'area', 'trial',
'ethnic', 'ebb', 'similar', 'localise', 'analyzed', 'translocate',
'conspicuousness', 'triclinic', 'multidimensional', 'guillotine', 'network',
'exaction', 'entrench', 'scandinavian', 'building', 'obtainment', 'diagonal',
'sympathized', 'asian', 'bendability', 'substance', 'sorcery', 'kingship',
'absconding', 'kind', 'galvanize', 'artifact', 'spill', 'avenue', 'process',
'life', 'diffidence', 'hill', 'estrogenic', 'reproduction', 'vector', 'compel',
'changeableness', 'history', 'casteless', 'plundered', 'seafaring', 'brightly',
'page', 'situation', 'defiant', 'subspecies', 'chauvinist', 'room', 'chromatic',
'stupid', 'bank', 'lay', 'unwrap', 'kid', 'poisoning', 'animality',
'sublieutenant', 'transvestitism', 'rebellious', 'overshoe', 'crudeness',
'penis', 'tunneled', 'assessments', 'independences', 'short-change',
'conformations', 'distinction', 'censoring', 'dirty', 'fluidity', 'automatic',
'critic', 'untilled', 'discrimination', 'brisker', 'nonperformance',
'friendliness', 'unfavorable', 'habitable', 'bleach', 'paparazzo', 'scrutiny',
'crane', 'destroyers', 'pronounce', 'transformation', 'self-improvement',
'humanness', 'unisons', 'concordance', 'bengali', 'heat', 'resource',
'shepherded', 'thrombosis', 'trioxide', 'boldness', 'precedent', 'backwardness',
'cofactor', 'scandalize', 'enunciates', 'liveable', 'comfortable', 'deep',
'commissions', 'acceptance', 'embezzle', 'upset', 'replacements', 'evaporate',
'inessential', 'protestant', 'intercede', 'recommendation', 'organismal',
'animalism', 'principality', 'raw', 'combusting', 'transalpine', 'positioners',
'hike', 'reprints', 'nonconscious', 'obstructive', 'disadvantaged',
'infectiously', 'regenerate', 'note', 'interlink', 'naturalise', 'stewardship',
'gracefulness', 'decision', 'synchronic', 'consumptive', 'nontoxic', 'expose',
'greenness', 'procreated', 'despoil', 'thinness', 'entrust', 'repeat', 'nurse',
'terrorize', 'join', 'internationalize', 'dissociations', 'consubstantial',
'microcircuit', 'empower', 'disability', 'sexy', 'stockers', 'prize',
'prejudging', 'seepage', 'photographer', 'intertwining', 'delimited',
'transmigrated', 'combatted', 'religious', 'poison', 'shape', 'behaviorist',
'suspect', 'microfilm', 'suppressor', 'deflate', 'exchangeable', 'stitch',
'seller', 'five', 'afghani', 'scampering', 'flee', 'mammal', 'line', 'emerald',
'uncomfortable', 'enslaves', 'recitalist', 'governance', 'moderate',
'attendances', 'innovativeness', 'unparented', 'American', 'commandership',
'purveying', 'scientist', 'weaken', 'steepen', 'informal', 'technology',
'spread', 'deletion', 'universe', 'submarine', 'disquieting', 'disgust',
'breathe', 'uncomprehending', 'germanic', 'retraction', 'noon', 'translunar',
'orchestrations', 'unpersuasive', 'genuinely', 'detectable', 'lengthy',
'energetic', 'invigorating', 'negotiable', 'plate', 'survivalist', 'entombment',
'fundamentalism', 'bounce', 'microfossils', 'Harvard', 'develop', 'circumpolar',
'example', 'concurrencies', 'modesty', 'statement', 'consigning', 'cheap',
'hive', 'gene', 'weirdly', 'blitzed', 'performances', 'thousand', 'squirt',
'singe', 'desirable', 'unnecessary', 'effort', 'race', 'serve', 'venomous',
'highjacking', 'wrestle', 'serial', 'picture', 'unfeathered', 'lastingly',
'rack', 'rook', 'help', 'trace', 'metabolism', 'sociable', 'luxuriance',
'spacewalker', 'wheel', 'defeating', 'premisses', 'obviousness', 'condensing',
'association', 'fortitude', 'incommutable', 'system', 'lie', 'susceptible',
'force', 'standardize', 'brand-newness', 'enthuse', 'algebra', 'arrange',
'laboratory', 'branch', 'intense', 'bewitchment', 'check', 'computation',
'anamorphosis', 'subdividing', 'hybridise', 'shrieks', 'traditionalism',
'continue', 'repurchases', 'disclosure', 'program', 'unrepeatable', 'word',
'stroked', 'survey', 'beginning', 'cry', 'rotational', 'engrave', 'exhibited',
'confess', 'residing', 'warship', 'rudderless', 'insurrectional',
'unaccessible', 'content', 'cockerel', 'attested', 'woodland', 'calendar',
'secularist', 'painkillers', 'ganging', 'equivalence', 'interlayers',
'undetectable', 'assay', 'biographer', 'prophetic', 'standard', 'brandy',
'inabilities', 'lover', 'protectorship', 'employed', 'nonviable', 'distressful',
'prisoner', 'unformed', 'unicycling', 'contraception', 'transducers',
'codefendants', 'perform', 'sugar', 'thermonuclear', 'ill', 'microvolts',
'dissolved', 'murderer', 'lilt', 'colorful', 'official', 'painter', 'position',
'summonings', 'disjunct', 'outfoxed', 'flattery', 'fill', 'reenactor',
'breather', 'insensitive', 'hypersensitive', 'registry', 'scenery', 'poll',
'gravity', 'fruiterer', 'absence', 'astronomical', 'sermonize', 'problem',
'bootless', 'complimentary', 'placidity', 'scowl', 'fascinate',
'protectiveness', 'monk', 'preteens', 'disfavor', 'stroke', 'microcircuits',
'nomad', 'basketball', 'offensive', 'carburettors', 'largeness', 'preempt',
'fighting', 'supermarket', 'muscularity', 'perceptible', 'macroevolution',
'arab', 'flighted', 'reproachful', 'inducement', 'respectively', 'animalize',
'necessitate', 'keyboard', 'evidence', 'debarred', 'noble', 'sweetish',
'encrusted', 'submariners', 'negociate', 'initiate', 'rabbi', 'restrict',
'direction', 'blow', 'constancy', 'equality', 'defame', 'intending', 'swing',
'invitation', 'editor', 'madhouse', 'think', 'profit', 'possession',
'drownings', 'unfortunate', 'abandonment', 'virologist', 'aim', 'reasoning',
'radiance', 'excavations', 'remarkable', 'mechanical', 'accomplished',
'follower', 'prehistorical', 'important', 'insecurities', 'sponsor',
'difference', 'commode', 'pottery', 'skid', 'undefinable', 'monogram',
'circumvents', 'shortish', 'omission', 'icelandic', 'unintelligible',
'undiscerning', 'desire', 'fertility', 'change', 'satisfactory', 'reproves',
'authority', 'size', 'dissimulate', 'vaporise', 'surroundings', 'inflammation',
'eavesdropper', 'fever', 'postglacial', 'intercommunicate', 'self', 'possessor',
'infeasible', 'unclog', 'car', 'creative', 'retrace', 'managership',
'extension', 'extort', 'connect', 'lenience', 'embroideries', 'circumcising',
'secret', 'partner', 'convert', 'spoonfuls', 'cucumber', 'supposed',
'baptistic', 'intercession', 'categorization', 'immobilization', 'synchronized',
'structure', 'shackle', 'eye', 'science', 'impossible', 'delight', 'gladness',
'unsuitable', 'index', 'beat', 'sight', 'idiocy', 'underprivileged',
'companionships', 'unconscious', 'illiberal', 'attachment', 'radical',
'exclaiming', 'intelligences', 'unflagging', 'selectively', 'huffy',
'bastardize', 'misleading', 'benefited', 'noncitizens', 'reduce', 'prudery',
'extravert', 'toppled', 'postmodernist', 'adventism', 'eruptive', 'emulsify',
'incorrupt', 'subeditor', 'glass', 'liquid', 'discovery', 'player', 'drawers',
'unheralded', 'rustic', 'group', 'corrupt', 'feminised', 'maildrop',
'migrational', 'impermissible', 'predetermine', 'repel', 'relocation',
'enthusiastic', 'discountenance', 'company', 'engorge', 'religiousness',
'contravened', 'deadness', 'helm', 'transshipped', 'galvanic', 'acquisition',
'roosted', 'radiators', 'extraterrestrial', 'wild', 'hostility', 'asylum',
'perfectible', 'isosceles', 'composed', 'about', 'advancement', 'prophetical',
'transubstantiate', 'sentenced', 'unobjectionable', 'spiritualize',
'circumnavigations', 'encroachments', 'displeases', 'curvature', 'sexual',
'directional', 'approved', 'prisoners', 'law', 'designs', 'autobuses',
'blithering', 'career', 'therapeutical', 'label', 'trespass', 'crusaders',
'unmanned', 'unassertiveness', 'extinguish', 'integrity', 'internationaler',
'movie', 'contrarily', 'accordance', 'injure', 'antedating', 'spherical',
'fireproof', 'troops', 'acting', 'accessible', 'blessing', 'battleships',
'opinion', 'crier', 'flight', 'transfusing', 'professor', 'touch', 'expel',
'postmark', 'happiness', 'reasonable', 'organic', 'encapsulate', 'improving',
'unisexual', 'secretary', 'Arafat', 'amorphous', 'equip', 'interact', 'travel',
'cell', 'victim', 'conclusive', 'drink', 'speed', 'noisy', 'expressionless',
'series', 'subordination', 'animal', 'encouragement', 'bridge', 'entrance',
'exacted', 'knowing', 'fractionate', 'internationality', 'accommodation',
'image', 'nonfunctional', 'inmate', 'excitation', 'acrobat', 'hundred', 'motto',
'elated', 'dictatorship', 'evolution', 'withdrawal', 'functionality',
'corpulence', 'distributive', 'supernatural', 'depopulate', 'ship',
'monoculture', 'unquenchable', 'pathless', 'dangerous', 'rectorate',
'duplicable', 'literalness', 'run', 'bird', 'freakishly', 'surround',
'hospitalize', 'federalize', 'cheapen', 'tiger', 'conflagration', 'stimuli',
'comprehensive', 'inoffensive', 'ceaseless', 'militarize', 'designed',
'refinery', 'washers', 'disestablishing', 'preconception', 'resurfacing',
'spangle', 'homogenized', 'volunteer', 'agitation', 'board', 'careerism',
'farmer', 'undisputable', 'numerical', 'earmuffs', 'inscribe', 'virtuoso',
'respectable', 'besieging', 'imperils', 'know-how', 'partnership', 'clownish',
'differences', 'anticancer', 'assassinated', 'heterosexism', 'exterminator',
'reordering', 'unilateralist', 'utterance', 'goldplated', 'dematerialised',
'gelatinous', 'motivation', 'surpass', 'interesting', 'classify', 'fire', 'pay',
'homogeneous', 'cynically', 'scot', 'fabricate', 'topically', 'scope', 'film',
'unicyclist', 'monogenesis', 'device', 'postdates', 'infrastructure',
'authorship', 'immortalize', 'unsatisfactory', 'general', 'leverage', 'current',
'languishing', 'remitting', 'fight', 'insure', 'cocoon', 'ripeness', 'colonise',
'different', 'separationist', 'hop', 'election', 'connection', 'puritanism',
'academicism', 'demanded', 'guidance', 'bishop', 'carbonic', 'center',
'capture', 'traveler', 'outshout', 'unquestioned', 'creator', 'proton',
'quitter', 'jaguar', 'convector', 'disarranged', 'embroideress', 'disaster',
'septic', 'unexpected', 'property', 'infolding', 'galaxy', 'distinguishing',
'objectify', 'lusterware', 'enrollment', 'starkness', 'internet', 'splitter',
'supplanting', 'abnormality', 'deposit', 'valor', 'indoctrinate', 'grassroots',
'traversals', 'ordain', 'kilometer', 'rhymers', 'refurbishments', 'military',
'concert', 'merchandise', 'circumventing', 'execute', 'cofactors', 'transact',
'effectiveness', 'quadratics', 'agency', 'tournament', 'quicken', 'stoical',
'approachable', 'unrewarding', 'day', 'territory', 'confine', 'guest',
'sprinkle', 'inexpedient', 'regimental', 'undefeated', 'replications',
'obvious', 'elaborate', 'clozapine', 'museum', 'pave', 'depression', 'server',
'unintelligent', 'noise', 'black', 'slanderous', 'party', 'condition', 'focus',
'freshen', 'planet', 'hypertension', 'reduced', 'precociously', 'angrier',
'pitch', 'resides', 'cooperation', 'hospital', 'ostentatious', 'clericalism',
'christianise', 'attacker', 'deviationism', 'indicted', 'hilarity', 'invisible',
'fuck', 'lushness', 'commutation', 'deformity', 'tennis', 'unsalable',
'sportive', 'resistive', 'blunders', 'helical', 'dominance', 'urbanize',
'ecology', 'preposed', 'southern', 'rumbled', 'imposition', 'warning', 'mogul',
'divide', 'kindergarteners', 'lend', 'world', 'heater', 'edgeless', 'Jerusalem',
'aerialist', 'descend', 'internships', 'caramelize', 'protrusion', 'reckoner',
'inclosure', 'laud', 'rock', 'inconvertible', 'favourable', 'refuted',
'mistrustful', 'unmolested', 'transponder', 'critical', 'epicure', 'practice',
'harden', 'jarringly', 'case', 'Freud', 'seasonable', 'primer', 'long',
'predators', 'specialism', 'seriousness', 'uninformed', 'cynical', 'omnipotent',
'eat', 'improvement', 'fringes', 'nightly', 'inharmonious', 'inroad', 'popcorn',
'magically', 'convocation', 'domain', 'incalculable', 'hypercoaster',
'socialist', 'monograms', 'heedless', 'imitation', 'embody', 'brood',
'unilluminated', 'strengthened', 'muscle', 'stand-in', 'database',
'institutionalize', 'manner', 'star', 'disassembled', 'skidding', 'entity',
'marketers', 'papered', 'depreciate', 'reinterpret', 'unforgiving',
'horsemanship', 'Mars', 'friendship', 'interlingua', 'put', 'importance',
'conductance', 'attainment', 'labourer', 'evangelize', 'cardinality',
'consciousness', 'adapt', 'causing', 'knifing', 'impeded', 'indexical',
'unloved', 'classicist', 'kill', 'latinist', 'collection', 'expounded',
'microphallus', 'balance', 'marginalize', 'untroubled', 'interspecies',
'employments', 'classification', 'characterless', 'combination', 'salable',
'disfavoring', 'belief', 'encouraging', 'Yale', 'disassociates', 'unknowing',
'canvass', 'battened', 'acknowledgement', 'illiterate', 'personifying',
'recorders', 'cowboys', 'wine', 'baggers', 'naivety', 'gardens', 'dooming',
'forest', 'direct', 'discounters', 'sing', 'unskillfulness', 'cross-index',
'handbook', 'perfect', 'reclassifications', 'hypersensitivity', 'electrical',
'subserving', 'ruralist', 'regained', 'viewer', 'extraterrestrials',
'irremovable', 'transmitter', 'fuel', 'bounced', 'foreign', 'letter', 'buck',
'impotently', 'explorers', 'antitoxic', 'dig', 'growth', 'ruler', 'street',
'viscometry', 'contravene', 'victory', 'unblock', 'tail', 'romanic', 'wizard',
'intraspecific', 'moon', 'combusts', 'disbelieving', 'cofounders', 'earning',
'illegal', 'immobilizing', 'order', 'vindictiveness', 'become', 'quality',
'unicycles', 'halfhearted', 'demerit', 'exclamation', 'characteristic',
'politician', 'circumference', 'selling', 'fulfillments', 'nonpolitical',
'game', 'investor', 'sheepish', 'gloom', 'autocracy', 'partnerships',
'concreteness', 'antipsychotic', 'unzipping', 'usher', 'heartlessness',
'disorderly', 'rareness', 'cosponsoring', 'encoded', 'directionless',
'instruct', 'uncontrolled', 'nonconformist', 'discipline', 'yellowish',
'magnetic', 'subsurface', 'unbiased', 'requests', 'broadcasters', 'block',
'ticket', 'membership', 'weapon', 'sexism', 'tailgate', 'king', 'intersected',
'empty', 'hotel', 'uncommunicative', 'adaptive', 'actor', 'software',
'circumscribed', 'remember', 'transsexual', 'leadership', 'profitless',
'interest', 'interdisciplinary', 'primates', 'uninterested', 'abnormal',
'arouse', 'apolitical', 'spouse', 'sandwich', 'ennobled', 'concerti', 'enjoins',
'rooters', 'dissociable', 'acoustics', 'unreserved', 'dry', 'fantasist',
'frighten', 'presenting', 'discourteous', 'representational', 'fasten',
'parallelize', 'prejudge', 'cession', 'pledged', 'foresters', 'narrow-minded',
'distillate', 'preaching', 'censorships', 'seat', 'food', 'disengages',
'interlace', 'headless', 'sessions', 'subtropical', 'racket', 'reviewers',
'insidiously', 'spiritualist', 'banished', 'funeral', 'presence', 'profanity',
'strife', 'insurance', 'algebras', 'issue', 'football', 'unaffected', 'situate',
'imprecise', 'unprofessional', 'refresher', 'concurrency', 'incontestable',
'nerveless', 'worsens', 'regulate', 'legion', 'row', 'splice', 'behavioural',
'supplement', 'itch', 'transportation', 'letters', 'seeders', 'incubate',
'rhythmicity', 'theater', 'dissonance', 'prayer', 'racism', 'americanize',
'bellowing', 'populace', 'procurators', 'document', 'unwed', 'coeducation',
'cooperators', 'enhancement', 'skiing', 'moderatorship', 'inaccessible',
'disloyal', 'guardedly', 'adverse', 'finality', 'inheritable', 'increase',
'conjoins', 'secluding', 'hold', 'envelop', 'autograft', 'causative', 'smooth',
'equipment', 'uncertainty', 'provisionary', 'accommodative', 'microwaving',
'developments', 'disrespectful', 'reply', 'illimitable', 'circumvented', 'mind',
'commodes', 'astronautical', 'dependence', 'disk', 'confirmable', 'affirm',
'antechamber', 'guarantee', 'skilled', 'digitise', 'adjournment', 'contrive',
'marker', 'potent', 'postcode', 'vegetational', 'containers', 'undated',
'rehashing', 'perfective', 'approach', 'mingles', 'artlessness', 'government',
'currency', 'vindictively', 'royalist', 'unfavourable', 'postmodernism',
'memoir', 'founder', 'similarity', 'demoralise', 'flatulence', 'utilitarianism',
'binging', 'blurting', 'remounted', 'friendships', 'major', 'forecast', 'steep',
'analogous', 'unworthiness', 'duty', 'variation', 'interwove', 'nanosecond',
'confinement', 'urgency', 'radio', 'travelers', 'defrayed', 'outlawed',
'discriminatory', 'infectious', 'care', 'grinder', 'alarmism', 'extrajudicial',
'reproducible', 'analyze', 'talkativeness', 'command', 'extending', 'wealthy',
'circumspect', 'penitent', 'sprint', 'play', 'impolitic', 'fear', 'declare',
'synthesize', 'confluent', 'clergyman', 'italian', 'unacceptable', 'unsettled',
'percent', 'patrol', 'scattered', 'lubricate', 'robbery', 'educate', 'dark',
'hallucinating', 'guard', 'disavowed', 'unspecialised', 'interlaces', 'rub',
'hazard', 'longing', 'write', 'sit', 'ukrainians', 'censorship', 'intramural',
'love', 'Mexico', 'autobiographer', 'forbid', 'reinsured', 'music',
'revolutionise', 'humorous', 'incredulous', 'monarchical', 'gin', 'uproarious',
'reformism', 'ungraceful', 'pressurise', 'discordance', 'talk', 'freighter',
'victorious', 'corrode', 'tricolor', 'crisis', 'macroeconomist', 'publicise',
'dissenter', 'appraisal', 'large', 'coat', 'entertainer', 'merchantable',
'small', 'highlanders', 'bite', 'mathematician', 'retarding', 'posthole',
'playful', 'secondary', 'plant', 'abundance', 'enchantress', 'sufficed',
'untracked', 'predictive', 'undesirable', 'baste', 'queen', 'punctuate',
'children', 'expounding', 'observe', 'wealth', 'freshness', 'oil',
'championship', 'announcement', 'crispness', 'protraction', 'cliffhanger',
'interceptor', 'possess', 'postponements', 'eroticism', 'start', 'ejector',
'commit', 'listing', 'slack', 'snooper', 'autosuggestion', 'weaponize',
'figurative', 'magician', 'inquiring', 'impoliteness', 'emigration',
'acquisitive', 'mildness', 'thatcher', 'innocuous', 'anger', 'roofers', 'lease',
'consign', 'reputable', 'standing', 'hush', 'lithium', 'nonindulgent',
'harmful', 'semiconducting', 'practical', 'burying', 'environment', 'puffery',
'unloving', 'mutinied', 'prominence', 'microbiologist', 'criticism',
'enforcing', 'banquet', 'ear', 'interlinking', 'inheritances', 'paragraph',
'hydrochloride', 'characters', 'giving', 'authorize', 'spellers', 'syntactic',
'inquisitive', 'title', 'follow', 'greengrocery', 'conformism', 'insatiate',
'undemocratic', 'interpreter', 'immigrate', 'skateboarders', 'doctrine',
'unwanted', 'ascendence', 'zoo', 'advisory', 'dissenters', 'irritatingly',
'malevolence', 'believing', 'pleading', 'perceive', 'inbreeding',
'extraterritorial', 'irrationality', 'unfledged', 'unmarketable', 'atmosphere',
'shoot', 'carbonate', 'recycle', 'embellishment', 'wrathful', 'antifeminist',
'disguise', 'aid', 'psychodynamics', 'mother', 'brotherhood', 'philosophic',
'physically', 'collected', 'antitumor', 'postdated', 'broad', 'witch-hunt',
'move', 'unploughed', 'autobiographies', 'campfires', 'singing', 'ceramicist',
'self-discovery', 'telephone', 'object', 'emotional', 'inexplicable',
'brainless', 'vicarious', 'opportune', 'CD', 'symmetrical', 'organism',
'automobile', 'profusion', 'hover', 'link', 'rearrangements', 'kidnapped',
'skater', 'softness', 'depictive', 'down', 'regardless', 'term', 'exceedance',
'deviously', 'postposition', 'excitements', 'recast', 'denominate', 'sniffers',
'cosigns', 'amateurish', 'tea', 'dispossess', 'flightless', 'pestilence',
'assistance', 'preschooler', 'transposable', 'subfamily', 'diagonals',
'stickler', 'defensive', 'unwelcome', 'intermarry', 'shrewdness', 'regretful',
'monarchic', 'morality', 'fence', 'cofounder', 'resistor', 'excitedly',
'inquisitiveness', 'thing', 'spend', 'report', 'stay', 'remainder', 'lightship',
'perished', 'postholes', 'hypervelocity', 'enlist', 'investigator',
'condescend', 'asphaltic', 'incommensurate', 'imperfection', 'diver', 'inform',
'aspirate', 'interpreted', 'people', 'phenomenon', 'irrelevant', 'continence',
'gringo', 'cheat', 'computer', 'musical', 'graft', 'dam', 'extraversion',
'hypermarkets', 'midday', 'explain', 'drought', 'source', 'indiscriminate',
'unchaste', 'decorate', 'heraldist', 'exacerbated', 'prescriptions', 'physics',
'untrustworthy', 'plucked', 'tricolour', 'competition', 'promiscuous',
'devilish', 'impassively', 'speculate', 'preservation', 'reliable', 'entraps',
'lesson', 'amazings', 'assigned', 'connoting', 'sink', 'future', 'voice',
'hydrolysed', 'industry', 'titillated', 'tenured', 'pick', 'automate',
'medicate', 'indifferently', 'nonpublic', 'mccarthyism', 'ineffective',
'deserters', 'explorer', 'reviles', 'impulsion', 'potential', 'encamping',
'unarguable', 'interweaved', 'ringer', 'run-down', 'heiress', 'dishonest',
'hormone', 'clamorous', 'calculate', 'investigation', 'exempt', 'complain',
'demand', 'nonprofessional', 'devalue', 'support', 'price', 'reciprocal',
'holder', 'decay', 'monoclinic', 'sourdough', 'autoimmune', 'limit', 'pretense',
'hateful', 'separate', 'right', 'princedoms', 'significances', 'purposeless',
'give', 'intelligent', 'incongruous', 'proximity', 'wrongdoer', 'brandish',
'unfasten', 'auditive', 'preservers', 'medicine', 'suppleness', 'quieten',
'read', 'embroiderer', 'fieldworker', 'annoy', 'actuator', 'landscape',
'excrete', 'arbitrary', 'formations', 'suppress', 'aqueous', 'contest',
'inaccurate', 'indispensable', 'marathon', 'historically', 'subhead', 'trading',
'virility', 'insanity', 'inconsiderate', 'space', 'reformations',
'fragmentation', 'thick', 'contrastive', 'unsubdivided', 'inflection', 'code',
'interjection', 'obstruct', 'experimenter', 'observation', 'psychiatry',
'dimensional', 'boy', 'aluminum', 'separatist', 'psychologist', 'coupling',
'meaningless', 'londoners', 'grassland', 'rebel', 'nonrepresentational',
'century', 'Brazil', 'necessary', 'calmness', 'strangers', 'enlarger',
'predominance', 'hunt', 'meadows', 'intelligence', 'attempt', 'soloist',
'traverse', 'statistician', 'unequivocal', 'capitation', 'anticyclones', 'FBI',
'rubberstamp', 'confidence', 'mathematical', 'burn', 'frowning', 'adulteration',
'security', 'compartmentalization', 'rascality', 'vodka', 'together',
'aeronautical', 'antagonist', 'baseness', 'whizzed', 'construct',
'consequences', 'cosponsors', 'psychology', 'result', 'Israel', 'wisdom',
'piety', 'monoatomic', 'active', 'expressible', 'employable', 'industrialise',
'buy', 'bodily', 'cognizance', 'disprove', 'impartiality', 'unsexy',
'sternness', 'ravenous', 'sustainable', 'news', 'monocultures', 'carrier',
'machine', 'creation', 'lively', 'genre', 'lectureship', 'save', 'allergic',
'discipleship', 'internee', 'preserve', 'opalescence', 'hyperlink',
'decelerate', 'connectedness', 'disgruntle', 'cover', 'intracerebral',
'repositioned', 'repeating', 'reserve', 'subgroup', 'shanghai', 'autografts',
'protesters', 'nurturance', 'gravitated', 'tidings', 'interlinks', 'transfused',
'anaesthetics', 'misbehave', 'philanthropy', 'undissolved', 'crouch',
'hypothesis', 'venders', 'warrior', 'significant', 'wicked', 'sea',
'abbreviate', 'cemetery', 'past', 'implication', 'comport', 'settle',
'anarchist', 'proposition', 'autographic', 'chip', 'unionise', 'buggered',
'chooses', 'mimicked', 'coinsurance', 'convertible', 'conscripting',
'scheduled', 'corral', 'maker', 'sufferance', 'unicycle', 'presenters', 'allow',
'invite', 'arrangement', 'transfigure', 'confinements', 'frequency', 'voyage',
'control', 'angular', 'reprehensible', 'heartlessly', 'education', 'decoration',
'macroeconomists', 'refuels', 'reporters', 'point', 'practicality', 'empirical',
'breed', 'crystalline', 'unceremonious', 'hotness', 'sponge', 'please',
'trader', 'commingle', 'autoerotic', 'scarcity', 'mitigated', 'slacken',
'priest', 'encyclopaedic', 'assign', 'unmarried', 'team', 'deceiver',
'serenaded', 'interview', 'resigning', 'engineering', 'intramuscular', 'widen',
'circularize', 'dawn', 'stressor', 'homophobia', 'Jackson', 'short', 'validate',
'insecureness', 'consumer', 'energy', 'explicit', 'irrigate', 'astringe',
'smoothen', 'inanimate', 'delimitations', 'unconcerned', 'strength',
'pronunciation', 'wingless', 'credibility', 'loveless', 'coiled', 'immoveable',
'impurity', 'sensitivity', 'representable', 'discriminating', 'foreigners',
'intended', 'disabused', 'synoptic', 'lavishness', 'rite', 'baby', 'sailings',
'fleshiness', 'deconstruct', 'list', 'push', 'producing', 'assimilate',
'sidewinder', 'hardware', 'continuously', 'entreaty', 'probability',
'preordained', 'feline', 'wrongdoing', 'desertion', 'fixture', 'communicator',
'prideful', 'pious', 'normalise', 'cross-link', 'opposition', 'quarter',
'antonymous', 'skin', 'assessment', 'jewel', 'recovery', 'migrate',
'corespondent', 'office', 'discolor', 'cup', 'learn', 'administration', 'cost',
're-create', 'circle', 'status', 'doubt', 'credentials', 'communistic',
'rattlesnake', 'premise', 'request', 'enjoining', 'address', 'autofocus',
'refurbishment', 'clarify', 'palestinians', 'layer', 'state', 'ordinary',
'cuteness', 'roosters', 'foreigner', 'nanometer', 'negligence', 'airship',
'subspaces', 'drug', 'train', 'subdivided', 'librarianship', 'canker',
'knightly', 'momentousness', 'reprocessing', 'preliterate', 'omniscience',
'sincere', 'jazz', 'transfer', 'inch', 'helplessness', 'cognition', 'cosigned',
'shift', 'intensions', 'comfort', 'receiverships', 'schemer', 'indirect',
'contrabands', 'defeatist', 'exciting', 'molar', 'reproductive', 'treat',
'draw', 'comment', 'delay', 'ministry', 'generation', 'personnel', 'undefended',
'interrelationship', 'circumferential', 'tasty', 'intend', 'snookered',
'apologize', 'normalize', 'randomize', 'bunking', 'manslaughter', 'replication',
'consonant', 'fruit', 'bureaucrat', 'worker', 'high', 'fossil', 'territorials',
'microflora', 'intoxication', 'donate', 'blackmailed', 'polar', 'fingerprint',
'communication', 'departure', 'populate', 'waste', 'prospector', 'tripods',
'swan', 'inadvertence', 'string', 'iranian', 'ulcerate', 'cozy', 'architecture',
'early', 'balanced', 'record', 'out', 'improvise', 'lad', 'hankering', 'quote',
'enshrouded', 'call', 'purgatory', 'coerce', 'provincialism', 'pathfinder',
'contraries', 'disgorge', 'year', 'enforcements', 'established', 'associations',
'retrials', 'adhesion', 'involve', 'microbalance', 'political', 'irreligious',
'ceremonious', 'coefficient', 'asexual', 'tasteless', 'primacy', 'nonobservant',
'nerve', 'gibberish', 'interconnectedness', 'pathfinders', 'concerts', 'brown',
'airplane', 'register', 'maleness', 'self-discipline', 'shock', 'inference',
'dynastic', 'pilot', 'narrow-mindedness', 'untruth', 'install', 'monoplanes',
'wholeheartedness', 'faze', 'snickering', 'endangerment', 'closet',
'impermanent', 'benefactor', 'video', 'liability', 'chord', 'unapproachable',
'christianity', 'choke', 'mount', 'imply', 'acquiring', 'local',
'businessperson', 'conclusion', 'symbol', 'evil', 'oracle', 'diarrhea', 'bed',
'orientate', 'toxic', 'circumstances', 'gauge', 'reason', 'sex', 'reenact',
'absorbing', 'homoerotic', 'balminess', 'gathered', 'paper', 'deflowering',
'independently', 'irreverence', 'remakes', 'convergent', 'picket',
'electioneering', 'leisured', 'oppress', 'forceps', 'opera', 'constant',
'tolerable', 're-argue', 'department', 'persuasions', 'conscientious',
'communicativeness', 'morph', 'trilateral', 'loose', 'information',
'premeditation', 'spaciousness', 'emotionalism', 'rich', 'subdivide', 'bush',
'assistances', 'design', 'being', 'tend', 'library', 'suffer', 'lawyer',
'extractor', 'family', 'brittany', 'preheated', 'economic', 'hit', 'inelegance',
'attitude', 'kazakhstani', 'admit', 'dazzle', 'over', 'tricolours', 'summer',
'memorabilia', 'enroll', 'quarrel', 'passable', 'discontinuance', 'enliven',
'endorse', 'roller', 'deal', 'disembodied', 'tricycle', 'gain',
'incontrovertible', 'irresolution', 'ecclesiastic', 'operation', 'transvestite',
'canonize', 'brained', 'relates', 'tie', 'phosphate', 'successful', 'giant',
'paving', 'chairmanship', 'antifeminism', 'impossibilities', 'schnauzer',
'perspectives', 'exemplify', 'withhold', 'footballers', 'implement', 'tool',
'performing', 'incomprehension', 'sexless', 'antipsychotics', 'docile', 'knock',
'automates', 'population', 'combusted', 'dispersive', 'fiddled',
'intramolecular', 'commingled', 'spiciness', 'hard-and-fast', 'war',
'subroutines', 'preassembled', 'excommunicate', 'fly', 'locality', 'chemistry',
'bicycle', 'produce', 'trade', 'converse', 'hinduism', 'slaughterers',
'ashamed', 'discernment', 'soulfully', 'distinguish', 'removal', 'combustion',
'needleworker', 'portrayer', 'exclusive', 'relieve', 'territorial', 'bobbers',
'express', 'toss', 'whimsically', 'woman', 'plane', 'media', 'storm',
'researchers', 'physical', 'holy', 'adversely', 'teaspoonful', 'amusements',
'uninhibited', 'associate', 'greeting', 'juncture', 'embroiderers', 'vacations',
'agreement', 'agent', 'covered', 'individualist', 'concavity', 'wordless',
'immeasurable', 'hash', 'shout', 'noncivilized', 'determine', 'archive',
'legal', 'organization', 'garment', 'concerning', 'subsequences', 'subtend',
'spirited', 'workman', 'Palestinian', 'suggestible', 'condescended',
'conjurors', 'apply', 'accomplishments', 'flag', 'evangelistic', 'copulate',
'exist', 'separation', 'charge', 'boxing', 'formalisms', 'phone',
'objectifying', 'undatable', 'heading', 'monopolist', 'blend', 'photocopy',
'development', 'indelicate', 'immensely', 'filing', 'cylindric', 'sitting',
'writer', 'treatment', 'antagonize', 'inducted', 'loveable', 'shanked', 'plot',
'bench', 'magnetize', 'microfiche', 'decide', 'practicable', 'supply',
'intrude', 'place', 'compound', 'penetrate', 'acoustic', 'spiritless', 'stump',
'synthetical', 'break', 'bluejacket', 'clothes', 'periodical', 'winners',
'fording', 'advocate', 'range', 'unshaped', 'evangelicalism', 'transfuse',
'abstractionist', 'notebook', 'incurved', 'deity', 'same', 'instructorship',
'micrometer', 'rooster', 'parallelism', 'soccer', 'calcify', 'speculativeness',
'conformity', 'princedom', 'facilitation', 'discrete', 'admission',
'uncontroversial', 'irregardless', 'rampant', 'flim-flam', 'project',
'reelections', 'tenderize', 'craftsman', 'look', 'tripod', 'malfeasance',
'gaiety', 'up', 'unmentionable', 'florescence', 'contagious', 'sanctioned',
'destroy', 'regionalisms', 'honor', 'rededicated', 'strengthen', 'prompt',
'prolapse', 'extendible', 'expensiveness', 'work', 'circumnavigate',
'nominated', 'standardise', 'minister', 'formal', 'exterminated', 'angry',
'clinic', 'performer', 'wear', 'feudalism', 'calculation', 'hypermarket',
'potato', 'incorruptible', 'temptation', 'expert', 'amounted', 'outperforming',
'receiving', 'moisten', 'archery', 'expansion', 'satisfaction', 'meaning',
'remove', 'placement', 'convene', 'clients', 'receptions', 'liberation', 'wash',
'man', 'sprouting', 'clamor', 'apocalyptical', 'weather', 'entrapped',
'fictitiously', 'inapplicability', 'nazi', 'brother', 'hypertexts',
'sophisticate', 'standoffish', 'carefreeness', 'reconstructs', 'willingness',
'fashionable', 'defeat', 'article', 'encrust', 'tumble', 'OPEC', 'piquancy',
'unproductive', 'unite', 'marinate', 'teasingly', 'copilots', 'powerful',
'imperceptible', 'entwined', 'reclaim', 'virginals', 'providence', 'parameter',
'warmness', 'thunderstorm', 'masculinity', 'overlying', 'vanish', 'undress',
'sightedness', 'deface', 'disinflation', 'rediscovery', 'copying', 'category',
'top', 'apprenticeship', 'frivolously', 'customise', 'proceeding', 'concerto',
'comfortless', 'informative', 'drive', 'reporter', 'action', 'seize',
'vocalism', 'winking', 'criterion', 'type', 'uproariously', 'flood', 'round',
'exporters', 'reassuringly', 'congruity', 'economist', 'even', 'incoordination',
'transmutes', 'fighter', 'undisclosed', 'oppose', 'interviewing', 'comparing',
'logical', 'cultist', 'reorientate', 'matter', 'volatility', 'interstellar',
'psychic', 'gathering', 'riskless', 'disposition', 'sanskrit', 'bibliographies',
'cargo', 'planning', 'increasing', 'isolation', 'headship', 'essential',
'verbalize', 'suspenseful', 'covert', 'private', 'wreathe', 'competes',
'generalized', 'coast', 'unattainableness', 'discontinuous', 'embracement',
'detail', 'dollar', 'inquisitor', 'new', 'compatibility', 'slavic', 'voter',
'healthful', 'yodeling', 'reassessments', 'replaces', 'discoverys', 'church',
'ignorance', 'money', 'emulsifying', 'promised', 'interconnect', 'stamp',
'antisubmarine', 'constitutive', 'appearances', 'effected', 'dwarfish',
'scratch', 'relation', 'convict', 'relationship', 'destabilization',
'internationalisms', 'stimulation', 'slave', 'correspondence', 'eldership',
'macrocosmic', 'wanderers', 'microseconds', 'confide', 'objector',
'reservation', 'microorganism', 'amethysts', 'rompers', 'pregnancy', 'heavenly',
'allurement', 'excretion', 'discharged', 'inheritance', 'catalogued', 'brain',
'deprive', 'shore', 'reproduce', 'repress', 'relinquishment', 'colored',
'decompositions', 'cat', 'sensualist', 'prayerful', 'inflicted',
'preadolescent', 'thoughtless', 'absolute', 'greenly', 'repositions',
'nonverbally', 'baseball', 'trio', 'extrasensory', 'splashy', 'surprise',
'beverage', 'sorrowful', 'pour', 'arrival', 'analogize', 'newness', 'fast',
'number', 'elector', 'insertion', 'containership', 'unenthusiastic',
'absorbance', 'cuddle', 'experience', 'caliper', 'insubordinate', 'crosswise',
'interned', 'gluttonous', 'individual', 'preheating', 'dissatisfying',
'demureness', 'stock', 'density', 'disapproving', 'mayoralty', 'invariable',
'sulfide', 'scar', 'stormy', 'immoderate', 'surface', 'remarriage', 'caesarism',
'compose', 'admittance', 'registration', 'energized', 'chronologize',
'deployment', 'cowered', 'juvenile', 'considerable', 'challenge', 'compare',
'interrelate', 'plan', 'sterile', 'methodically', 'liverpools', 'originality',
'lordship', 'hilariously', 'aspect', 'attendance', 'deduce', 'regularize',
'beauty', 'remedy', 'extraordinary', 'unreal', 'person', 'seed', 'ablaze',
'chloride', 'graveyard', 'acceptable', 'scornful', 'worsen', 'form', 'thrust',
'manifestation', 'dead', 'idle', 'exploitive', 'spatiality', 'odorize',
'unconsciousness', 'bring', 'egg', 'globalise', 'imbedding', 'hypothetical',
'enfolding', 'bright', 'unfit', 'abashed', 'implantations', 'adjustor',
'optical', 'improver', 'senate', 'unforeseen', 'circumcision', 'supporters',
'syllable', 'propriety', 'young', 'excommunicated', 'democratize', 'gift',
'affordable', 'motion', 'insurrectionist', 'malicious', 'protractors',
'journal', 'belligerence', 'irrelevance', 'sanctify', 'seductive', 'ideality',
'punjabi', 'management', 'impregnate', 'predetermination', 'mercifulness',
'dependent', 'stove', 'flavourful', 'mark', 'airport', 'nonnative', 'curved',
'believe', 'observed', 'chemical', 'worthy', 'deregulating', 'mechanism',
'presuppose', 'unrealizable', 'disjoined', 'extrapolations', 'trilogies',
'subjugate', 'incised', 'wood', 'subarctic', 'Maradona', 'distrust',
'anterooms', 'mar', 'divided', 'transmuted', 'yen', 'smallish', 'inelasticity',
'distress', 'planners', 'proud', 'symbolist', 'parasitical', 'indecent',
'autoloading', 'griping', 'enunciated', 'trichloride', 'scholarships',
'flicker', 'part', 'dutch', 'card', 'nondescripts', 'act', 'awkward',
'transgress', 'portioned', 'decomposition', 'killer', 'revivalism', 'tense',
'inquirer', 'unconvincing', 'unvariedness', 'attackers', 'promotive',
'constrict', 'unwaveringly', 'comprehensible', 'affect', 'nonpartisan',
'composure', 'box', 'associational', 'clairvoyant', 'stimulates', 'corruptive',
'uncreative', 'irreproducible', 'locate', 'nobelist', 'ropewalker', 'cook',
'monarchist', 'brace', 'glistens', 'cooperator', 'retraced', 'laureate',
'reburial', 'lieutenant', 'conductive', 'repressing', 'protestantism',
'emergency', 'rematches', 'deceive', 'lustrate', 'discover', 'television',
'interchanging', 'dividend', 'institution', 'attractor', 'depressor',
'individualize', 'circumvolution', 'color-blind', 'acoustical', 'requirement',
'homophony', 'constellation', 'religion', 'braid', 'incomprehensible',
'sulfuric', 'pastorship', 'canonical', 'slurred', 'annihilator', 'concurrence',
'severer', 'swooshing', 'enthusiast', 'syphons', 'nominate', 'bestowals',
'safe', 'spoonful', 'personify', 'seven', 'transmissible', 'valorous',
'scarceness', 'sponsorship', 'microcomputers', 'procreating', 'continuous',
'antecedent', 'hear', 'decrease', 'disease', 'extroversive', 'laundering',
'subjoined', 'translocation', 'wallpapered', 'impartial', 'flaunt',
'sanctifying', 'monsignori', 'nosiness', 'equatorial', 'rarity', 'hungry',
'dull', 'followed', 'rid', 'procedure', 'isolate', 'written', 'sociability',
'purchasable', 'applaud', 'removes', 'oust', 'returning', 'regularise',
'nature', 'copartnership', 'prejudice', 'consultive', 'president', 'divisible',
'water', 'smart', 'postmarks', 'independent', 'chatter', 'commenting',
'totalism', 'strains', 'governor', 'nonstandard', 'grievous', 'fancy',
'lobster', 'roadless', 'expound', 'incombustible', 'country', 'soulless',
'procurator', 'spiritize', 'plague', 'pedicab', 'arousal', 'univocal',
'inflame', 'conditional', 'autoimmunity', 'float', 'autopilots', 'blacken',
'torment', 'postcodes', 'gumption', 'addiction', 'bohemia', 'postboxes',
'activity', 'crew', 'unambiguous', 'superficial', 'disturbance', 'disfigure',
'inarticulate', 'girl', 'raise', 'born', 'copilot', 'steal', 'luxury',
'exceptionally', 'hyperlinks', 'indian', 'pittance'}

# %% [markdown]
# ### get the reduced embedding file

# %%
def get_reduced_embedding(embed_path, output_path):
# filename = "reduced_embedding_4.txt"

    outfile = open(output_path, 'w')

    for row in open(embed_path):

        word, *_ = row.split()

        if word in words:
            outfile.write(row)
    outfile.close()

# %%
get_reduced_embedding("embedding_4.txt", "reduced_embedding_4.txt")

# %% [markdown]
# ### test set similarity generation

# %%
import sys
def test_similarity_geneartion(embed_path, output_path):
    def preprocess_word(s):
            s1 = s.lower()
            s1 = re.sub(RE_STRIP_SPECIAL_CHARS, '', s1)
            s1 = re.sub(RE_NUMBER, ' ', s1)
            s1 = s1.strip()
            if s1 in stop_words:
                s1 = ''
            else: 
                s1 = s1.strip()
            return s1
    def read_embedding(path):


        embedding = {}
        dim = None

        for row in open(path):

            word, *vector = row.split()
            try:
                embedding[word] = [float(x) for x in vector]
            except:
                continue

            if dim and len(vector) != dim:

                print("Inconsistent embedding dimensions!", file = sys.stderr)
                sys.exit(1)

            dim = len(vector)

        return embedding, dim


    E, dim = read_embedding(embed_path)
    pairs = pd.read_csv("data/similarity/test_x.csv", index_col = "id")
    cal_similarity = []
    for w1, w2 in zip(pairs.word1, pairs.word2):
        #process the w1,w2 like we did previously to the raw text
        w1 = preprocess_word(w1)
        w2 = preprocess_word(w2)

        if w1 not in E.keys():
            cur1 = '<UNK>'
        else:
            cur1 = w1
        if w2 not in E.keys():
            cur2 = '<UNK>'
        else:
            cur2 = w2
        cal_similarity.append(np.dot(E[cur1], E[cur2]))
    pairs["similarity"] = cal_similarity
    del pairs["word1"], pairs["word2"]
    pairs.to_csv(output_path)

# %%
test_similarity_geneartion("embedding_4.txt", "results/test_prediction_4.csv")

# %% [markdown]
# ## dealing with unknown words

# %%
from argparse import ArgumentParser
import nltk
from nltk.corpus import wordnet as wn
from nltk.stem import PorterStemmer
nltk.download('wordnet')

def manual_stem(word):
    if word[-2:] == 'ly':
        return word[:-2]
    elif word[-3:] == 'ish':
        return word[:-3]
    else:
        return None


added_words = []
vocab = {}
unk_vector = ""

for row in open("embedding_3.txt"):

    word, *vec = row.split()
    vocab[word] = ' '.join(vec)

    if word in words:
        print(row, end = "")
        added_words.append(word)
    elif word == '<UNK>':
        unk_vector = row

counta = 0
countb = 0
countc = 0
countd = 0
counte = 0
countz = 0
ps = PorterStemmer()
filename = "modified_reduced_embedding_3.txt"

outfile = open(filename, 'w')



for w in words:
    if w not in added_words:
        vec = None
        # print(f'{w} not in vocab')
        found = False

        # find stemmed word in vocab
        stemmed_word = ps.stem(w)
        if stemmed_word in vocab:
            vec = w + ' ' + vocab[stemmed_word] + '\n'
            # print(f'!!found stemmed {word}')
            found = True
            countd += 1
        
        manual_stemmed_word = manual_stem(w)
        if manual_stemmed_word and manual_stemmed_word in vocab:
            vec = w + ' ' + vocab[manual_stemmed_word] + '\n'
            # print(f'!!found manually stemmed {manual_stemmed_word} for {w}')
            found = True
            countd += 1

        # find synonyms in vocab
        synonyms = wn.synsets(w)
        stemmed_synonyms = wn.synsets(stemmed_word)
        addl_stemmed_synonyms = []
        if manual_stemmed_word:
            addl_stemmed_synonyms = wn.synsets(manual_stemmed_word)
        synonyms += stemmed_synonyms + addl_stemmed_synonyms
        if not found:
            for synonym in synonyms:
                word = synonym.lemmas()[0].name()
                if word in vocab:
                    vec = w + ' ' + vocab[word] + '\n'
                    # print(f'!!found syn {word}')
                    found = True
                    counta += 1
                    break
        
        # find 1st level hyponyms of all synonyms
        if not found:
            for synonym in synonyms:    
                hyponyms = synonym.hyponyms()
                for hyponym in hyponyms:
                    hyponym_word = hyponym.lemmas()[0].name()
                    if hyponym_word in vocab:
                        vec = w + ' ' + vocab[hyponym_word] + '\n'
                        # print(f'!!found 1st level hyponym {hyponym_word}')
                        found = True
                        countb += 1
                        break
        
        # find 1st level hypernyms of all synonyms
        if not found:
            for synonym in synonyms:
                hypernyms = synonym.hypernyms()
                for hypernym in hypernyms:
                    hypernym_word = hypernym.lemmas()[0].name()
                    if hypernym_word in vocab:
                        vec = w + ' ' + vocab[hypernym_word] + '\n'
                        # print(f'!!found 1st level hypernym {hypernym_word}')
                        found = True
                        countc += 1
                        break
        
        # find all hyponyms recursively, for all synonyms
        if not found:
            for synonym in synonyms:
                all_hyponyms = [w for s in synonym.closure(lambda s:s.hyponyms()) for w in s.lemma_names()]
                for hyponym_word in all_hyponyms:
                    stemmed_word = ps.stem(hyponym_word)
                    if hyponym_word in vocab:
                        vec = w + ' ' + vocab[hyponym_word] + '\n'
                        # print(f'!!found hyponym {hyponym_word} for {w}')
                        found = True
                        countb += 1
                        break
                    elif stemmed_word in vocab:
                        vec = w + ' ' + vocab[stemmed_word] + '\n'
                        # print(f'!!found hyponym {stemmed_word} for {w}')
                        found = True
                        countb += 1
                        break

        # find all hypernyms recursively, for all synonyms
        if not found:
            for synonym in synonyms:
                all_hypernyms = [w for s in synonym.closure(lambda s:s.hypernyms()) for w in s.lemma_names()]
                for hypernym_word in all_hypernyms:
                    stemmed_word = ps.stem(hypernym_word)
                    if hypernym_word in vocab:
                        vec = w + ' ' + vocab[hypernym_word] + '\n'
                        # print(f'!!found hypernym {hypernym_word} for {w}')
                        found = True
                        countc += 1
                        break 
                    elif stemmed_word in vocab:
                        vec = w + ' ' + vocab[stemmed_word] + '\n'
                        # print(f'!!found hypernym {stemmed_word} for {w}')
                        found = True
                        countc += 1
                        break
    
        if not found:
            for synonym in synonyms:
                antonyms = synonym.lemmas()[0].antonyms()
                for antonym in antonyms:
                    antonym_word = antonym.name()
                    stemmed_word = ps.stem(antonym_word)
                    if antonym_word in vocab:
                        vec = w + ' ' + vocab[antonym_word] + '\n'
                        found = True
                        countz += 1
                        break
                    elif stemmed_word in vocab:
                        vec = w + ' ' + vocab[stemmed_word] + '\n'
                        found = True
                        countz += 1
                        break
                        

        if not found:
            vec = w + unk_vector[5:] + ''
            counte += 1
        outfile.write(vec)
outfile.close()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/yuxinzhang/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# blackmailed 0.5159319 -1.0157686 -0.4138661 0.2731767 0.5695822 1.4408952 0.107705705 0.44747534 0.62479496 -1.3837435 -0.87625295 0.11330099 0.3022902 -0.19215499 -0.46355224 -0.57833844 -0.22103654 0.32899398 -0.29066238 1.2680197 0.6860633 -0.25759414 -0.57290787 -0.4023823 -0.3397179 -0.19929418 0.666399 0.46441212 -0.16408618 -0.23075412 -0.6541861 0.7611803 0.22740805 0.5591832 -1.3969213 -0.84511894 0.80114913 1.0374118 0.74116546 0.16888918 0.63308483 0.31543684 0.47564372 0.63882965 0.07255144 -0.13334197 0.910876 -0.19073436 -1.0772332 -0.06172043 0.4021403 1.0566512 0.72916204 -0.83291006 -0.5096141 0.54617685 0.40822953 -0.64650166 -0.3381973 0.191883 -0.45311862 0.8950991 0.25362924 -0.41472295 0.09999568 -0.42301154 -0.8713409 0.89266014 -0.6710341 0.048123345 -0.7232793 -0.25738043 -0.44469082 -0.13616395 -0.43198347 0.72001857 -0.68762386 -0.01296525 1.0663222 0.99702793 -0.10473941 0.8741657 0.6884531 -0.57924074 -0.00076101045 -0.21412663 0.37063107 -0.007982731 0.50107837 0.25672644 -1.0105712 0.6884224 0.5855978 0.51585305 0.7758355 0.7358249 0.36482552 0.017004173 -1.133742 -0.6171798 -0.25303328 -0.3285897 0.6794246 -0.9069351 -0.84382725 -0.28462204 0.65471476 0.27743596 -0.02502387 -0.4753592 -0.21671183 1.635215 0.1525397 0.27741054 0.28390232 0.4622844 -0.8173083 -0.18496916 -0.454545 -0.4026347 0.037524294 -0.9849861 0.15419368 0.3736836 0.98893154 -0.43382013 -0.5672561 0.031149367 0.47644144 -0.5772857 0.29327378 -0.14906733 0.5930851 -0.21907629 0.37467507 0.124801666 0.4766878 0.16683774 0.675398 -1.1270078 -0.010580954 -0.33702928 -0.3584124 -0.39902398 -0.17668913 -0.3627004 0.8433136 -0.24227485 1.3415004 -0.3205621 0.47520155 0.25983676 0.25766245 0.609323 -0.726103 0.85620856 -0.76268435 -0.069101766 0.29614416 0.8275241 -0.43238556 -0.5538888 0.14317666 -0.34147894 -0.72136706 0.940052 0.01350355 -0.10663717 -0.0049012806 0.9365224 0.35589743 0.087063044 -0.17546852 -1.0170406 0.38959873 -0.9360138 -0.68472785 0.89143157 1.0632981 0.21321978 -0.29237357 -0.37688005 0.8792476 0.71263653 0.27976006 0.23274958 -0.85617113 0.03624758 0.61505854 0.20128876 0.2955088 1.013602 -0.5235305 1.1844267 -0.6294546 0.13367857 -0.35097757 0.6082579 -0.2165578 -0.36863202
# extrapolations 0.8562192 0.5677133 -0.49351755 -0.48518807 1.2752832 -0.5320311 -0.81094295 -0.54059154 0.24808921 -1.3849854 -0.10144958 0.8261554 -0.18065903 0.26312357 0.8204188 -0.90538406 0.0007980129 0.67109203 -0.81601876 -0.19434448 0.6244204 -0.2064682 0.348155 -0.1871138 0.27005985 0.36855525 0.21294956 0.4140444 -0.32012033 -0.4366839 -0.17783254 0.9626592 0.34890294 -0.42605844 0.23427081 -0.10614684 -0.083156444 -0.30046615 0.18132962 0.0062013227 1.0168862 0.17357282 -0.09921319 -0.44623774 0.54066026 -0.62653744 -0.15980285 0.8509221 0.19296597 -0.5336453 0.9108576 0.597352 0.33116087 0.61764026 0.17597254 -0.10620343 -0.089019775 -0.108977996 -0.21506803 -0.3001163 -0.5328891 -0.2891752 -0.101758294 0.4344373 0.6292243 0.29597104 0.092248455 -0.42623904 0.61516315 0.8252595 0.14019777 0.15668923 0.23906559 0.062621735 -0.54021436 -0.33767253 -1.1548656 -0.054401174 -0.029219147 1.2705803 -0.8520252 0.13657664 -0.29381135 -1.3135915 -0.46033493 -0.83483845 -0.044779547 0.32729444 0.6169495 1.4298549 0.30294806 1.4211713 1.1440812 -0.09038949 -0.28110087 -1.0665606 -0.73742276 -0.49237105 -0.17359324 0.06923889 -0.0011483426 -0.8791001 0.22562216 -0.43371147 -0.5953423 0.61529636 -0.74728703 -0.64849335 -0.0056813946 -0.4104498 0.57768387 0.8330139 -0.2762031 1.2712516 0.92989534 1.059404 0.3900994 0.9877178 0.47452655 -0.38233793 -0.29515415 -0.028040515 1.1547495 -0.0039523193 0.18470542 0.45422652 -0.24397336 -0.49880052 0.60373926 0.02506422 0.06867167 0.1780412 -0.64101666 0.56813526 0.6890339 0.51840377 -0.9221488 0.0909465 -1.170268 0.5765992 -0.19722979 -0.33914804 0.38659146 -0.20949005 -0.13741033 0.40780026 1.4030424 0.012161173 0.6851674 -1.0537748 -0.18251841 0.95146066 1.1477038 -0.6836319 0.6133862 -0.55236936 -0.39747524 -0.5980672 0.64943457 -1.1326289 -1.0558287 -0.31934398 -0.99495083 -0.6342344 -0.6725274 0.5474668 -0.58712053 0.5678658 -0.14660695 -0.5634291 0.39300054 -0.2415867 -0.6566612 0.04305213 -0.21327202 -0.905222 -0.47413358 -0.3213797 -0.5910194 -0.9063488 -0.50604 -0.594501 0.17167228 0.85622436 0.014188589 -1.0269107 -0.84110785 1.1137365 -0.2567155 0.21540159 0.0043937005 1.2314415 -0.5600107 0.7430074 -0.49955076 -0.38873997 -0.6946195 0.75185156 -0.061295085 0.046329435
# admittance -0.6818222 0.44670358 0.2238721 -0.36385006 0.39063683 0.23847255 -0.46827465 0.69879746 1.004928 0.089308694 -0.6617966 0.80476856 0.466684 -0.8300404 1.1415908 0.8183266 -1.5505164 -0.36203405 0.6524475 -0.20167339 -0.59974366 -0.77953696 0.060934186 -0.6489248 -0.2130519 0.58386713 -0.05391571 0.30977413 -0.42531487 0.5175671 -0.33405545 1.0687195 0.8764059 -0.14552921 0.6349755 0.74244314 0.25945535 -0.5148902 0.3197413 -0.50236857 0.73426855 0.08367601 0.29475212 -0.6673955 0.42547393 -0.2981018 0.47680783 -0.53477836 -0.7671964 -0.8456844 -0.24184108 0.57754445 0.40559274 0.34069735 -0.26977018 -0.14179821 0.12063184 -0.1818805 0.53177106 0.12559737 -1.2401152 0.41615146 -0.095848866 -0.088148035 0.6721448 0.061988756 -0.13005692 0.22300099 -0.22020203 -0.38136283 1.0100667 0.9053183 0.10895443 -0.104747824 -1.1107175 -0.66135544 0.37376586 -0.7895719 0.49221224 -0.18298745 -1.0639124 1.046649 1.0592844 -0.3357376 0.096500225 -0.18564852 0.52326584 -0.18874756 -0.337922 0.53109604 -0.607453 -0.04880041 -0.45807222 1.191003 0.30747107 -0.64297146 -0.5225495 -0.3901306 0.16845378 -0.3715942 0.13387783 -0.19168185 0.26015133 -1.0844145 -0.89680004 -0.93436015 -0.50150424 -0.9083818 -0.8721832 -0.666212 0.08772268 1.182794 0.7877626 0.578953 0.2151496 -0.97794455 -0.11439753 -0.24068369 1.2063962 -0.32578424 0.9461135 0.34385222 -0.050005067 -0.6794036 1.06189 -0.79535514 -0.073331386 0.5951977 0.7089 -0.8059749 -0.05616044 -0.09100018 0.10887661 0.07089451 -0.3070169 -1.0174582 -0.70799756 -0.025568437 0.28854978 -0.07706651 -1.3995514 -0.001824929 0.80441684 -0.26419774 0.10535806 -0.64713585 -0.49152723 0.51864725 0.0043543936 -0.87843347 0.27046925 1.2085245 -0.1954637 -0.36903632 -0.99018574 0.18864681 -0.32425952 -0.57304364 -0.45838228 0.054306556 0.5079903 0.13821597 -0.3568506 0.3897994 -0.7987427 0.77867824 -0.73180085 -0.04799664 0.17162012 0.7355539 -0.50467354 -0.42211935 -0.20710649 -0.78833145 -0.47479498 -0.5995868 -0.15677904 0.7819745 -0.06649932 0.4792386 -0.5975984 -0.15195344 -0.34663355 -0.23310629 1.2243314 0.86110944 -0.5835586 1.2383226 -0.3770989 0.15128495 -0.7822032 -0.39773452 0.60989416 0.4035082 -1.2361809 0.1026039 -0.55523914 0.21875033 -0.054414965 -0.37454972
# sterile 1.1506326 0.2264153 -0.84815663 -0.8768476 -0.9361809 0.56078964 -0.6918586 0.87444574 -0.3067403 -1.1520832 -0.50325793 -0.04585288 0.6288551 -0.81445545 0.5288782 -0.04565162 -0.7283667 0.24576564 0.41492587 -0.09669309 -0.7457234 0.6654123 -0.3549424 -0.5739128 -0.060914714 0.46132272 0.3481193 -0.303923 -0.23448089 -0.1437737 0.49029455 0.9405759 0.8689878 0.55770516 -0.21745388 0.045117922 -0.9407738 0.60399956 -0.40933645 0.774119 -0.08128749 0.108591616 0.45760125 0.45592856 -0.8831701 -1.6504836 0.17545033 -0.4152408 -1.6485015 -0.022821823 -0.23308237 0.22858931 -0.29001927 0.3592819 1.3711953 0.7385946 -0.89597803 0.547211 0.6909952 0.61834127 0.5228143 0.16672866 -0.73168415 -0.8168829 0.11521585 -0.26657745 -0.26124144 -0.2673998 0.32452804 -0.19931583 0.6291869 0.14979468 0.19515789 0.3369082 -0.51374906 0.38844228 0.6698828 -0.19361049 0.5537577 0.4912348 -0.11507229 0.8428778 0.8183193 -0.2910423 -1.4435198 0.669544 -0.077802226 -1.2402219 -0.7661536 1.0194535 0.1391402 0.056438155 0.5298572 -0.25304523 -0.70447856 -0.41750696 1.5948356 -0.18647182 0.732411 -0.21125135 0.11736208 0.038472623 1.0750257 -0.8032751 0.17652737 1.5441478 -0.6067227 1.4934386 0.41761872 0.63013095 0.8779413 0.43892637 1.7962573 0.78331393 0.13156381 0.26340985 -0.7332746 0.5763904 -0.6565985 -0.64185166 1.132462 0.66484934 0.8517415 -1.150262 0.18833815 -0.103269264 0.57677233 -1.1197445 1.4003437 0.75024545 0.7428139 -0.19788769 0.19463761 -0.5729053 -0.075123556 0.33877847 -0.5129786 -0.6315616 -0.66059226 0.04035465 0.062601365 -0.63162756 -0.100931816 -0.5597354 0.111784235 0.48014542 1.2237834 1.29683 0.638885 -0.101845704 0.37112555 -0.051527083 0.5024917 0.14574268 -0.28621945 -0.288334 -0.58063406 -0.029136093 0.90856004 0.5612242 -0.013448784 0.45885727 -0.8640188 0.78999656 0.52717495 -0.17675164 0.8200188 0.426305 -0.0640253 0.8702146 -0.35370824 0.030018993 -0.73681384 -0.8399611 0.48967966 -0.24076878 0.1145711 -0.13235922 0.38437706 -0.44776976 -0.20912932 -0.09614848 0.91500556 -0.29166186 0.02597841 -0.40818393 -0.8118334 0.6198806 0.9564753 0.2759942 -0.09742084 0.16144294 -0.5545222 -0.3603168 -0.23181446 -0.34043 -0.36075205 -0.06539998 0.8402511 0.02797885
# counterfeit -0.5105044 0.15433648 -0.5799147 -1.0955251 1.43135 -0.97028 0.4547638 0.23507263 0.020487716 -0.5930604 -0.6106012 0.20565376 -0.2739965 0.0476428 -0.070757 -0.37611702 -0.005928277 -1.4991585 0.1955914 -0.049346175 0.6847885 -0.83741283 0.53983915 -0.21539354 0.45923397 0.54323924 0.34543943 0.46617404 0.21003735 0.50762105 1.077949 0.14543284 -1.3633846 0.49290895 -0.33494765 -1.0266111 -0.7685535 0.44997323 -0.018191889 0.636234 0.021665215 0.66712 -0.45956475 -0.68689686 1.1196458 -0.63109595 -0.4270547 -0.63003695 -0.6422591 -0.32895878 -0.07816101 0.504558 -0.4355194 -0.71993387 -0.9039685 -0.43945462 0.63556355 0.31695682 -0.43823665 0.31675667 -0.22148919 -0.26249802 -0.053839862 -0.29776895 -0.6381312 -0.37078455 0.31780112 -0.39687032 -0.28240356 0.5370512 1.0020745 -0.12800425 0.65908206 0.5380685 -0.25547338 0.11191448 -0.20963904 -0.3788481 -0.24592614 1.1685675 0.7320109 0.78312045 -0.6388155 0.06892367 -0.20228583 -0.6312715 0.80310625 0.3140536 -0.074815705 -0.063358925 1.0568521 0.56591135 -0.30090493 -0.6593822 1.0418106 0.23120564 0.7176185 0.15364133 0.02646134 -0.23762757 -0.40564543 0.89033777 0.60722077 0.049919166 -0.44364923 -0.30901498 0.67119455 -1.104299 0.6829911 -0.30309594 -0.23687035 0.8667759 -0.32553545 -0.68193734 0.06750397 -0.15890938 0.3238665 -0.13495825 -0.30281663 -0.31772402 1.3036046 0.5966232 -0.032695435 -0.19805892 1.041189 -0.12406266 0.56524175 0.5657847 -0.33955514 0.75084734 0.47002873 1.8792188 0.21712492 -0.010373233 -0.84296185 0.8220954 -0.8626007 -1.3345416 -0.13968264 -0.71890277 0.4378089 -0.18542162 0.40479454 -0.21351737 0.6152392 0.8290001 0.9436669 -0.84779495 0.026280914 -0.61475575 0.28523606 -0.5131108 0.04436062 -0.29699212 1.4943602 -0.097871535 -1.06622 -1.4253756 0.19100073 0.31421733 -0.031448096 -1.0446527 0.20034966 -0.038149215 -0.44722456 0.27725467 -0.53443164 0.08607238 0.56892145 0.07153715 1.149904 -0.18097082 0.22616377 -0.18429478 0.57929593 0.25936052 0.08587305 -0.86394167 0.32099205 0.29128686 -0.8461336 -0.871103 0.76159865 -0.23297861 -0.21713014 -0.67579037 -0.70386446 0.5882594 0.41242063 0.040996127 0.9531866 -0.040348742 -0.5261491 -0.05711736 -1.077382 0.35546482 0.00963935 0.1406671 -0.27591357 0.39845777
# ship -0.24082687 0.03788042 -0.80642885 -0.38033327 0.41812155 -0.5123256 -0.24447581 -0.16959223 -0.36090344 -0.971332 0.3731541 0.5746178 -0.8194282 -0.300915 0.09099729 0.047229692 -0.14209493 -0.2968701 0.3443972 0.12717117 -0.10764605 -0.70059985 0.25509587 -0.5169623 -0.20830898 0.7364613 0.14840075 0.6344145 -0.26462093 -0.16850701 0.30170402 -0.25903186 -0.25860378 -0.3056613 0.078861885 -0.74086034 -0.0053856405 0.04019603 0.44678754 0.47988838 0.70946485 -0.30284438 -0.2773269 0.48774537 0.31669056 -0.5076123 0.2916475 -0.59410906 -0.45700535 -0.63607144 -0.24516547 1.6100501 -0.7021902 -0.41058075 0.33407444 0.040301364 0.22963358 0.29292333 0.7651607 -0.5901505 0.25629494 -0.6248742 -0.11212014 0.3351673 -0.37600476 0.5764643 0.46822608 0.65619004 0.19049765 0.59094876 0.30673236 0.47812942 -0.3946392 0.57272273 -0.6682236 -0.12225823 -0.3174738 0.39248246 -0.041315142 0.3307907 -0.04428605 -0.9768178 0.43275273 -0.11842241 0.5455708 0.60426253 0.22793005 -0.5547216 -0.058025084 0.41908315 1.1632732 -0.24407803 -0.032678556 0.4187614 0.36772138 -0.14706168 -0.29205543 0.32353032 0.23869535 -0.079655245 0.013616695 0.62955743 0.109530926 0.15270182 -0.31564233 -0.4809383 0.55435526 1.0138189 0.6051228 -0.028458219 0.5042977 -0.06493834 0.26596507 0.008356572 0.46368298 0.15896626 -0.09301329 -0.123886 -0.26484334 0.24114719 0.9022974 -0.049751006 -0.28573143 -0.6585958 0.8971854 -0.4763738 0.19589268 0.076609224 0.55836946 0.51762414 0.40067664 0.028363973 -0.1059211 0.7229981 -0.49967247 0.06410834 0.47462004 -0.56241626 -0.35400334 -0.6238712 0.17869107 -0.6530202 -0.092317194 -0.10453067 -0.020117143 -0.032087415 0.3678313 -0.24168347 0.77863437 -0.3408633 0.067729145 -0.24281858 -1.4048531 -0.33339593 -0.14568038 0.24978864 0.14444286 -0.395118 0.3713184 -0.48881084 -0.112157725 -0.2725251 -0.054474156 0.47400686 -0.2701839 -0.40124205 0.6021317 -0.32675797 0.7004411 -0.3070752 -0.4207478 -0.3662076 -0.64428794 -0.41508853 -0.23996364 -0.14055453 0.46761298 -0.23813494 0.38675904 -0.16476649 -0.18053475 -0.2912799 0.09521761 -0.4337281 0.48852137 0.139288 -0.35622194 0.59554034 0.09276693 0.15660712 -0.54507446 0.85837847 -0.23877938 0.44627726 -0.26844472 -0.7120142 -0.51977354 -0.28428456 0.79630655 -0.055915337
# enlist 0.25440443 -0.10505265 -1.0698397 -0.8157775 0.4671353 -0.105869345 -0.10608906 0.2727147 0.19155176 -0.2402189 0.05380944 -0.18801731 -0.790811 -0.1588237 0.2713269 -0.56878453 -0.7797199 0.44924787 0.20721485 0.49088374 -0.1648949 0.43784022 0.3886383 0.045023553 -0.35404786 0.055138636 0.9567442 0.02978892 0.055168726 -0.8912039 0.5743734 0.50402784 0.15503831 -0.40525186 -0.40040937 -0.5187014 0.7100855 -1.1490918 -0.7216803 0.72500485 0.08213078 -0.5375099 0.6627894 0.6758649 0.66972846 -0.96192944 0.6237342 0.5660361 -1.1418191 -0.1242342 -0.29309785 0.4272249 0.009670828 -0.93285096 -0.46684268 0.28651568 0.13202232 -0.7678082 -0.55915993 -0.5328454 -1.3274697 -0.13804832 -0.6015016 -0.96918553 -0.95783246 0.20991614 0.8715645 0.90740764 -0.3759173 -0.12554136 0.20148095 0.23306614 -0.5337496 -0.74325645 0.14960028 0.30496576 0.16277957 0.72635436 -0.17461751 -0.12603104 -0.17752959 0.82081985 0.3792344 -0.6553261 -0.31694102 -0.78139573 -0.2356482 0.47227925 -0.23314355 -0.09890367 0.59742916 0.027073791 0.32598886 -0.32499623 0.26012266 -0.34867758 0.84827965 0.11119403 -0.12707865 0.16128394 0.36756775 -0.2729531 0.39204696 -0.51301104 0.53362715 -0.37270752 0.016056912 -0.9130709 -0.19157365 -0.10642179 -0.6162094 0.6979532 0.4818258 0.4915932 0.12775744 0.8901722 -0.27680326 -0.99025524 0.70390743 -0.63466877 0.8520827 0.17031564 0.37230146 0.1359853 0.8813496 0.9904529 0.21736334 0.21880512 -0.26644152 0.32057324 0.5751253 1.6551906 -0.3697845 0.5697905 -1.1214373 -0.19960521 -0.57075083 -0.19148937 -0.3497573 -0.43020278 -0.4185446 0.42036688 0.057638444 -0.38826507 0.24529965 -0.25068614 0.2903342 -0.9918681 0.73819226 0.19467668 -0.068182915 -0.018389387 -0.082923256 0.098832294 -0.7284882 0.054516654 0.22795156 -0.5024084 -1.283468 -0.64627093 -0.54065824 0.8672697 0.1479319 -0.24212287 -0.5245318 0.15780635 0.20944946 -0.6023304 0.3091221 -0.34678027 0.37127978 -0.17773865 -0.3075214 -0.1711525 -0.47028384 -0.2516628 -0.13666502 0.39769682 -0.16582897 -0.3884067 -1.034922 0.32872233 0.010335704 0.5432789 0.8641273 -0.4374707 -0.038784493 0.71820754 0.36491564 -0.02462716 -0.18357602 0.7692879 -0.2827282 0.5173902 -0.18645245 -0.7055918 -0.37796083 0.78967136 -0.5899875 -0.4584598
# undetectable 0.057045672 0.12769468 -0.5642553 -1.234544 0.08610153 0.044748258 0.13640004 0.18410952 0.5371219 -0.79001445 -0.7570416 -0.5379838 0.6503511 0.5857992 0.12442795 0.6918272 -0.87791413 0.22667745 0.9742505 0.17160012 0.39147052 0.35044667 -0.1863656 0.1512882 0.0040751463 0.87722665 0.7615108 0.65877026 0.8057387 0.58711433 0.865964 -0.6866993 -0.37621212 0.3660664 -0.33107492 -1.9521956 0.39527422 -0.07019277 0.040133476 0.8939489 0.4851204 0.5756679 -0.39752695 -0.03833926 0.95259017 0.49808136 1.1768216 0.7404913 -0.9761819 0.22245471 0.28343496 0.6031176 0.46898347 -1.0572361 0.88080865 0.07430611 -0.21782035 -0.9870808 -0.8317649 -0.99291253 -0.7087506 -0.093694285 0.050330315 0.24530195 -0.9037208 0.98254144 0.4698353 1.0698892 -0.2082905 0.026776504 0.45512915 -0.012678582 0.68787205 -0.41423342 -1.1112273 0.33179158 -0.47173566 -0.04843844 -0.063457675 0.03717161 -0.25539547 0.4685822 0.2876326 -0.83903134 0.24309722 -0.028059738 -0.07384517 -0.30108804 0.3910013 0.75752157 0.31203198 1.1488562 0.434356 -0.81956375 0.20326456 0.8200493 -0.3153683 0.15561394 -0.42464757 -0.8258529 0.3855573 -0.9063728 0.8839291 -0.06975757 0.38750806 -0.21265823 0.05056472 -0.3795092 -1.0793005 -0.62086344 -0.2715318 0.9210396 1.1001161 -0.45211905 -0.009576749 0.50926 0.3997076 0.17374519 0.5859637 -1.0010309 0.30041927 -0.09979393 0.519206 -0.4834074 -0.48181406 0.15365905 -0.26643017 0.70305234 -0.24602292 0.26948515 0.04152655 0.42193696 0.29639104 0.06977183 0.21471073 -0.291605 0.015644757 -0.51704097 0.62133557 0.061347865 0.22945505 -0.65346473 2.1052487 -0.052747462 -1.5974756 0.08545464 -0.4896477 -0.33656043 0.67472214 -0.22644886 0.29637364 -0.03239709 -0.3205146 0.7331068 -0.007351066 -0.110611536 -0.836783 -0.36461127 -0.3237811 -0.7711536 -1.0802883 -0.8989703 0.1258283 -0.5249497 -0.24033056 0.630467 0.89138854 0.81187695 -0.092543714 0.14697815 0.2437566 0.3189624 -0.9103861 -0.799428 -0.45343956 -0.62025076 0.3916435 -0.52541023 1.0339565 0.46494645 0.04591346 0.27169788 1.0181128 -0.5135489 -0.7986712 -0.35585445 -0.20570746 0.70608073 0.75880265 -0.69125 0.86642796 0.5507479 -1.0155828 0.5636178 -0.03857905 -0.56942236 -0.56182295 -0.21218625 -1.1209508 -0.5701713
# imperils 0.32633403 -0.084250815 0.73792344 -0.38442028 1.1527925 -0.33052182 0.87144774 0.12918611 0.40765172 -0.91750693 -0.4153537 -0.39309156 0.7621264 0.33009946 0.4412775 0.4832493 0.47398815 -0.21758784 -0.19954161 -0.1480747 -1.1153615 0.3192815 -0.27266183 -0.45587286 0.14657445 0.9787351 0.14475057 0.43713596 0.017078197 1.0558392 0.9314695 0.63410383 0.08815619 -0.14286458 0.0708112 -0.054904174 -0.38205078 0.89973164 0.36129266 -0.3576113 -0.24378812 -0.3141392 0.25634694 -0.15829086 -0.38169464 0.26429752 0.1645033 0.75097847 -0.22031423 -1.0126228 0.86136216 0.5696855 0.9408525 -0.95740056 -0.44982773 -0.123948604 0.3193814 0.7593228 -1.0724834 -0.6921337 -0.40781084 -0.5906108 -0.6554753 0.6040913 0.6252695 -0.33979604 0.4970114 0.16110851 -0.9506594 0.1241822 0.8946262 0.7862182 0.56828815 -0.29857355 -0.8666091 0.33067986 0.24565546 0.2686512 0.082254566 -0.6242145 -0.02185912 -0.15140264 0.78515095 -0.44740093 -0.23322669 -0.8140943 1.0754658 1.2854353 -1.1501962 1.0719937 -0.46895045 0.6143548 0.60181326 -0.7475681 0.55201775 -0.69119143 -0.3054334 -0.049663063 0.5015823 0.30371746 1.0247856 -0.562688 0.45844007 0.10936073 -0.29645976 0.079233535 0.7444017 0.05806203 0.34739295 0.8780349 0.71267736 -0.113302924 0.2583885 -0.30193368 0.32461894 -0.5522429 -0.37032494 0.4369125 -0.35227743 -0.40002182 0.7575137 0.52140576 0.3296733 -0.011413228 0.29720244 -0.59996575 -0.21310808 1.3493263 0.659684 -0.9193991 -0.76097363 -0.2046924 -0.64432776 -0.3528894 -0.51405644 0.71727616 -0.20332915 0.5511772 -0.032121886 -0.2501371 -0.14629054 0.73699504 0.1118277 0.11177467 0.9598214 0.73264235 0.39501053 -0.7580807 0.7113314 -0.14275365 -0.5992353 0.36376947 -0.16459039 -0.59895796 -0.74465996 -0.5557079 -0.65468097 -1.174259 -0.25395662 -0.93570775 -0.38750383 -1.2313485 -1.0043594 0.42920175 0.5815662 0.3655591 0.41676256 0.56806195 0.33767775 -0.7284884 -0.78373975 0.29520842 0.44185263 -0.778247 -0.22292104 -0.3958447 0.9001331 0.5460362 1.2534076 -0.44228593 -0.22174759 -0.39519143 0.1768537 -0.62457 0.2869673 0.6781749 0.6425861 0.28981566 0.022437163 0.32453555 0.3072593 1.4401184 -0.36963075 0.3406237 -0.23235698 -1.4279234 -0.70022273 0.6786905 0.14347258 -0.49255094
# plundered 0.18387271 -0.7016088 0.2729091 -0.29282472 1.2127702 -0.15288807 -0.7312101 0.25904685 0.77429205 -0.81036866 -0.1600097 -0.2673433 -0.59060514 -1.5141118 -0.6902495 1.3805745 -0.19976392 0.012335558 -0.8179554 0.58485174 0.29812935 0.10023218 -0.6161999 -0.103835166 0.5459372 0.15862635 -0.0038210403 1.1750743 0.18979838 0.2835502 0.68727636 0.9106503 -0.69256425 -0.7203131 0.75030327 -0.83791417 -0.6381136 -0.10163453 0.5190821 0.87517977 0.4179652 -1.12677 0.1192678 -0.23641042 0.311158 0.13983116 1.0934823 0.22252367 -0.3205839 -0.7757467 -0.34633183 0.32326815 0.19600864 0.27940872 1.1019028 -0.49947542 0.5101599 0.21447371 -0.7312265 -0.3367356 0.24807613 -0.39307544 0.12975273 -0.8862998 0.29181078 -0.08323745 0.89680755 -0.82181126 -0.6160641 0.25987256 0.7702019 0.4022873 -0.010679036 0.2694917 -0.22960648 0.76242894 -0.26631275 -0.17819026 0.6750213 0.3034553 0.17954557 0.16830699 0.32357693 -0.68105775 0.09813881 -0.011147779 0.22471073 -0.5573454 -0.017575128 -0.44139564 0.3190785 1.2229723 -0.430007 -0.5371265 -0.28923884 0.25569552 1.2363983 0.58555543 -0.8360904 -0.0668568 0.7274487 -0.6479321 -0.2127897 -0.31876472 0.2875632 0.15395193 1.0371429 -0.46739677 0.42674226 -0.3135389 0.6635411 1.487815 0.18991747 1.1006861 -0.5950971 -0.2727666 -0.26340842 -0.58241355 -0.8852984 0.17100854 0.61364883 0.4224485 -0.233532 -0.05030332 0.7398471 -0.7036822 1.0878892 -0.06666295 0.8454318 -0.7292381 -0.71750575 0.72807944 -0.51115686 -0.9181474 0.8163385 0.091261655 -0.11745395 0.22433119 -0.7666416 -0.12793398 -0.3428816 -0.45404977 -0.6454426 0.7709834 0.60804737 -0.9664501 0.31643417 -0.8656306 0.6467701 0.9214268 0.047652 0.5440603 0.33828402 -0.713415 0.30064714 -1.2223642 -0.29412532 -0.38534358 -0.93356097 -0.4809228 -1.1064332 -0.613889 -0.05000899 -0.06580459 -1.2683973 -0.37261364 -0.2303864 -0.084858865 0.29068208 -0.41509622 -0.58498466 0.7063675 -0.88717943 0.77928954 1.3167573 0.4599314 -0.014532219 -0.11133637 0.88345754 0.40377986 -0.6528018 0.12111604 0.95466757 -0.27468655 0.5534983 -0.57502437 -1.1113712 0.06920404 0.75188446 -0.6859129 -0.77818704 1.0862828 0.53007233 -0.57616717 0.36171445 0.36139515 -0.445159 1.0822918 0.92799306 0.33726078
# libelous 0.10805126 0.9426678 -0.09580579 0.338713 -0.35375077 0.16153447 -1.1185646 0.06918104 -0.007784302 -0.11555284 0.18989277 -0.026589625 0.09828362 -0.8395431 0.9425417 0.40429717 -0.33798268 0.5404559 0.17636184 0.816217 0.76632607 -0.49005264 0.21209183 -0.06528039 -0.061222807 0.6956254 -0.09263489 0.56487656 0.73329824 -0.93517035 1.0819014 -0.17763317 0.10627869 0.6061009 -0.011219795 0.35684508 1.0140725 0.16309756 -0.2043951 0.86611116 -0.2545433 0.83068675 -0.9273106 -0.019249935 -0.1364371 0.030525776 0.46527153 0.06153919 0.014062674 0.13375993 0.49510917 0.336048 -0.16614634 -0.30885094 -0.7348498 -0.14717893 0.65875214 -0.5967368 0.6438516 -0.49187315 -1.1095705 0.38480794 0.4209775 -0.63968426 0.6035861 0.22919838 -0.83505213 0.61126894 0.12267131 0.15320788 -0.44105333 -0.79214805 0.4471913 0.4277035 -1.0637035 0.75774956 -0.3533345 -0.33089334 -0.58004284 -0.16839996 -1.033417 0.9101861 0.035139035 -0.6190489 -0.5732382 -0.101960436 -0.8351279 0.3109438 -0.0011115574 1.155349 -0.25979137 0.31046227 0.28900176 -0.9721477 0.8529619 -0.37758178 0.38188237 -0.79252416 -0.5827265 -0.13925429 -0.9886304 0.32324904 -0.27591822 0.17231105 -0.9484874 0.2007103 -0.5480163 1.1907724 -0.507416 -0.53654385 0.47209716 0.3061466 0.660285 0.2569756 -0.34656477 -0.015542101 0.5107206 0.32893148 0.0073371073 -0.1454201 0.62724125 0.71512485 1.205829 0.503791 -0.5391171 0.23896748 1.1569936 0.6229489 0.8732567 -0.91692865 -0.99427766 0.94633573 0.08618112 -0.036810327 -0.11150079 -0.11534101 0.9042685 -0.23778957 0.027851611 -0.69047886 0.0802038 -0.4582956 0.7482685 0.361723 -0.8235288 -0.9492678 0.12465932 -1.0312335 0.181598 0.65765643 0.8864558 1.0251518 -0.54212976 0.15713546 -0.7215002 0.10575541 -0.3886924 -0.8491948 0.5754394 0.13555257 0.0066912 -0.3484989 -0.087736055 0.40989423 0.5084179 0.24671035 0.5483572 0.480267 -0.38480186 0.033777382 -0.1454432 0.90947264 -0.43824723 -0.36346662 -0.23581654 0.03424021 -0.43915465 -0.7280651 0.9167027 -0.6689263 0.5749767 0.42206055 -0.32893878 0.59399784 -0.5983728 -0.85679716 -1.1013271 0.996948 0.6706087 -0.2978045 -0.7085771 0.007554624 -0.9706438 0.51617676 -0.48801365 0.106095694 -1.1531873 0.5401164 0.79210776 -0.62746906
# undisclosed -0.2618389 -0.33579016 0.13243641 -0.38591737 -0.25016376 -1.1166211 -0.21561193 0.09752641 -0.042776145 -0.4903457 0.06932651 -0.6075146 0.019627854 0.049315244 -0.16627876 0.34992355 0.22543062 -0.23051131 0.36499533 0.008701173 0.10054999 0.058292463 -0.4029016 -0.42043132 0.24890974 0.3187816 0.24915889 0.5600785 0.53555423 0.8000341 0.2826584 0.71075326 0.51263726 -0.45822132 -0.39490485 -1.0465667 0.062407758 0.75379324 0.27135912 0.65707994 -0.6813457 -0.3239293 -0.05754494 0.11988957 0.34858727 -0.45568198 0.22169717 -0.12210734 -1.6711876 -0.38975543 0.68456036 0.1392023 0.20549294 0.06465408 -0.023992658 -0.039457403 0.6778536 -0.014572281 -0.642863 -0.5088657 0.19897372 0.7159733 -0.3354019 -1.1235491 -0.55968785 -0.46930048 0.23137067 -0.11146468 -0.20884053 0.7569902 1.148765 0.22830996 0.27337006 -0.66641617 0.46147612 0.14975895 0.33220115 0.33284146 0.11499811 1.2501785 -0.63952154 0.9117939 -0.1867615 0.0076066134 -0.59840894 -0.86144036 0.12769155 -0.20153783 -0.2104706 -0.20009837 0.7185165 0.55509084 -0.43489346 -0.12585516 -0.6901926 -0.005509697 0.2882807 -0.20852196 0.12699981 -1.3175082 0.20069247 -0.89925486 0.28567907 -1.1177006 -0.4370052 -0.663565 -0.07892754 0.6819656 -0.5263127 0.6174649 -0.42493227 -0.46226504 1.0410086 -0.4348084 0.5149694 0.08058646 -0.08782499 0.6632784 0.09538708 -0.04810452 0.8525095 -0.12935282 1.091619 0.49269238 1.2855068 -0.061581455 0.81828326 0.45559245 0.18932223 0.65912837 0.18061924 -0.024929598 -0.11340035 0.5959962 -1.3261385 -0.46004233 -1.369874 -0.6397799 0.33886114 0.2753711 -0.6778568 0.12006899 -0.11136198 -0.72876865 -0.092778035 0.36386403 0.8497712 0.026493035 0.05268589 -0.11372175 -0.17367242 0.58954406 -0.13923295 -1.0574971 -0.0054875263 -0.4103889 -0.105988644 -0.36113095 -0.024846777 0.10045313 -0.879855 -1.0343858 0.03753388 -0.5671969 -0.46476576 1.2279857 0.7774349 0.40959206 -0.33964828 0.15173352 -0.5180973 -0.6656172 -0.76076597 -0.12074521 -0.30742976 0.79298204 -0.12450879 -0.21013647 0.53505707 0.1810909 -1.6177773 -0.31418663 0.5774564 -0.49075764 -0.05903191 -0.31692597 0.33480665 -0.17413926 -0.24780059 0.012739656 0.8118035 0.15611145 0.14379743 -0.5362846 -0.4027156 -0.3631294 -0.70410115 -0.34034225 -0.18736842 -0.073870085
# macroeconomists 0.46746182 0.30488345 -0.08069659 0.45411992 0.066537045 -0.15345481 -0.35486153 0.502064 0.3778498 -0.8704995 -0.1078139 0.94896454 0.5158115 -0.09325198 -0.75763863 -0.38961187 -0.16187619 0.82801545 -0.49398148 -0.08727171 0.257746 -0.35949343 0.3065227 0.6034982 0.7813096 0.30581287 -0.68506974 0.19513519 0.1346802 -0.9066095 1.0759627 0.8699598 0.233284 -0.54048973 0.33958542 0.5987307 -0.2289412 1.073897 0.2707441 0.10270121 1.1179194 1.1515074 0.2324107 1.0624882 1.1383238 0.14072609 0.23479661 0.73868567 0.59760374 0.6087687 -0.5238919 -0.5934735 0.6980289 0.1849941 0.23271498 -0.055081323 -0.21597445 0.7412941 -0.6685484 0.62487817 -0.052424423 1.121351 -1.1717906 0.1713914 0.6517734 0.07547269 -0.66154957 -0.30954334 -0.12495881 -0.64691955 0.18077366 -0.29154643 -0.52381665 0.6525254 0.5650313 1.0959084 0.39597386 0.038770735 0.01485577 -0.8017289 -0.13682689 -0.21705434 0.72358066 -0.5168229 -0.25841403 -0.4694894 -0.33023623 -0.080319196 0.15606567 -0.5769241 0.33313134 -0.1265097 0.78639966 0.2898543 0.4242784 -0.6109446 0.39975384 0.019812694 -0.7968034 0.5543812 0.11342761 0.48717424 -0.22577211 -0.2027078 -0.08016042 0.07402648 -0.010492811 -0.45346126 -0.9492407 1.0868677 -0.8713232 0.1791679 0.60992223 -0.40948775 0.13172355 -0.065144956 -0.6019706 0.13915318 0.039704196 0.25438684 0.28383294 -0.2649704 0.9131963 -0.74150246 -0.1774686 -0.36719382 0.053814936 0.5504182 0.7857719 0.96212715 0.12313496 0.7298971 -1.0757335 -0.8160211 -0.5601098 -0.39523852 0.41331032 -1.2654226 0.4421243 -0.2830414 -1.0319738 -0.5086108 -0.84858865 -0.36228514 -0.31539804 0.95289874 -0.51999146 0.3001249 0.28649426 -0.28003606 -0.60701144 -0.47355458 -0.75956565 -0.028532343 0.17069826 -0.9109751 -0.26679572 -0.2853905 0.76808995 -1.2411522 -0.49192277 0.3925621 0.25283828 0.51554525 0.034393273 0.819557 1.0713878 -0.7793402 0.8171174 -0.36195043 -0.053115558 0.5490974 0.43168744 0.5827006 0.61499035 0.6983602 0.7004197 0.93067163 1.0997343 -0.48945078 -0.25646877 -0.46246663 -0.524783 -0.39242256 -0.2495253 -0.21595274 -1.190932 0.8957503 0.30942598 -0.8420485 0.85029566 0.2857962 0.01744782 0.41788638 0.46251777 0.17827247 -0.2910116 1.0196128 -0.15009707 -0.83192706
# interdisciplinary 0.2810907 0.35530818 -1.2514207 -1.5730808 -0.14592506 -0.25769615 -0.61776656 -0.8943903 0.61679417 -0.55263895 0.22182684 0.07515631 0.38828874 -0.43614292 0.4272438 0.5754511 0.11172894 -0.2015949 0.7928674 0.15473478 0.84023774 -0.15269895 0.18499409 -0.24150297 1.313305 0.5194399 0.11677991 -0.15434891 -0.6167262 -0.2522822 0.91969544 0.27707216 0.3743177 0.63189834 -1.0551022 -0.45213693 0.28553715 0.6322194 -0.076388344 -0.19111401 0.6986032 0.46454856 0.4309559 -0.18594311 0.7426046 -0.6691108 -0.60010177 0.52799547 -1.059325 -0.12664855 -0.20991798 0.93267566 0.98188496 -0.11554042 0.8661152 1.2178059 0.20489533 -0.23302498 -0.628737 0.22722146 0.29808778 0.5204693 -1.0225296 -0.8916356 0.41223502 -0.5700421 0.36393982 1.542603 0.27282906 0.056210756 0.50366014 1.1013715 0.6172988 0.2682271 0.08179303 -0.50085133 -0.26505327 0.15986966 -0.21178655 1.3395106 -0.53605366 0.26956803 0.99563295 -0.92071474 -0.11853038 -0.02328813 -0.16653876 0.4219515 -0.9589092 0.09629711 0.17656493 -0.22693625 0.5768784 0.09909531 -0.6091816 -0.29546407 0.95590323 -0.055673316 -0.17696707 -0.273133 0.1163021 -0.09023204 0.61483234 -1.0823715 0.5646718 -0.2986904 -0.16048555 -0.44071445 -1.2736262 -0.28621966 -0.38263896 0.030069623 0.05346129 1.0518041 -0.4944294 0.9025924 -0.33960658 0.49859712 0.47183108 0.23804578 -0.14041393 -0.16956352 1.1490028 -0.9079468 1.7431628 1.0564758 0.18475437 0.2494649 0.056429338 -0.29925263 -0.066962324 0.20469128 0.62521386 -0.79800534 0.3009334 -0.14219224 -0.36628976 -1.3152246 -0.59072125 -0.8005902 -0.4972503 0.32018596 0.8052776 -0.69474256 -0.32119805 0.39476126 -0.16300471 -0.8007902 -0.6445775 0.27428758 -0.10906274 -0.25097772 -0.2952371 -0.13994776 -0.06485711 -0.16711657 0.115265675 0.4707135 -0.19994032 -0.5031323 0.01687636 -0.67325264 0.096716695 0.6891803 -0.23399264 0.5740392 -0.6425597 0.73366535 0.21863462 0.84055954 -0.24689345 0.5955609 0.4378961 0.06745754 0.6671622 -0.20908819 0.4479395 0.56970835 -0.36260557 -0.24915099 -1.2705859 0.13781816 0.085198276 0.0092129605 -0.07708554 0.80485225 -0.94283724 0.9947128 0.3508413 0.081816256 0.027650915 -0.18372877 0.005717221 0.3125173 0.43689632 -0.7982102 -1.0617009 0.90419066 0.8935669 -0.5499919
# remedy 0.5772606 0.17880103 0.058737956 -0.6778796 0.9689559 0.50767744 -0.35187244 0.5331793 -0.99051636 -1.0418116 -0.11738137 -0.33952397 -0.39692608 -0.5857776 -0.11498851 -0.30488884 0.1478111 -0.3036099 -0.2218836 0.15115869 0.41039047 -0.30487084 -0.41858846 0.5101901 0.0018634547 0.18573186 0.7168316 0.10914942 -0.074842945 -0.4727854 0.8963781 -0.19558068 -0.28879964 0.34226206 -0.95057595 0.25224903 0.6319609 0.64257 0.604484 0.45459282 0.5274375 1.3541383 0.6926334 0.50032437 0.6965396 -0.19591177 0.72725624 0.30754507 -0.78185827 -0.9801623 -0.52887017 0.14647502 0.5030993 -0.26943564 1.0035758 -0.36067474 -0.4461159 -0.030929789 -0.7272065 0.53371906 -0.27408025 0.20097052 0.16799791 -0.12410204 0.5214966 -0.61942446 0.58205736 0.28365555 -0.6949905 0.8372967 -0.64099795 0.31223086 0.08918457 -0.5936622 -0.56645906 -0.10233064 0.3506087 0.030368425 0.83315015 0.39047533 -0.10794934 1.4498358 -0.6225617 0.24174845 -0.514608 0.5692374 -0.02759037 -0.054292873 0.20945188 -0.59144694 0.8148554 0.45963046 0.52507144 -0.27368966 0.97896534 0.30032104 0.55327 -0.5535038 -0.404449 -0.51049167 -0.031118302 0.6035659 -0.19142109 -0.6246411 -0.11301479 -1.0787175 1.2479128 -0.02291988 -0.40181616 -0.40381137 -1.3400595 0.4287701 -0.56455183 0.21378721 -0.40325767 0.1299891 -1.2970592 0.015850598 0.684468 -1.4542531 0.7445684 -0.4379429 -0.31664935 -0.023523826 0.01019942 -0.5536475 -1.0586141 0.043964013 -0.10824377 0.10475733 -0.0639164 0.7885702 -0.6525038 0.8676008 0.14060667 -0.1506032 0.1283437 -1.3323711 0.80144185 -0.5959665 -0.88134193 -0.22392571 0.73329186 0.012410315 0.86152285 0.28480068 -0.85442007 -0.21004042 0.22205201 -0.0014681863 -0.19284636 0.7751895 0.22742821 -1.0878005 0.30175602 -0.44451755 0.40960583 -1.2581686 0.6095633 1.035927 0.16773084 0.19770294 0.07763164 -0.49703255 0.15517625 0.21813963 0.002024663 -0.37813452 -0.27108702 0.3979112 0.89708555 -0.23151384 -0.55469346 0.5543179 -0.10427433 -0.3671127 0.017893322 0.20858859 0.7511927 -0.53502786 -0.28157026 0.03405418 -0.344652 0.07073913 0.49163374 0.6667584 -0.35514554 0.5800155 0.68260497 0.38137797 0.24542955 0.05836121 -0.70863897 0.46006286 0.60135686 0.20795156 0.380411 -0.21877821 0.8450019 0.210832
# authority 0.37370077 -0.08846024 -0.50575536 -0.4447613 -0.30785322 -0.29448915 -0.24145435 0.8011806 -0.39602077 -0.29748267 0.2410689 -0.09735653 -0.39709228 -0.21100114 -0.5507708 0.53746814 -0.073381975 0.6786548 0.7005949 0.33552232 -0.6543832 -0.35758236 -0.6136199 0.6900303 -0.32477942 -0.016453125 -0.21740653 -0.45700315 -0.24892642 0.1480877 0.5301971 0.18238486 -0.3324181 -0.16963403 0.037288215 -0.3201078 -0.8437667 -0.2043799 0.34551933 -0.34594 0.9666481 -0.40713003 -0.2401203 -0.24706604 -0.020875415 0.35544077 0.39776886 0.53643423 -0.6533926 -0.8066825 -0.18082955 0.24114883 0.09977397 -0.521656 -0.57440627 -0.39314184 -0.6129002 -0.20826474 0.053649116 0.44403303 -0.07624851 0.19195156 0.0912169 -0.026475525 -0.59896356 0.3955703 -0.316532 0.40904632 0.53935695 0.08612086 0.56989783 0.43333974 -0.06899559 -0.026806552 -0.27148405 -0.23031965 -0.17691986 -0.2662683 -0.20811386 -0.3392811 -0.620266 -0.019401867 -0.33222887 0.48557192 -0.5219912 0.07430881 -0.26318508 -0.5817231 -0.1289466 0.4978221 0.43170443 -0.35059422 0.47961894 0.54876566 0.4800357 -0.85304743 0.53738385 0.21190153 0.028099602 -0.49396652 -0.10437061 -0.18454407 0.16679707 -0.8576715 -0.36498126 -0.40530756 -0.20004222 0.14879903 -0.18400978 0.5010528 -0.05573373 0.5776894 0.2018304 -0.043067925 -0.27338743 -0.20147443 -0.4580412 0.28732648 0.29408354 0.1839609 0.49842927 0.38049605 0.947917 0.16661806 0.7203491 0.40152466 0.016507456 0.43992513 -0.2679092 -0.2816917 -0.34916142 0.20042875 0.39474225 0.32521364 -0.07681921 0.1436472 0.027471973 -0.21562387 -0.16246015 0.05232537 -0.14634849 0.1310793 0.13675863 -0.5006639 -0.5322922 0.49265417 0.75246775 -0.123293996 -0.57410556 0.12114454 -0.3222382 0.43821594 -0.23805565 -0.10515058 -0.38696098 0.39179173 -0.12662728 -0.36980346 -0.59361464 0.37014583 -0.08376608 -0.6565199 0.019054057 -0.19652872 0.018249756 -0.27761316 0.5628228 -0.4806348 -0.24554048 -0.6524854 0.041211635 -0.19968769 -0.45366013 -0.49755475 0.926043 -0.8531584 0.55676746 0.088803716 0.4649455 0.58967 -0.45291877 -0.13409077 -0.052095246 -0.019892791 -0.67739475 -0.69297713 -0.5745786 0.47703484 -0.3470002 0.14485894 -0.3234665 0.15659551 -0.07038744 -0.095774636 0.006998943 -0.5443079 -0.09727596 -0.07458223 -0.064366594 -0.5438462
# moisten -0.200635 -0.023303429 -0.1959919 -0.114246756 0.09986103 -0.96675646 -0.43622476 -0.098721355 0.20095839 -0.8405461 -1.5571104 0.5189216 0.73215383 0.4367765 0.17016901 -0.6054243 -0.44778037 0.32664087 0.4722886 0.97871596 0.8054682 -0.0560897 0.42439172 0.29548767 0.71709025 -0.28371954 0.37750643 0.98659486 -0.12195035 -0.8438716 0.19612648 0.39242315 -0.42731664 0.6421651 0.5766205 -1.2783281 -0.9434697 0.47824118 0.43340844 -0.55967754 -0.24277611 0.28424728 0.6836459 0.30512062 0.050898485 -0.53585476 1.1983418 -0.16305871 -0.65259516 -0.5887871 0.084811516 0.16835599 0.6161325 -0.8901366 -0.63382834 0.0511175 0.50715387 1.2140478 0.46091118 0.1516342 -0.8887821 -0.9216554 -0.7810925 -0.8210461 -0.73448664 -0.39108193 -0.32068613 0.5842231 0.19796894 0.8813116 0.753323 1.0343354 -0.57695717 -0.25125006 0.1804653 -0.6003358 0.39229664 -0.5592466 0.41074857 -0.19134802 0.090008795 -0.14631356 -0.4646126 -0.5125029 0.2840357 -1.0244185 -0.8054108 -0.722677 -0.019664949 -0.21900791 0.9678537 -0.14452176 -0.47022703 0.27801365 -0.61431533 0.98092765 -0.5085499 0.13274388 -0.24106689 0.6772182 -0.3630681 1.0980948 0.79228604 0.36462408 -0.86387265 -1.0560546 -0.33502 0.4464455 -1.6243328 -0.111220464 0.56174237 0.36952797 0.15010516 1.3545741 0.2727442 0.9579629 0.35346085 -0.0803759 -0.84968245 0.0052913534 0.35916027 0.9760542 1.5329883 0.02207839 1.1420453 0.36487496 -0.87458736 -0.044600837 0.8513204 -0.09200949 0.14888912 0.44519073 0.24674574 0.9229931 -0.35884044 -0.05632784 -0.11293932 -0.048730373 -0.57957166 0.0038840359 -0.21228486 0.61448556 0.46989378 -0.35613942 0.14241198 0.15430725 0.53315943 -0.40034884 0.37200508 0.6721889 -0.5197491 0.4510632 1.0433923 0.18509698 -0.29633445 -0.60853297 0.56790876 0.35027257 -0.3627877 -0.8812363 -0.074700855 -0.5517461 0.48710144 -0.259751 -0.4045369 0.052436758 0.9323377 0.34916186 -0.118054464 -0.22493455 -1.2890487 -0.059535205 -0.16345096 -0.61117214 0.43588674 0.3101703 -0.41691118 -0.15520829 0.8927946 0.510186 -0.09731083 -0.22274362 -0.45828006 -0.41112456 0.7510083 -0.7636698 -0.13980547 -0.64947796 0.12787233 -0.52857715 0.14669491 0.80676574 -0.17420591 -0.64405805 -0.30425403 0.71710265 -0.7040205 0.7959745 -0.78572714 -0.62811923
# wrathful 0.46669835 -0.13341613 -1.0560153 0.61037856 -0.7510839 0.7095365 -1.0792836 -0.58252674 0.3261438 -0.5084467 -0.729026 -0.5132425 -0.6886419 -0.0024425178 -0.30672276 0.115419805 -0.119141094 -0.38636485 0.7372774 0.4268857 -0.46747184 0.11306751 -0.043844145 0.876248 -0.9270173 -0.0037949786 0.30340362 -0.7127135 0.9263269 -0.52302456 0.56884545 -0.6640042 -0.99639493 -0.77899176 -0.08773976 -0.068962656 0.259383 0.63827044 -0.5813852 -0.34273747 -0.052309886 -0.6805452 -0.5837119 0.14322668 -0.3150079 0.7888417 1.1914943 -0.570257 -0.7293679 -1.061029 -0.32972962 -0.5992543 -0.8209748 -0.8460614 0.40318957 -0.34937006 -0.24719924 -0.117250495 0.30551383 -0.15933345 -0.38020515 -0.32890406 0.19378713 0.21179827 0.48040152 -0.5048105 -0.074407734 -0.31873283 -0.34628183 -0.19132811 -0.36770314 0.395377 0.98687136 -0.22787245 -0.17994505 0.6077329 -0.33332744 0.589774 0.005601977 0.86795235 -0.8707175 -0.013473786 0.8030431 0.13450542 -0.9716338 0.23115136 -0.10083148 0.65541714 -0.77637964 -0.3356164 0.18906485 0.10085562 0.8202435 -0.5903411 0.9567555 -0.44495937 0.23716962 0.27758533 -0.7465569 0.08085486 -0.059578925 0.82227194 0.34254462 0.0021122608 -0.39894488 -0.4062579 0.40854046 -0.13436648 -0.29923365 0.4597295 -0.505105 0.4400636 -0.48037967 0.2024611 -0.992348 0.12907268 -0.3236319 -0.02838646 0.8916948 -0.22302902 0.40124735 -0.7994114 0.608573 0.8305939 -0.15654425 0.37500012 -0.38630527 1.1462224 -0.6401195 -1.0944964 -0.32159328 1.1533169 -0.52020764 0.577834 0.59732443 0.5906435 -0.055998925 0.33173043 0.5199589 0.76416093 0.27817556 -0.5554125 -0.06406667 -0.69967717 -0.4427167 -0.7435997 -0.19073561 0.023781024 0.85681844 -0.7796015 1.0148045 -0.036778245 0.2551581 0.052702423 0.6029654 -0.9598286 -1.2183272 -1.1022495 -0.10379329 0.7905043 0.75627655 -0.84609914 0.030779181 0.12459425 -0.3367032 0.4636058 -0.59789735 -0.41146025 0.08793276 0.2840404 -0.34968615 0.62586063 -0.31677034 -0.37850448 0.8532827 -0.89553225 0.27051044 0.53892994 0.32865995 0.22475675 -0.3741986 0.69986093 0.27340665 0.5185867 -0.4837449 0.9721916 -0.059888072 -0.33994922 0.11176658 -1.2342896 0.53133017 0.66512567 0.6113333 0.4420423 -0.53284293 -0.50289136 -0.09221468 -0.3283024 0.8826252 -0.62329817
# enrollment -0.3221238 -0.4062431 -0.81226605 -0.058744125 0.064718604 -0.4067527 -0.28269354 0.40406552 -0.3911159 -0.5092777 -0.084680825 0.7345649 -0.64832973 0.9711678 0.36182144 -0.28020227 -0.14824949 -0.11092916 -0.4355928 1.2226794 -0.42198128 0.6619399 -0.60106385 -0.28636202 0.063465536 -0.19842687 1.3780378 -0.8511068 0.34096947 0.4816834 0.9538516 0.48710507 -0.6733102 -0.24389245 0.48934183 -0.3386711 0.83232653 0.3737216 1.0535979 0.08149813 0.79790217 0.55643773 0.07416265 0.095675156 0.028030703 0.74184316 -0.46247843 -0.2967581 -1.5350627 -0.17827606 -0.018350817 0.6968127 0.7101193 -0.0813665 -0.066991396 -1.4144789 0.4359997 0.57583904 0.32009223 0.54776496 -0.0051848083 -0.5709247 -0.968849 -0.618607 -0.91588324 -0.27440467 0.045493208 0.24403578 -0.44490185 -0.30995804 0.5420279 1.2393805 0.36293957 0.28289595 -0.26742417 -0.55979156 -0.5137086 0.056717094 0.7740458 0.8334126 -0.020267557 0.23298375 0.40789008 -1.0321757 -0.10882104 -0.67746335 -0.12357669 -0.046985712 -0.34511396 0.48473328 -0.6003118 0.124603234 1.2071157 0.31606513 1.1062766 -0.056005277 -0.075031824 -0.65003234 -0.4679868 -0.23644172 0.82689226 -0.59046316 -0.3166839 -0.07490398 0.32823935 -0.11544028 -0.5874744 0.30710334 0.13942727 0.09313239 0.67031085 0.19337124 -0.28173944 0.8511567 0.49138904 0.007807656 0.3002424 0.46773243 1.0241574 -0.06803471 0.45245486 -0.3493351 0.23944311 0.5660067 0.077246025 -0.6959611 -0.49933183 -0.35025123 -0.19557993 0.749803 0.22755435 0.39398184 -0.8177369 0.4846294 -0.8006534 -0.15201092 -0.6376925 0.056138214 -0.4709754 0.2084134 -0.8470831 -0.5096689 -0.31132868 0.25023764 -0.0773817 -0.20371798 -0.20890933 0.06883591 -0.5057885 0.4115936 0.98538065 0.9294618 0.044472545 -0.742415 -0.2549998 -0.27552006 0.003154268 -0.46820408 0.54071474 -0.22035874 -1.0016396 -0.39382374 -0.3991301 0.03952521 -0.34585044 0.5590621 -0.04168711 -0.28125185 -0.59726495 -0.22062181 -0.13608615 -0.50624806 0.2556261 -0.08100168 -0.41408938 0.38335416 -0.33680248 0.4489817 1.1968095 -0.14271879 -0.99030226 0.68843865 0.08297271 -0.15500882 0.10044081 -1.2825322 -0.13015997 1.0865417 -0.09248749 0.74059963 -0.7933787 1.2329125 0.58482814 0.2996851 0.2288434 -0.1393793 -1.351407 -0.28819898 0.44486406 0.74318796
# conclusive -0.6043002 -0.28406075 -0.8370353 -0.6207989 0.6433227 -0.2986395 0.2281306 -0.6248267 -0.059829585 -0.3796459 -0.12987925 -0.01115105 -0.40292907 -0.27200374 -0.2618255 0.13603285 -0.16643837 0.08707824 -0.7219162 -0.2299043 -0.08502506 -0.6426783 0.1269625 -0.71612465 0.37089044 -0.6387478 0.8143781 0.13989301 -0.5601862 -0.70378584 1.0429255 0.8156761 -0.039101362 -0.6891046 -0.32330602 -0.30741578 -0.009227109 0.8500942 0.11231436 0.49329567 0.4987269 1.2164142 0.38876745 -0.037417416 0.15463294 -0.32867303 -0.021241287 -0.98388153 -0.6580268 -1.0767734 1.035019 0.19164069 0.123308994 0.0015050237 0.24286325 0.026555985 0.16620217 -0.15787354 0.011708076 0.08347823 0.26996544 -0.36954162 0.12982969 -0.92347515 0.32775858 0.02147424 -0.92056763 0.3830883 -0.5631922 -0.904227 1.1295176 1.1918455 -0.12126775 -0.5736136 -0.6136664 -0.15582468 -0.6824046 0.4215729 -0.2066752 0.045138817 0.14442742 1.1531106 -0.087974384 -0.47192326 -0.5558787 -0.5752455 0.41412735 0.24420127 -1.5315319 0.95302814 -0.17707844 0.19943985 0.6589411 0.6056311 0.4303326 -0.7192784 -0.4673873 -0.7689065 0.3022276 0.30814525 -0.4016851 -0.10437568 0.64192677 -0.6234012 -0.81674725 -0.28853965 0.5919371 -0.04500625 -1.0169978 0.8028476 0.21833578 -0.2175715 -5.909667e-05 0.65630406 1.0609658 0.15823579 -0.46390527 -1.0253003 -0.024971714 -0.37317416 1.0377625 0.23302904 1.1923444 -0.2709499 1.1553308 0.19983049 1.0437708 0.7183674 -0.4059456 0.20687895 -0.8146829 1.1951162 0.3200604 0.8600933 0.6495726 0.35243738 -0.4182261 -0.9407571 0.08259202 0.32521114 0.40224093 0.509228 0.8034523 0.061910544 0.39078638 0.59854466 1.0225321 -0.22951464 -0.14505236 -0.38160774 0.06356716 -0.29893476 -0.5657691 -1.0375681 -0.43493912 -0.45463663 -0.14991128 -0.6850871 -0.017026883 -0.10701804 -0.15082791 0.087341696 -0.40347213 -0.31466863 -0.9806293 0.43305534 0.15195768 -0.24466972 0.08364377 -0.09348669 -0.50442153 0.6187604 -0.32841054 0.23881336 0.39503342 0.23860794 -0.9615179 -0.025727697 -0.2906269 0.12468252 -0.09186239 -0.34828228 0.8887518 0.32686397 -0.30399588 0.26632524 -1.1766205 0.9413024 0.67821145 -1.0670482 -0.59817773 0.15370537 -0.82282925 0.8683792 -0.7405803 -1.3257682 -0.09233864 -0.06900919 0.39426303 -0.48668957
# delight 0.351845 0.68425965 -0.20956236 0.13109729 -0.610566 0.31949648 -0.6056714 0.38768968 -0.69793123 -0.60001 -0.9149898 0.83771944 0.23141 0.038871653 0.14653468 0.007726426 0.53300077 -0.9152679 -0.4296406 -0.21093218 -0.5580854 -0.7041896 0.0593756 -0.41801605 -0.23410559 0.5158401 -0.3702691 0.9586005 0.30384654 -0.06786337 0.037466284 0.017399697 -1.1992129 0.7233799 -0.48175046 0.08199155 0.8127067 -0.44746053 -0.02066468 -0.3642206 -0.13544838 1.1789821 -0.26397532 0.40691167 -0.05533067 -0.023629783 0.07040665 -0.5718497 -0.9773304 -0.5708241 -0.07967449 0.81237423 -0.3231402 0.44613218 -0.21715678 0.012813386 0.07014208 0.2905285 -0.62727386 -0.15808512 -0.7664122 -0.15349874 -0.8432679 -0.31588075 0.637863 -0.15518479 0.37544447 0.028308798 0.023789713 -0.69820637 -0.076168254 0.36826444 -0.14929146 0.5729375 -0.59842414 1.3535372 0.3440445 -0.57300574 0.8185514 0.56880647 -0.7046426 -0.5297635 -0.6800776 0.50298613 -0.9559905 0.15699846 -0.47818682 0.56205934 -1.1505113 0.33268008 -0.24018142 0.036130562 0.78969103 -0.7435774 -0.6520609 -0.10846312 0.3848372 -0.29726717 1.0118839 -0.17882414 0.45859814 -0.2029652 -0.018743956 -0.3205269 -0.02063009 -0.6959145 0.6700179 0.4228464 -0.7390141 1.0004157 -0.108953886 -0.026595758 0.57500434 0.29730752 0.52827936 0.6412845 -0.8009227 -0.54127324 -0.2734131 -0.1009207 0.3529054 -0.09369318 -0.47725314 -0.11170449 -0.018606296 -0.68511385 0.2569554 0.39472803 0.20991431 0.29030034 -0.6070818 -0.56911343 -0.98009676 -0.65188104 -0.4024884 1.0220901 -0.16449381 -0.5921808 0.2674734 0.24250764 0.6565784 0.36569607 0.64006346 -0.36707127 0.54749954 -0.7023916 -0.8075677 -0.30244085 0.68578094 -0.2064391 -0.15577067 0.4808279 -0.81895673 0.94175285 -0.019324252 -0.18898235 -0.549432 0.4507231 0.7119862 -0.7794144 -0.5161315 0.008922841 -0.37684682 0.5679252 -1.2161759 0.7654339 -0.13027458 -0.8282991 -0.5442962 0.8795808 -0.64452434 0.66536486 0.06973615 -0.5072335 0.32474384 -0.31239995 0.4072528 0.30868325 0.4237681 -0.54900074 -0.870175 -0.116828576 -0.21193735 0.38230324 -0.031421833 0.54302454 -1.3279496 1.4122367 0.99278706 -0.69567806 -0.72288835 0.2938404 -0.96921664 0.7009085 -0.41420004 -1.4793203 0.38664487 0.10997641 -0.34252283 -0.87174124
# ...
# cell -0.084549375 0.3517133 -0.28294465 0.14319241 0.6089156 -0.77025414 0.022811322 -0.15335397 0.40550897 -0.41819766 0.28850043 -0.54696834 0.0877161 -0.50698024 -0.49038792 0.030024072 -1.1108104 -0.75252974 0.0014336783 0.7893088 0.2967729 -0.47551003 -0.046255928 -0.09015787 0.29672426 0.99012977 0.25135934 -0.06899668 -0.18875691 0.79641974 0.5346774 0.6306306 0.03334637 0.03706808 -0.06493864 0.19507894 -0.643586 -0.21137382 -0.3702109 0.4174321 0.2397339 -0.10985639 0.0253166 -0.18519162 -0.76109934 0.36647695 0.08028582 0.35580075 -1.1778322 -0.79114217 0.3646728 0.5720466 0.011161387 -0.6691735 0.13446648 -0.11590727 -0.5976995 0.37148803 -0.4399965 0.20812294 0.27224287 -0.06996632 -1.1643667 0.18406227 0.015900385 0.23022549 0.6683089 0.34443024 -0.17768878 1.2286335 1.0698768 0.7817231 0.38568598 0.5555257 0.04882596 0.016486378 -0.29947957 -0.18148966 -0.03591913 0.22393942 0.039478924 0.17326397 0.06356835 -0.18590064 -0.11592374 0.07523577 -0.42033905 0.42042196 0.7181764 -0.27124518 0.54304475 0.53709346 0.2589652 0.07793177 -0.14793247 0.15572582 -0.16046014 -0.4870864 -0.06721359 -0.65160006 0.710685 -0.083172664 0.30229446 -0.42423815 -0.50853014 -0.4134102 0.18177576 0.2187542 0.07290176 0.28072897 0.12271196 0.5227951 0.70264846 0.42273042 -0.007802749 -0.19511296 -1.1028739 -0.31311032 -0.7953682 -0.22121967 0.67170155 0.36140662 1.2384514 -0.0482795 0.5254961 -0.32334262 0.40457413 0.016858475 -0.6466538 -0.06971994 0.5541259 0.81795406 -0.25584263 0.3608533 -0.435387 0.2753693 -0.19113499 -0.6777402 0.27305987 -0.677251 0.19250512 0.16323072 0.08791671 -0.3091035 0.903541 0.48496792 -0.5450476 -0.29767257 0.114788875 -0.28782114 -0.32676384 -0.0088912975 0.32320485 0.12133529 -0.12381959 -0.3173515 -0.33358815 -0.029240994 0.08948574 0.31504235 -0.13211729 -0.5767971 0.31351674 -0.93747044 -0.060942132 0.73960125 0.12648574 -0.9787541 0.20437294 -0.25178155 0.49349132 -0.2620674 -0.21808755 -0.24984102 0.7292098 -0.039061256 0.41454017 0.86538607 0.2880647 -0.35067046 0.087577306 -0.42588422 -0.23469466 0.1755487 0.0096049 0.66455144 -0.5726935 0.07134274 -0.8079882 -0.14952324 0.27288762 0.72634035 -0.22532031 -0.080009416 -0.40746334 0.0052311397 0.5023622 -0.273941 0.46723747 -0.20936716
# advisory -0.2203166 -0.031262815 -0.8199793 -0.04212477 -0.5818017 0.33725074 0.20380679 0.59358627 -0.04335479 -1.1458958 -0.26792195 0.12690048 -0.31535277 -1.0118394 0.37320274 0.116259895 0.62997365 0.7097287 0.0036954903 0.50690836 0.40306792 -0.7534891 -0.35361907 -0.92787194 0.5785944 -0.30488902 -0.08240086 -0.11426404 -0.0700617 -1.0681915 1.7122371 0.27571163 -0.42650986 0.26672778 -0.30775762 -0.8770939 -0.43402007 0.06014437 -0.2796931 0.5574274 -0.29724386 -0.65123063 0.15974046 1.048564 -0.22190936 1.453633 0.7037247 -0.36846256 0.0058983075 -0.46751225 0.112136506 0.8305735 -0.008412235 -0.8417616 0.020125188 -0.41203877 -0.6702712 -0.67017555 -0.81198514 0.37704542 -0.10851889 -0.97676605 -0.28140366 0.028745573 0.052038353 -0.18098488 0.4133833 0.25629252 0.468818 -0.56319624 0.7852565 0.42763993 0.3460553 -0.25156713 -0.5840468 -0.33345976 -0.74149066 0.3058162 -0.047060028 0.7028202 0.39809445 0.5852081 -0.08220184 -0.74058354 -0.42162925 -0.76930034 -0.22543566 0.40233245 -0.7693336 -0.45052987 0.9277902 0.61945194 0.32551375 -0.38006458 0.5943018 0.74759096 0.35928804 -0.08586444 -0.7751015 -0.33541688 0.2502937 -0.6178356 0.0895429 0.3189889 0.5063194 -0.43388572 -0.5327557 0.16516343 -0.059966873 -0.17263637 -0.1623726 0.9367619 -0.23554312 0.2888707 0.4839333 -0.04484797 -0.41531593 -0.22489691 -0.078104906 -0.5949069 0.21055499 -0.20146275 0.43941465 -0.57839894 1.149463 -0.70061797 -0.23339877 0.26105687 -0.12123304 0.45229876 0.14237492 0.46258125 -0.7181981 -0.20623136 -0.36555785 0.31132174 -0.79086965 -0.16648279 0.4085904 0.7315844 -0.075437 -0.16900422 0.1517794 0.12416099 0.29235637 0.39859763 0.6796735 -0.7349058 0.5811591 -0.12668727 0.037184894 -0.13641676 -0.28387097 0.5029961 -0.08570467 0.30573225 -0.47126296 -0.92334247 -0.5368945 0.6865831 0.22975397 -0.37489882 -0.055053614 0.2727775 -0.46514332 0.045455907 0.369939 -0.7373182 -0.24493986 0.72692776 0.041603733 -0.84198546 0.19248179 -0.77168226 -0.85302234 0.550379 0.02394589 -0.094147384 0.65467054 -0.32890767 -0.7737203 0.15202539 0.21191393 0.21525142 0.11470143 -0.2781373 -0.7528921 0.20101373 1.0219706 -0.099046186 0.12593424 0.11638898 -0.22857454 0.24068448 -0.06510943 -0.38184375 0.13183646 0.20771925 0.0742722 -0.49960428
# broad -0.37823918 -0.47203347 0.3178 -0.28632814 -0.03709417 0.1459406 0.6344001 -0.04195989 -0.142985 -0.48767957 -0.037818972 0.1606947 0.23822735 -0.0195226 -0.17703769 0.53929704 -0.5111134 -0.30186218 0.055187505 -0.34302437 -0.19658515 -0.056665923 -0.4113123 0.3824455 0.85884047 0.4986413 0.3364793 0.01463338 -0.28600395 -0.34601703 1.1724735 1.2861748 0.22842218 0.31279725 0.12618893 -0.3093884 -0.106098756 0.64201266 -0.017944397 0.15027824 0.7864105 0.2868447 -0.6707749 0.53094286 -0.12134815 -0.72953993 0.13363804 0.17449468 -0.87464005 -0.86943316 0.5912018 0.39918527 -0.18771729 -0.27388662 -0.27294672 -0.068687215 0.08309865 -0.45325395 -0.49551687 0.1993071 0.18098304 -0.67924964 0.12559761 -0.07410193 -0.1367508 0.30347595 -1.0912302 0.4672913 0.62738603 -0.9061078 0.18149818 0.75722605 0.21482025 -0.51332724 0.25649628 -0.101065814 -0.008184897 0.14165631 0.46368068 -0.21250091 0.65205467 0.39211527 -0.4097923 -0.3422442 -0.11290664 -0.34471613 0.04647231 -0.1619347 0.61354977 0.44488245 -0.047969498 -0.49186516 -0.30344507 0.3908444 0.19610927 -0.99408525 0.32651752 -0.22629082 0.40007436 0.20662625 0.62893826 -0.104137644 -0.30299303 -0.45288998 0.334278 -0.01738737 0.42514232 -0.0787883 0.3368668 -0.8405285 0.23080824 1.1031082 0.4102172 1.0891142 -0.083704375 -0.24861422 -0.17690428 0.24989526 -0.17612632 -0.5853613 0.27377498 0.46397942 -0.24731949 -1.2162111 0.38238326 0.36346313 0.7174423 0.2076883 0.07151347 0.1092283 -0.10252168 0.40023154 -0.6054662 0.91069347 0.44952586 0.12187747 -0.39676392 -0.032233357 0.058470275 -0.6533892 -0.4062744 0.5294608 0.4374408 -0.7070995 -0.41379583 -0.41175297 0.7398262 -0.14235295 0.9511367 -0.3654129 0.16359326 -0.03396602 -0.07378686 0.51703125 0.2318985 -0.25926527 0.020274948 -0.6003247 0.50582165 0.18231964 -1.3636956 -1.0145141 0.5541603 -0.5844541 -0.4205399 -0.04925879 0.06692088 -1.2265908 -0.27761626 1.2169468 -0.4219582 0.33968803 -0.09055871 -0.0030673116 0.58296835 -0.2574924 0.07354139 -0.09415558 0.6546428 0.40902594 -0.11752535 -0.45453006 0.14826617 0.39730135 0.058999885 -0.883511 -0.14754297 -0.03576811 0.060024712 -0.7743898 -0.041553088 0.14831558 -0.9592327 -0.25490898 -0.24769211 -1.0897602 -0.45376182 0.2565643 -0.015773458 0.21110812
# laugh 0.53623474 -0.10185447 0.39766914 -0.54649454 0.3338625 -0.43447325 -0.5205334 0.8146425 -0.1171704 -1.0938287 -0.16932602 0.8401051 -0.7051831 0.1138584 0.25936154 -0.17775072 -0.44892973 0.21118404 -0.6043644 -0.50973016 -0.40775058 -0.3327336 -0.27516615 0.58747673 -0.1909861 -0.28276476 -0.124148 0.46006387 -0.42530814 -0.38577715 -0.41565704 1.3986663 -0.45090213 -0.082558125 -0.5310648 -0.59212077 -0.011877576 -0.13296875 -1.1166213 0.69793266 0.15830913 0.564582 0.49085608 0.10828751 0.13420308 -0.846068 0.6989689 0.5964643 -0.25307465 -0.30233577 -0.1170162 0.86687815 0.5479151 -0.06412009 -0.045904875 0.2416575 0.549605 -0.08354892 0.111144185 -0.16588716 0.15369575 -0.14874695 -0.51563877 0.102406226 0.5436802 -0.14568105 -0.07186232 0.45185593 0.5194794 0.2069003 0.5308673 0.09963849 0.53674585 0.362246 -0.12284145 0.18024053 0.32432097 -0.02117676 0.30280367 0.59542996 -0.13865684 -0.5218102 -0.84396416 0.59118485 0.48824662 0.38281843 -0.95851535 0.44780007 -0.41891125 0.41120288 -0.3329552 0.8503857 0.2760643 0.12984398 0.113509595 0.7106585 0.6196494 -1.0055856 -0.08443434 0.5641621 0.13552588 0.29658857 0.38045835 -1.0850935 -0.23002477 -0.33413282 0.2767473 0.30886942 0.12281644 0.07178325 0.9175545 0.16775535 0.047698747 1.1020923 -0.6772444 -0.3793538 -0.19708587 0.11418251 0.4857764 0.061044663 0.16196238 0.16308185 -0.31098834 -0.6235743 0.41043228 0.4790893 0.1626142 0.16585875 0.25616798 0.8907777 0.01237387 -0.2573498 -1.0339104 0.24755087 -0.10826825 -0.21893388 -0.34439245 0.1453559 -0.0040897634 -0.26515105 0.18164234 0.11833194 -0.17275691 0.30303177 0.17811593 0.17420484 0.7972748 -0.3528697 0.42055988 -0.26930735 -0.04940483 -0.20699708 -0.5392992 0.24853425 -0.5830879 -0.13473292 -0.4151281 -1.2130613 0.51414883 -0.9642739 -0.267968 -0.111975364 0.080498695 0.18250056 -0.50969726 -0.038948275 1.4990776 -0.45593098 0.46518028 -0.21779078 -1.0096109 0.44302204 -0.0020319715 -0.13697644 -0.0578765 0.5463073 0.21956684 0.20734572 0.6802326 -0.21135618 0.44691655 0.19050884 0.30337313 -0.6096079 -0.33108398 0.4225432 -0.77365184 1.0793926 0.7922296 -0.7225973 0.24357857 0.18113536 -0.36191383 0.18167719 0.14839329 -0.0743996 0.49386397 -0.12899995 -0.13885956 -0.044082634
# title -0.7134001 -0.20797016 0.17948902 -0.71507984 -0.3032715 -0.31222177 0.40025848 -0.0017812912 0.2590879 -0.6468484 -0.379392 0.1737787 -0.6291506 0.1440601 0.634521 0.5635783 0.3133506 0.8861862 -0.3766695 0.4143574 -0.75693774 -0.43544292 0.8226477 0.36049163 -0.29808596 0.3054206 0.69767493 1.0025102 0.0840795 0.33725673 0.31241724 -0.3199852 -0.14537004 -0.011839251 0.09056578 0.8242553 -0.6823714 -0.42353725 0.2863509 -0.72629786 0.8873259 0.96500874 0.6064051 0.5476642 0.06879384 0.58614403 0.44003236 0.4283124 -0.772944 -0.19054082 0.652727 0.51821566 0.46052852 0.028407793 0.35917318 0.41422358 0.3631944 0.31972268 0.24441329 -0.14146107 -0.5072123 -0.25946677 -0.25435865 -0.15528232 -0.51776284 -0.22844112 -0.14111552 0.5009978 -0.7212176 -0.4098923 0.3709525 0.7281602 0.038720306 0.5831174 0.35268262 0.17268802 -0.23973753 0.25018522 1.4492229 0.22228816 -0.17850505 0.43573898 -0.2425121 -0.27419937 -0.25944626 -0.09548501 0.17195436 -0.2278042 0.6165642 -0.20713958 -0.02743033 -0.024736814 -0.3566568 -0.1289493 0.048597924 -0.9011441 0.19779074 0.39398506 -0.5758505 -0.20166637 -0.40519354 -0.3593298 -0.5044171 -0.6193228 -0.09400823 -0.37501058 0.21066457 -0.017246574 -0.6649673 -0.026782757 -0.7481882 -0.38152912 0.29194382 0.26569167 0.33160982 0.108679995 -1.0565636 -0.026549546 -0.3763076 -0.31117344 0.5686845 0.85357845 0.35231292 -0.10016631 0.8546451 0.19128776 0.31109926 0.32668638 -0.12705113 -0.38182995 -0.13635725 0.09319139 0.25599536 0.059299543 -0.12398807 0.20490287 0.34860474 -0.44091833 -0.25627548 -0.057552192 0.2976474 0.43457243 -0.10874688 0.35072798 0.22959547 0.019211754 0.17226043 0.45437285 0.1322553 -0.31031013 -0.38234794 0.375753 -0.1449302 -0.16099375 -0.3337744 0.05624227 -0.46763843 -0.085581705 -0.18520756 0.45212224 0.21247853 0.072024025 -0.17883182 0.5413705 -0.00372476 0.16140413 0.6081223 -0.7482766 -0.2659826 -0.19209844 0.07321419 -0.7663294 -0.5940212 0.013528964 -0.010967395 0.33437765 -0.38987043 0.2821758 0.90641487 0.2203147 0.11991344 -0.35458174 0.2226243 -0.06892481 -0.101484284 -0.4699583 -0.44449297 0.5721138 0.18233043 -0.32513902 0.33132058 0.17928466 -0.87174326 -0.14608204 -0.12172955 0.14260273 -0.073354386 0.5931867 -0.5399656 0.18994237
# uninterested -0.39900294 -0.37193817 -0.4313535 -0.6145361 0.082925245 -0.18918079 0.02726491 0.13527781 -0.056745913 -0.6915329 -1.1851085 -0.73251235 -0.37643465 0.3683787 0.8464806 0.14765544 -1.0781043 -0.8449356 0.17780629 0.42427328 0.17994247 -1.3359665 -0.20314407 -0.84743804 0.65880096 0.22030333 0.22514385 0.43840358 -0.36288753 -1.3210266 -0.07304816 0.049872104 -0.4518004 0.6586006 0.015458883 -0.8364793 -0.24209549 -0.120136835 -0.20483553 -0.65112305 -0.07720616 0.76840276 0.07281088 -0.49844742 0.06694531 -0.07255657 1.2179376 0.5481352 0.1337996 0.12768903 -0.8905191 0.5049863 -0.06619491 -0.2413304 -0.37937897 0.17726141 0.817688 -0.28397858 -0.19279605 0.36739513 -0.14642549 -0.8296049 -0.06685457 -0.57731694 -0.4080745 -0.5667594 -0.7786277 0.7201031 0.116968006 0.7040894 0.3983636 -0.14846231 0.6895321 -0.73513496 0.33055243 0.5475403 -0.94369936 1.6963363 -0.27677813 0.18523304 -1.2024673 0.5779915 0.34451726 0.9465338 -1.9434098 -0.25384375 0.9730578 0.41899765 -0.4294327 -0.52708936 -0.09636092 0.69178385 -0.30612466 -0.05810719 0.48082128 -1.0411193 0.08236622 -0.036190566 1.0337145 0.45466894 -1.0918036 -0.47401375 0.22601102 -1.5710887 1.0057586 -0.3577494 0.45468917 -0.1511488 -1.1939093 0.8006246 0.23754583 0.8447562 0.420789 0.29374412 -0.33665755 -0.25025222 0.11522905 0.13955414 0.046918303 -0.10027611 0.5554204 0.40692344 0.72539836 -0.86429477 0.031192303 0.39921916 1.1834638 1.8333603 0.8842657 -0.4788058 0.4187359 0.0391672 -0.04483981 0.1257582 -0.109702624 -0.621246 -0.0022701982 0.17404345 -0.017260125 -0.18840241 -1.4276197 -0.42236042 -0.09635439 -0.791746 -0.68495965 -0.65535384 0.2907375 0.2556657 0.61702657 0.55694824 0.042006444 0.16961841 -0.18810438 0.46129435 -0.4366097 0.50789064 0.55277795 -1.8215114 -1.0858312 -0.5017083 -0.44980454 -1.2084924 -0.3598524 -0.62125075 -1.4149532 0.6258062 -0.7584462 -0.85724247 0.23250313 -0.8199624 -0.06360613 0.35453326 0.08023884 -0.47803503 0.13284108 0.20656349 -0.5160354 -0.08976706 0.1648432 -0.80969316 -0.689165 -0.030851128 0.06089607 0.49977586 -0.07404002 0.9778152 0.1576816 0.21519405 0.27098742 0.62541795 0.21110071 1.2244055 -0.16774382 0.14739749 -0.648147 1.0874995 -0.5850677 -0.855666 -0.45408553 -0.15231337
# subarctic 0.25175595 -0.074168906 -0.92318 -0.72034365 1.0861945 -0.35229883 -0.35419318 0.5308225 -0.08260899 -0.74749005 -0.0093813045 0.18028885 -0.20137343 -1.1567358 0.055745795 -0.3537824 -0.8695409 0.444132 -0.34884652 1.1859671 0.6109689 0.0021081252 -0.25650632 0.5808047 0.49093893 0.002669208 0.40885195 -0.45975885 0.38183874 1.0580523 0.8482112 1.0921116 0.067872874 -0.46661898 0.16044602 -0.04546797 1.0170528 -0.10132263 0.40200123 0.603787 -0.14840959 -0.90636307 1.0012828 -0.36303863 -0.93596286 -0.42027438 -0.0381679 -0.593154 0.49160793 -0.6359328 -0.28853816 0.90043813 -0.020494053 -0.5066765 0.40234405 0.41710818 -0.067238525 0.008749249 0.6458443 0.4610884 -0.7708164 0.2717271 0.10804861 -0.67670375 0.6880663 -0.3205142 -0.24371001 0.23330986 -0.455661 0.35503456 0.95182574 0.13023573 0.5223468 -0.64498395 -0.65473115 -0.6955169 0.23811787 1.4082851 0.5139533 1.3654512 0.6136028 0.75182086 0.4308603 -0.64048064 -0.07235073 -0.5122467 -0.21214354 -0.25814256 -1.0084443 -1.0557662 -0.18354775 0.85232854 0.44345897 -0.075850956 0.6898944 -0.45069766 -0.14226648 0.15719369 -0.5716593 -1.2567464 -0.32760876 -0.8434994 0.48494506 -0.8053399 0.42927036 -0.89889 0.4629219 0.15338814 -0.9645404 -0.37298477 0.7266167 0.20417583 0.11531914 0.21387686 -0.50653476 0.27440244 -0.45270076 0.6247251 -0.9921181 -0.5499465 0.22547533 0.9060166 0.478757 0.013283973 0.1683982 -0.456511 1.1154294 0.37666464 -0.5131949 0.37618992 0.31472012 0.21041043 0.7756408 0.08284441 0.3940325 0.51491857 0.574017 0.11250369 -0.7463295 0.37374926 -0.5028738 0.7404184 0.45544994 0.49334773 0.02406268 -0.18520044 0.5380378 -0.15264337 -0.2813482 -0.6608035 0.7298472 1.0279564 0.99390733 0.07710472 -0.33888757 -0.32013512 0.54065686 -1.2727531 1.1716479 -0.25435048 0.62330306 -0.23763634 0.18444932 -0.51564133 -1.3132333 -0.066851296 -0.7074138 -0.6898807 -0.004782981 0.32632306 0.4605523 0.931041 0.76130134 -0.7109434 -0.012439225 -1.1465285 0.3701493 -0.3333737 0.4146212 -0.80614585 -0.019977279 -0.7751153 -0.90943325 -0.41633773 -0.15368952 0.0070553906 0.5571284 0.4245499 -0.23948306 -0.12848993 0.4177114 -0.27515104 -0.5952529 1.2469847 1.2526946 -0.008264075 -0.07555379 0.1695432 0.708274 -0.48219195

# %%
counta = 0
countb = 0
countc = 0
countd = 0
counte = 0
countz = 0

# %%
def get_word_vector_wordnet(w, added_words,E,stemmedE, vocab):
#     vocab = V.keys()
    if w in added_words:
        return E[w]
    else:
        vec = None
        print(f'{w} not in vocab')
        found = False
        ps = PorterStemmer()
        # find stemmed word in vocab
        stemmed_word = ps.stem(w)
        if stemmed_word in vocab:
            vec = w + ' ' + vocab[stemmed_word] + '\n'
        
            print(f'!!found stemmed {w}')
            return E[stemmed_word]
            found = True
#             countd += 1
        
        manual_stemmed_word = manual_stem(w)
        if manual_stemmed_word and manual_stemmed_word in vocab:
            vec = w + ' ' + vocab[manual_stemmed_word] + '\n'
            print(f'!!found manually stemmed {manual_stemmed_word} for {w}')
            return E[manual_stemmed_word]
            found = True
#           countd += 1
        if stemmed_word in stemmedE.keys():
            return stemmedE[stemmed_word]

        # find synonyms in vocab
        synonyms = wn.synsets(w)
        stemmed_synonyms = wn.synsets(stemmed_word)
        addl_stemmed_synonyms = []
        if manual_stemmed_word:
            addl_stemmed_synonyms = wn.synsets(manual_stemmed_word)
        synonyms += stemmed_synonyms + addl_stemmed_synonyms
        if not found:
            for synonym in synonyms:
                word = synonym.lemmas()[0].name()
                if word in vocab:
                    vec = w + ' ' + vocab[word] + '\n'
                    print(f'!!found syn {word}')
                    return E[word]
                    found = True
#                     counta += 1
                    break
        
        # find 1st level hyponyms of all synonyms
        if not found:
            for synonym in synonyms:    
                hyponyms = synonym.hyponyms()
                for hyponym in hyponyms:
                    hyponym_word = hyponym.lemmas()[0].name()
                    if hyponym_word in vocab:
                        vec = w + ' ' + vocab[hyponym_word] + '\n'
                        print(f'!!found 1st level hyponym {hyponym_word}')
                        return E[hyponym_word]
                        found = True
#                         countb += 1
                        break
        
        # find 1st level hypernyms of all synonyms
        if not found:
            for synonym in synonyms:
                hypernyms = synonym.hypernyms()
                for hypernym in hypernyms:
                    hypernym_word = hypernym.lemmas()[0].name()
                    if hypernym_word in vocab:
                        vec = w + ' ' + vocab[hypernym_word] + '\n'
                        print(f'!!found 1st level hypernym {hypernym_word}')
                        return E[hypernym_word]
                        found = True
#                         countc += 1
                        break
        
        # find all hyponyms recursively, for all synonyms
        if not found:
            for synonym in synonyms:
                all_hyponyms = [w for s in synonym.closure(lambda s:s.hyponyms()) for w in s.lemma_names()]
                for hyponym_word in all_hyponyms:
                    stemmed_word = ps.stem(hyponym_word)
                    if hyponym_word in vocab:
                        vec = w + ' ' + vocab[hyponym_word] + '\n'
                        print(f'!!found hyponym {hyponym_word} for {w}')
                        return E[hyponym_word]
                        found = True
#                         countb += 1
                        break
                    elif stemmed_word in vocab:
                        vec = w + ' ' + vocab[stemmed_word] + '\n'
                        print(f'!!found hyponym {stemmed_word} for {w}')
                        return E[stemmed_word]
                        found = True
#                         countb += 1
                        break

        # find all hypernyms recursively, for all synonyms
        if not found:
            for synonym in synonyms:
                all_hypernyms = [w for s in synonym.closure(lambda s:s.hypernyms()) for w in s.lemma_names()]
                for hypernym_word in all_hypernyms:
                    stemmed_word = ps.stem(hypernym_word)
                    if hypernym_word in vocab:
                        vec = w + ' ' + vocab[hypernym_word] + '\n'
                        print(f'!!found hypernym {hypernym_word} for {w}')
                        return E[hypernym_word]
                        found = True
#                         countc += 1
                        break 
                    elif stemmed_word in vocab:
                        vec = w + ' ' + vocab[stemmed_word] + '\n'
                        print(f'!!found hypernym {stemmed_word} for {w}')
                        return E[stemmed_word]
                        found = True
#                         countc += 1
                        break
    
        if not found:
            for synonym in synonyms:
                antonyms = synonym.lemmas()[0].antonyms()
                for antonym in antonyms:
                    antonym_word = antonym.name()
                    stemmed_word = ps.stem(antonym_word)
                    if antonym_word in vocab:
                        vec = w + ' ' + vocab[antonym_word] + '\n'
                        print(f'!!found antonym {antonym_word} for {w}')
                        return E[antonym_word]
                        found = True
#                         countz += 1
                        break
                    elif stemmed_word in vocab:
                        vec = w + ' ' + vocab[stemmed_word] + '\n'
                        print(f'!!found antonym {stemmed_word} for {w}')
                        return E[stemmed_word]
                        found = True
#                         countz += 1
                        break
                        

        if not found:
#             vec = w + unk_vector[5:] + ''
#             print(f'syn not found for {w}')
# #             counte += 1
            return E['<UNK>']
#         return [float(i) for i in vec.split()[1:]]

# %%
def get_dev_similarity_wordnet(embed_path, output_path):
    def read_embedding(path):
        embedding = {}
        stemmed_embedding = {}
        dim = None
        for row in open(path):
            word, *vector = row.split()
#             try:
            embedding[word] = [float(x) for x in vector]
#             except:
#                 continue
            stemmed_word = ps.stem(word)
            stemmed_embedding[stemmed_word] = [float(x) for x in vector]

            if dim and len(vector) != dim:

                print("Inconsistent embedding dimensions!", file = sys.stderr)
                sys.exit(1)

            dim = len(vector)

        return embedding, stemmed_embedding,dim
    

    E, stemmedE, dim = read_embedding(embed_path)
    pairs = pd.read_csv("data/similarity/dev_x.csv", index_col = "id")
    #build the embedded word collection from the test set
    added_words = []
    vocab = {}
    unk_vector = ""
    words = set(pairs.word1).union(pairs.word2)
    for row in open(embed_path):

        word, *vec = row.split()
        vocab[word] = ' '.join(vec)

        if word in words:
#             print(row, end = "")
            added_words.append(word)
        elif word == '<UNK>':
            unk_vector = row

    

    cal_similarity = []
    for w1, w2 in zip(pairs.word1, pairs.word2):
        #first process
        w1 = preprocess_word(w1)
        w2 = preprocess_word(w2)
        #find the embedding, if the word not directly exist in the embedding, try to identify a synomon 
        cur1 = get_word_vector_wordnet(w1, added_words,E,stemmedE,vocab)
        cur2 = get_word_vector_wordnet(w2, added_words,E,stemmedE,vocab)
#         print(len(cur1)
#         print(cur2)
#         print(np.dot(np.array(cur1), np.array(cur2)))
        cal_similarity.append(float(np.dot(np.array(cur1), np.array(cur2))))
    pairs["similarity"] = cal_similarity
    
#     print(cal_similarity)
    # [np.dot(E[w1], E[w2])
    #     for w1, w2 in zip(pairs.word1, pairs.word2)]

    del pairs["word1"], pairs["word2"]

    # print("Detected a", dim, "dimension embedding.", file = sys.stderr)
    pairs.to_csv(output_path)

# %%
# "lisztian" in vocab

# %%
get_dev_similarity_wordnet("embedding_4.txt", "adjusted_dev_prediction_4.csv")
# Out:
# fbi not in vocab
# !!found stemmed fbi
# opec not in vocab
# !!found stemmed opec
# mars not in vocab
# !!found stemmed mars
# jerusalem not in vocab
# !!found stemmed jerusalem
# palestinian not in vocab
# !!found stemmed palestinian
# jerusalem not in vocab
# !!found stemmed jerusalem
# israel not in vocab
# !!found stemmed israel
# wednesday not in vocab
# !!found stemmed wednesday
# harvard not in vocab
# !!found stemmed harvard
# yale not in vocab
# !!found stemmed yale
# japanese not in vocab
# !!found stemmed japanese
# american not in vocab
# !!found stemmed american
# arafat not in vocab
# !!found stemmed arafat
# jackson not in vocab
# !!found stemmed jackson
# arafat not in vocab
# !!found stemmed arafat
# mexico not in vocab
# !!found stemmed mexico
# brazil not in vocab
# !!found stemmed brazil
# fbi not in vocab
# !!found stemmed fbi
# opec not in vocab
# !!found stemmed opec
# arafat not in vocab
# !!found stemmed arafat
# mars not in vocab
# !!found stemmed mars
# freud not in vocab
# !!found stemmed freud
# antecedent not in vocab
# maradona not in vocab
# !!found stemmed maradona
# cd not in vocab
# !!found stemmed cd

# %%
evaluate_correlation("adjusted_dev_prediction_4.csv")
# Out:
# Correlation: 0.3771302835484122

# %% [markdown]
# ## test similarity generation with wordnet

# %%
def get_test_similarity_wordnet(embed_path, output_path):
    def read_embedding(path):
        embedding = {}
        stemmed_embedding = {}
        dim = None
        for row in open(path):
            word, *vector = row.split()
#             try:
            embedding[word] = [float(x) for x in vector]
#             except:
#                 continue
            stemmed_word = ps.stem(word)
            stemmed_embedding[stemmed_word] = [float(x) for x in vector]

            if dim and len(vector) != dim:

                print("Inconsistent embedding dimensions!", file = sys.stderr)
                sys.exit(1)

            dim = len(vector)

        return embedding, stemmed_embedding,dim
    

    E, stemmedE, dim = read_embedding(embed_path)
    pairs = pd.read_csv("data/similarity/test_x.csv", index_col = "id")
    #build the embedded word collection from the test set
    added_words = []
    vocab = {}
    unk_vector = ""
    words = set(pairs.word1).union(pairs.word2)
    for row in open(embed_path):

        word, *vec = row.split()
        vocab[word] = ' '.join(vec)

        if word in words:
#             print(row, end = "")
            added_words.append(word)
        elif word == '<UNK>':
            unk_vector = row

    

    cal_similarity = []
    for w1, w2 in zip(pairs.word1, pairs.word2):
        #first process
        w1 = preprocess_word(w1)
        w2 = preprocess_word(w2)
        #find the embedding, if the word not directly exist in the embedding, try to identify a synomon 
        cur1 = get_word_vector_wordnet(w1, added_words,E,stemmedE,vocab)
        cur2 = get_word_vector_wordnet(w2, added_words,E,stemmedE,vocab)
#         print(len(cur1)
#         print(cur2)
#         print(np.dot(np.array(cur1), np.array(cur2)))
        cal_similarity.append(float(np.dot(np.array(cur1), np.array(cur2))))
    pairs["similarity"] = cal_similarity
    
#     print(cal_similarity)
    # [np.dot(E[w1], E[w2])
    #     for w1, w2 in zip(pairs.word1, pairs.word2)]

    del pairs["word1"], pairs["word2"]

    # print("Detected a", dim, "dimension embedding.", file = sys.stderr)
    pairs.to_csv(output_path)

# %%
get_test_similarity_wordnet("embedding_4.txt", "results/adjusted_test_prediction_4.csv")
# test_similarity_geneartion("embedding_4.txt", "results/test_prediction_4.csv")
# Out:
# squishing not in vocab
# !!found stemmed squishing
# undatable not in vocab
# provincialism not in vocab
# narrowmindedness not in vocab
# !!found stemmed narrowmindedness
# provincialism not in vocab
# instrumentality not in vocab
# !!found stemmed instrumentality
# instrumentality not in vocab
# !!found stemmed instrumentality
# ecclesiastic not in vocab
# carbonic not in vocab
# !!found stemmed carbonic
# carbonic not in vocab
# !!found stemmed carbonic
# aspirate not in vocab
# aspirate not in vocab
# incommensurable not in vocab
# cognizance not in vocab
# urbanize not in vocab
# !!found stemmed urbanize
# ungraceful not in vocab
# !!found syn graceless
# colorblind not in vocab
# !!found stemmed colorblind
# naturalise not in vocab
# antifeminism not in vocab
# !!found 1st level hypernym sexism
#  not in vocab
# wrongdoer not in vocab
# transgress not in vocab
# intentionality not in vocab
# !!found stemmed intentionality
# inelegance not in vocab
# preliterate not in vocab
# preliterate not in vocab
# noncivilized not in vocab
# !!found antonym civilized for noncivilized
# retrying not in vocab
# unfeathered not in vocab
# !!found antonym feathered for unfeathered
# unfledged not in vocab
# !!found syn fledgling
# unfeathered not in vocab
# !!found antonym feathered for unfeathered
# eavesdropper not in vocab
# !!found 1st level hyponym tapper
# monocultures not in vocab
# calcify not in vocab
# calcify not in vocab
# disinheritance not in vocab
# !!found stemmed disinheritance
# discontinuance not in vocab
# interwove not in vocab
# !!found syn weave
# cession not in vocab
# !!found 1st level hyponym recession
# relinquishment not in vocab
# !!found stemmed relinquishment
# dwarfish not in vocab
# !!found manually stemmed dwarf for dwarfish
# circumferential not in vocab
# unisons not in vocab
# !!found stemmed unisons
# unisons not in vocab
# !!found stemmed unisons
# unaccessible not in vocab
# !!found syn inaccessible
# pathless not in vocab
# opalescence not in vocab
# estrogenic not in vocab
# !!found stemmed estrogenic
# consubstantial not in vocab
# condescend not in vocab
# ruralist not in vocab
# !!found syn countryman
# ruralist not in vocab
# !!found syn countryman
# conjurors not in vocab
# !!found stemmed conjurors
# analogize not in vocab
# !!found stemmed analogize
# hypercoaster not in vocab
# !!found hypernym elevated for hypercoaster
# hypermarket not in vocab
# confluent not in vocab
# !!found syn feeder
# confluent not in vocab
# !!found syn feeder
# anterooms not in vocab
# !!found 1st level hypernym room
# reargue not in vocab
# summonings not in vocab
# !!found stemmed summonings
# summonings not in vocab
# !!found stemmed summonings
# predetermine not in vocab
# concavity not in vocab
# concavity not in vocab
# unzipping not in vocab
# !!found stemmed unzipping
# unfasten not in vocab
# containerful not in vocab
# !!found stemmed containerful
# partible not in vocab
# inscribe not in vocab
# virginals not in vocab
# !!found stemmed virginals
# hypertexts not in vocab
# !!found stemmed hypertexts
# inelasticity not in vocab
# conformism not in vocab
# !!found stemmed conformism
# interlink not in vocab
# intercommunicate not in vocab
# interlink not in vocab
# unicycles not in vocab
# unicycles not in vocab
# preservers not in vocab
# preservers not in vocab
# autografts not in vocab
# !!found 1st level hypernym graft
# encrust not in vocab
# encrust not in vocab
# intraspecific not in vocab
# !!found syn intraspecies
# restrainer not in vocab
# !!found stemmed restrainer
# extravert not in vocab
# extroversive not in vocab
# sheikhdoms not in vocab
# !!found syn sheikdom
# discontinuous not in vocab
# disjunct not in vocab
# impotently not in vocab
# !!found manually stemmed impotent for impotently
# deviationism not in vocab
# !!found stemmed deviationism
# capitation not in vocab
# denominate not in vocab
# narrowminded not in vocab
# disfavoring not in vocab
# !!found stemmed disfavoring
# anticyclones not in vocab
# repositions not in vocab
# repositions not in vocab
# librarianship not in vocab
# !!found 1st level hypernym position
# semiconducting not in vocab
# entreaty not in vocab
# constitutive not in vocab
# !!found stemmed constitutive
# kindergarteners not in vocab
# !!found stemmed kindergarteners
# defiles not in vocab
# defiles not in vocab
# criticality not in vocab
# !!found stemmed criticality
# criticality not in vocab
# !!found stemmed criticality
# presuppose not in vocab
# presuppose not in vocab
# companionships not in vocab
# !!found stemmed companionships
# maildrop not in vocab
# !!found 1st level hypernym drop
# antedating not in vocab
# !!found syn predate
# chronologize not in vocab
# contrastive not in vocab
# !!found stemmed contrastive
# contrastive not in vocab
# !!found stemmed contrastive
# antonymous not in vocab
# !!found stemmed antonymous
# baseness not in vocab
# !!found stemmed baseness
# snookered not in vocab
# !!found stemmed snookered
# snookered not in vocab
# !!found stemmed snookered
# flimflam not in vocab
# !!found stemmed flimflam
# illimitable not in vocab
# inroad not in vocab
# territorials not in vocab
# territorials not in vocab
# recreate not in vocab
# transmigrating not in vocab
# !!found syn reincarnate
# transmigrating not in vocab
# !!found syn reincarnate
# autobiographer not in vocab
# wholeheartedness not in vocab
# !!found stemmed wholeheartedness
# replications not in vocab
# replications not in vocab
# retrials not in vocab
# !!found stemmed retrials
# venders not in vocab
# !!found syn seller
# interlinks not in vocab
# intercommunicate not in vocab
# interlinks not in vocab
# repulses not in vocab
# repulses not in vocab
# humanness not in vocab
# !!found stemmed humanness
# hybridise not in vocab
# parallelism not in vocab
# !!found stemmed parallelism
# sightedness not in vocab
# !!found stemmed sightedness
# dreadnought not in vocab
# !!found 1st level hypernym battleship
# overshoe not in vocab
# !!found 1st level hyponym arctic
# sufferance not in vocab
# !!found stemmed sufferance
# monoplanes not in vocab
# hyperextension not in vocab
# !!found 1st level hypernym extension
# amazings not in vocab
# amazings not in vocab
# transmissible not in vocab
# transmissible not in vocab
# inheritable not in vocab
# !!found stemmed inheritable
# magnetize not in vocab
# !!found stemmed magnetize
# magnetize not in vocab
# !!found stemmed magnetize
# translocate not in vocab
# macroevolution not in vocab
# !!found 1st level hypernym evolution
# adventism not in vocab
# !!found stemmed adventism
# transgress not in vocab
# speculativeness not in vocab
# associational not in vocab
# associational not in vocab
# irremovable not in vocab
# !!found antonym removable for irremovable
# monsignori not in vocab
# !!found 1st level hypernym priest
# macrocosmic not in vocab
# !!found syn universe
# containerful not in vocab
# !!found stemmed containerful
# instructorship not in vocab
# !!found 1st level hypernym position
# enunciating not in vocab
# enunciating not in vocab
# caramelize not in vocab
# !!found stemmed caramelize
# causative not in vocab
# undisputable not in vocab
# subserve not in vocab
# religionist not in vocab
# warmness not in vocab
# !!found stemmed warmness
# protectiveness not in vocab
# !!found stemmed protectiveness
# warmness not in vocab
# !!found stemmed warmness
# cardinality not in vocab
# !!found stemmed cardinality
# circumvolution not in vocab
# !!found 1st level hypernym rotation
# totalism not in vocab
# !!found stemmed totalism
# absorbance not in vocab
# !!found stemmed absorbance
# disjoined not in vocab
# !!found 1st level hypernym separate
# irreproducible not in vocab
# !!found antonym reproducible for irreproducible
# entraps not in vocab
# !!found stemmed entraps
# entraps not in vocab
# !!found stemmed entraps
# anamorphosis not in vocab
# !!found 1st level hypernym evolution
# anamorphosis not in vocab
# !!found 1st level hypernym evolution
# dispersive not in vocab
# smoothen not in vocab
# obtainment not in vocab
# !!found stemmed obtainment
# protraction not in vocab
# endurable not in vocab
#  not in vocab
# impossibilities not in vocab
# unattainableness not in vocab
# unmentionables not in vocab
# walloper not in vocab
# !!found stemmed walloper
# conformations not in vocab
# !!found stemmed conformations
# conformations not in vocab
# !!found stemmed conformations
# highjacking not in vocab
# !!found syn commandeer
# highjacking not in vocab
# !!found syn commandeer
# leagued not in vocab
# inversions not in vocab
# inversions not in vocab
# impoliteness not in vocab
# initialise not in vocab
# !!found syn format
# initialise not in vocab
# !!found syn format
# reenactor not in vocab
# ulcerate not in vocab
# !!found stemmed ulcerate
# ulcerate not in vocab
# !!found stemmed ulcerate
# incorrupt not in vocab
# bestowals not in vocab
# !!found stemmed bestowals
# bestowals not in vocab
# !!found stemmed bestowals
# undeviating not in vocab
# undeviating not in vocab
# unmarketable not in vocab
# deflowering not in vocab
# !!found syn mar
# innovativeness not in vocab
# impulsion not in vocab
# impulsion not in vocab
# unisexual not in vocab
# rearrangements not in vocab
# insatiate not in vocab
# interrelate not in vocab
# synthetical not in vocab
# entombment not in vocab
# !!found stemmed entombment
# discipleship not in vocab
# !!found 1st level hypernym position
# vaporise not in vocab
# vaporise not in vocab
# mercifulness not in vocab
# !!found stemmed mercifulness
# preposed not in vocab
# !!found 1st level hypernym put
# prophetical not in vocab
# !!found stemmed prophetical
# excitations not in vocab
# excitations not in vocab
# attributions not in vocab
# concerti not in vocab
# !!found syn concerto
# reformism not in vocab
# !!found stemmed reformism
# baste not in vocab
# !!found stemmed baste
# intermingles not in vocab
# commingle not in vocab
#  not in vocab
# nonconscious not in vocab
# nonconscious not in vocab
# unstuff not in vocab
# !!found 1st level hyponym unblock
# rhythmicity not in vocab
# !!found stemmed rhythmicity
# significances not in vocab
# eruptive not in vocab
# !!found stemmed eruptive
# eruptive not in vocab
# !!found stemmed eruptive
# aqueous not in vocab
# transvestitism not in vocab
# conscripting not in vocab
# !!found stemmed conscripting
# depopulate not in vocab
# nonindulgent not in vocab
# !!found antonym indulgent for nonindulgent
# viscometry not in vocab
# !!found 1st level hypernym measurement
# rundown not in vocab
# !!found stemmed rundown
# prayerful not in vocab
# !!found stemmed prayerful
# bestowal not in vocab
# !!found stemmed bestowal
# bestowal not in vocab
# !!found stemmed bestowal
# ingroup not in vocab
# comfortless not in vocab
# therapeutical not in vocab
# therapeutical not in vocab
# transmigrated not in vocab
# !!found syn reincarnate
# infeasible not in vocab
# !!found syn impracticable
# rhymers not in vocab
# !!found 1st level hypernym writer
# covariant not in vocab
# postposition not in vocab
# !!found 1st level hypernym place
# wreathe not in vocab
# !!found stemmed wreathe
# expressible not in vocab
# !!found stemmed expressible
# representable not in vocab
# !!found stemmed representable
# unicyclist not in vocab
# !!found hypernym pedal for unicyclist
# pedaler not in vocab
# !!found stemmed pedaler
# spatiality not in vocab
# !!found stemmed spatiality
# resistor not in vocab
# pastorship not in vocab
# !!found 1st level hypernym position
# evangelicalism not in vocab
# cofactor not in vocab
# !!found 1st level hypernym compound
# unrealizable not in vocab
# !!found syn unachievable
# dissociations not in vocab
# dissociations not in vocab
# scarceness not in vocab
# changeableness not in vocab
# academicism not in vocab
# !!found stemmed academicism
# subhead not in vocab
# !!found 1st level hyponym title
# independences not in vocab
# independences not in vocab
# conductance not in vocab
# !!found stemmed conductance
# selffulfillment not in vocab
# algebraist not in vocab
# !!found 1st level hypernym mathematician
# encamping not in vocab
# !!found stemmed encamping
# prostatic not in vocab
# prostatic not in vocab
# remitting not in vocab
# !!found stemmed remitting
# premisses not in vocab
# !!found syn premise
# presuppose not in vocab
# premisses not in vocab
# !!found syn premise
# bluejacket not in vocab
# !!found 1st level hyponym striker
# seasonable not in vocab
# !!found stemmed seasonable
# moderatorship not in vocab
# !!found 1st level hypernym position
# demureness not in vocab
# !!found stemmed demureness
# objectifying not in vocab
# nonperformance not in vocab
# reckoner not in vocab
# !!found stemmed reckoner
# reckoner not in vocab
# !!found stemmed reckoner
# vegetational not in vocab
# vegetational not in vocab
# vocalism not in vocab
# !!found stemmed vocalism
# vocalism not in vocab
# !!found stemmed vocalism
# selfdiscipline not in vocab
# immoderate not in vocab
# !!found antonym moderate for immoderate
# ideality not in vocab
# !!found stemmed ideality
# momentousness not in vocab
# !!found stemmed momentousness
# affectional not in vocab
# !!found stemmed affectional
# rediscovery not in vocab
# !!found 1st level hypernym discovery
# microfossils not in vocab
# !!found 1st level hypernym fossil
# commandership not in vocab
# !!found 1st level hypernym position
# autoimmunity not in vocab
# secluding not in vocab
# containerful not in vocab
# !!found stemmed containerful
# brandnewness not in vocab
# !!found stemmed brandnewness
# circumscribes not in vocab
# internationaler not in vocab
# !!found stemmed internationaler
# heartlessness not in vocab
# !!found stemmed heartlessness
# carefreeness not in vocab
# procreated not in vocab
# sanctify not in vocab
# lustrate not in vocab
# !!found 1st level hypernym purify
# sanctify not in vocab
# restrainer not in vocab
# !!found stemmed restrainer
# restrainer not in vocab
# !!found stemmed restrainer
# heraldist not in vocab
# !!found syn heraldic
# heraldist not in vocab
# !!found syn heraldic
# cultist not in vocab
# traversals not in vocab
# !!found stemmed traversals
# traversals not in vocab
# !!found stemmed traversals
# posthole not in vocab
# !!found 1st level hypernym hole
# unilluminated not in vocab
# purchasable not in vocab
# purchasable not in vocab
# sternness not in vocab
# !!found stemmed sternness
# profitless not in vocab
# insurrectional not in vocab
# algebras not in vocab
# !!found stemmed algebras
# unvariedness not in vocab
# !!found stemmed unvariedness
# princedom not in vocab
# !!found syn principality
# princedom not in vocab
# !!found syn principality
# condescended not in vocab
# decompositions not in vocab
# decompositions not in vocab
# indirectness not in vocab
# !!found stemmed indirectness
# skillfulness not in vocab
# !!found stemmed skillfulness
# shortish not in vocab
# !!found manually stemmed short for shortish
# americanize not in vocab
# !!found stemmed americanize
# protectorship not in vocab
# !!found 1st level hypernym position
# convector not in vocab
# !!found 1st level hypernym heater
# subroutines not in vocab
# !!found syn routine
# outshout not in vocab
# microcircuit not in vocab
# !!found hypernym circuit for microcircuit
# intramolecular not in vocab
# incensing not in vocab
# incensing not in vocab
# odorize not in vocab
# !!found stemmed odorize
# embroiderers not in vocab
# !!found 1st level hyponym faggot
# embroideress not in vocab
# !!found 1st level hyponym faggot
# microflora not in vocab
# !!found 1st level hypernym microorganism
# importances not in vocab
# !!found stemmed importances
# importances not in vocab
# !!found stemmed importances
# circumnavigations not in vocab
# interrelationship not in vocab
# !!found 1st level hypernym relation
# psychodynamics not in vocab
# monoatomic not in vocab
# monoatomic not in vocab
# thermonuclear not in vocab
# undefinable not in vocab
# heterosexism not in vocab
# !!found 1st level hypernym discrimination
# sermonize not in vocab
# !!found stemmed sermonize
# combusted not in vocab
# !!found stemmed combusted
# swooshing not in vocab
# !!found stemmed swooshing
# unwaveringly not in vocab
# !!found manually stemmed unwavering for unwaveringly
# interlingua not in vocab
# !!found hypernym language for interlingua
# tricolours not in vocab
# !!found stemmed tricolours
# fictitiously not in vocab
# !!found manually stemmed fictitious for fictitiously
# fictitiously not in vocab
# !!found manually stemmed fictitious for fictitiously
# delimitations not in vocab
# !!found syn specify
# microfiche not in vocab
# !!found 1st level hypernym microfilm
# bewitchment not in vocab
# reburial not in vocab
# witchhunt not in vocab
# !!found stemmed witchhunt
# rascality not in vocab
# !!found stemmed rascality
# fractionate not in vocab
# !!found stemmed fractionate
# annihilator not in vocab
# inconvertible not in vocab
# !!found antonym convertible for inconvertible
# incommutable not in vocab
# !!found antonym commutable for incommutable
# dissatisfying not in vocab
# disgruntle not in vocab
# autograft not in vocab
# !!found 1st level hypernym graft
# democratize not in vocab
# !!found stemmed democratize
# unassertiveness not in vocab
# !!found 1st level hypernym diffidence
# spiritless not in vocab
# !!found syn meek
# sensualist not in vocab
# !!found 1st level hyponym bisexual
# unchaste not in vocab
# !!found antonym chaste for unchaste
# internationality not in vocab
# transgress not in vocab
# excitation not in vocab
# excitation not in vocab
# rectorate not in vocab
# !!found stemmed rectorate
# shortchange not in vocab
# procurators not in vocab
# procurators not in vocab
# assistances not in vocab
# !!found stemmed assistances
# assistances not in vocab
# !!found stemmed assistances
# unsubdivided not in vocab
# !!found syn simple
# implantations not in vocab
# !!found stemmed implantations
# implantations not in vocab
# !!found stemmed implantations
# translocating not in vocab
# corespondent not in vocab
# !!found 1st level hypernym codefendant
# monarchic not in vocab
# !!found stemmed monarchic
# syntactic not in vocab
# duplicable not in vocab
# adjustor not in vocab
# !!found syn adjuster
# depictive not in vocab
# !!found stemmed depictive
# romanic not in vocab
# !!found stemmed romanic
# interlaces not in vocab
# interlaces not in vocab
# immobilization not in vocab
# immobilization not in vocab
# subsequences not in vocab
# bibliographies not in vocab
# !!found 1st level hypernym list
# expensiveness not in vocab
# acronymic not in vocab
# !!found stemmed acronymic
# incoordination not in vocab
# !!found hypernym inability for incoordination
# unskillfulness not in vocab
# provisionary not in vocab
# !!found syn probationary
# promotive not in vocab
# asphaltic not in vocab
# !!found stemmed asphaltic
# asphaltic not in vocab
# !!found stemmed asphaltic
# emulsifying not in vocab
# knightly not in vocab
# !!found manually stemmed knight for knightly
# knightly not in vocab
# !!found manually stemmed knight for knightly
# monogenesis not in vocab
# !!found hypernym reproduction for monogenesis
# interlace not in vocab
# contraries not in vocab
# amethysts not in vocab
# !!found stemmed amethysts
# suspiciousness not in vocab
# vindictively not in vocab
# !!found manually stemmed vindictive for vindictively
# vindictively not in vocab
# !!found manually stemmed vindictive for vindictively
# uptodate not in vocab
# microwaving not in vocab
# managership not in vocab
# !!found 1st level hypernym position
# knowhow not in vocab
# !!found stemmed knowhow
# christianise not in vocab
# !!found 1st level hypernym convert
# evangelistic not in vocab
# !!found stemmed evangelistic
# emotionalism not in vocab
# !!found stemmed emotionalism
# differentia not in vocab
# !!found 1st level hypernym difference
# hallucinating not in vocab
# hallucinating not in vocab
# liverpools not in vocab
# !!found stemmed liverpools
# unparented not in vocab
# !!found antonym parented for unparented
# contrabands not in vocab
# !!found stemmed contrabands
# receiverships not in vocab
# !!found stemmed receiverships
# scandalize not in vocab
# !!found stemmed scandalize
# autobuses not in vocab
# !!found syn bus
# dematerialised not in vocab
# enlarger not in vocab
#  not in vocab
# localise not in vocab
# localise not in vocab
# animality not in vocab
# !!found stemmed animality
# interweaved not in vocab
# engorge not in vocab
# !!found syn gorge
# rooters not in vocab
# !!found 1st level hyponym aficionado
# autosuggestion not in vocab
# !!found hypernym improvement for autosuggestion
# selfimprovement not in vocab
# trichloride not in vocab
# !!found 1st level hypernym chloride
# excretion not in vocab
# excretion not in vocab
# defecation not in vocab
# conspicuousness not in vocab
# spangle not in vocab
# embroiderer not in vocab
# !!found 1st level hyponym faggot
# needleworker not in vocab
# !!found stemmed needleworker
# enforcements not in vocab
# singe not in vocab
# !!found stemmed singe
# postdated not in vocab
# !!found hypernym date for postdated
# clozapine not in vocab
# !!found hypernym antipsychotic for clozapine
# intensions not in vocab
# alarmism not in vocab
# !!found stemmed alarmism
# imbedding not in vocab
# transalpine not in vocab
# !!found 1st level hypernym foreigner
# disassociates not in vocab
# inexpert not in vocab
# !!found syn amateurish
# implicational not in vocab
# dissociable not in vocab
# abbreviate not in vocab
# nanosecond not in vocab
# !!found hypernym measure for nanosecond
# univocal not in vocab
# !!found syn unequivocal
# balminess not in vocab
# civilise not in vocab
# civilise not in vocab
# businessperson not in vocab
# !!found 1st level hyponym accountant
# interlinking not in vocab
# princedoms not in vocab
# !!found syn principality
# princedoms not in vocab
# !!found syn principality
# intermarry not in vocab
# !!found 1st level hypernym marry
# crosslink not in vocab
# !!found stemmed crosslink
# regionalisms not in vocab
# !!found stemmed regionalisms
# regionalisms not in vocab
# !!found stemmed regionalisms
# disinvestment not in vocab
# !!found syn divest
# transmuted not in vocab
# !!found syn transform
# baptistic not in vocab
# !!found stemmed baptistic
# clericalism not in vocab
# !!found stemmed clericalism
# irresolution not in vocab
# !!found syn indecision
# irresolution not in vocab
# !!found syn indecision
# transmutes not in vocab
# !!found syn transform
# transmutes not in vocab
# !!found syn transform
# transponder not in vocab
# copulate not in vocab
# gracefulness not in vocab
# !!found stemmed gracefulness
# bendability not in vocab
# prehistorical not in vocab
# transfusing not in vocab
# transfusing not in vocab
# circularize not in vocab
# !!found stemmed circularize
# circularize not in vocab
# !!found stemmed circularize
# formalisms not in vocab
# !!found stemmed formalisms
# formalisms not in vocab
# !!found stemmed formalisms
# interpenetrate not in vocab
# !!found syn permeate
# spiritize not in vocab
# !!found stemmed spiritize
# eldership not in vocab
# !!found 1st level hypernym position
# homophony not in vocab
# !!found 1st level hypernym pronunciation
# homophony not in vocab
# !!found 1st level hypernym pronunciation
# contrarily not in vocab
# !!found syn perversely
# copartnership not in vocab
# !!found 1st level hypernym partnership
#  not in vocab
# sportive not in vocab
# nurturance not in vocab
# microvolts not in vocab
# !!found stemmed microvolts
# asteroidal not in vocab
# !!found stemmed asteroidal
# asteroidal not in vocab
# !!found stemmed asteroidal
# talkativeness not in vocab
# !!found stemmed talkativeness
# communicativeness not in vocab
# abstractionist not in vocab
# abstractionist not in vocab
# merchantable not in vocab
# !!found stemmed merchantable
# syphons not in vocab
# !!found syn siphon
# syphons not in vocab
# !!found syn siphon
# organismal not in vocab
# !!found stemmed organismal
# sanctifying not in vocab
# spiritualize not in vocab
# subserving not in vocab
# cofactors not in vocab
# !!found 1st level hypernym compound
# combusting not in vocab
# !!found stemmed combusting
# combusting not in vocab
# !!found stemmed combusting
# auditive not in vocab
# !!found stemmed auditive
# auditive not in vocab
# !!found stemmed auditive
# florescence not in vocab
# !!found syn blossoming
# autopilots not in vocab
# !!found stemmed autopilots
# autopilots not in vocab
# !!found stemmed autopilots
# separationist not in vocab
# falsifier not in vocab
# deceiver not in vocab
# manacles not in vocab
# microcircuits not in vocab
# !!found hypernym circuit for microcircuits
# unshaped not in vocab
# trioxide not in vocab
# !!found 1st level hyponym arsenic
# despoil not in vocab
# blurting not in vocab
# !!found stemmed blurting
# positioners not in vocab
# !!found stemmed positioners
# actuator not in vocab
# inadvertence not in vocab
# inclosure not in vocab
# !!found syn enclosure
# inclosure not in vocab
# !!found syn enclosure
# regularize not in vocab
# !!found stemmed regularize
# regularize not in vocab
# !!found stemmed regularize
# interlayers not in vocab
# !!found 1st level hypernym layer
# microphallus not in vocab
# !!found 1st level hypernym penis
# gladness not in vocab
# !!found stemmed gladness
# disestablishing not in vocab
# slaughterers not in vocab
# !!found stemmed slaughterers
# corruptive not in vocab
# !!found stemmed corruptive
# autographic not in vocab
# !!found stemmed autographic
# autographic not in vocab
# !!found stemmed autographic
# predetermine not in vocab
# predetermine not in vocab
# autoregulation not in vocab
# !!found hypernym process for autoregulation
# incurved not in vocab
# synchronic not in vocab
# expounding not in vocab
# !!found stemmed expounding
# inharmonious not in vocab
# !!found antonym harmonious for inharmonious
# consultive not in vocab
# !!found stemmed consultive
# deposes not in vocab
# deposes not in vocab
# bastardize not in vocab
# !!found stemmed bastardize
# unspecialised not in vocab
# !!found syn unspecialized
# disarranged not in vocab
# !!found 1st level hyponym muss
# randomize not in vocab
# !!found stemmed randomize
# exaction not in vocab
# !!found stemmed exaction
# synoptic not in vocab
#  not in vocab
# infolding not in vocab
# !!found hypernym process for infolding
# fleshiness not in vocab
# censorships not in vocab
# !!found stemmed censorships
# censorships not in vocab
# !!found stemmed censorships
# depressor not in vocab
# depressor not in vocab
# greengrocery not in vocab
# fruiterer not in vocab
# unionise not in vocab
# unionise not in vocab
# reclassifications not in vocab
# embracement not in vocab
# autoloading not in vocab
# delimited not in vocab
# !!found syn specify
# insecureness not in vocab
# churchs not in vocab
# !!found stemmed churchs
# rediscovery not in vocab
# !!found 1st level hypernym discovery
# literalness not in vocab
# !!found stemmed literalness
# concreteness not in vocab
# !!found stemmed concreteness
# antifeminist not in vocab
# !!found 1st level hypernym bigot
# ascendence not in vocab
# !!found stemmed ascendence
# ropewalker not in vocab
# !!found 1st level hypernym aerialist
# precociously not in vocab
# !!found manually stemmed precocious for precociously
# precociously not in vocab
# !!found manually stemmed precocious for precociously
# indexical not in vocab
# !!found stemmed indexical
# crossindex not in vocab
# indexical not in vocab
# !!found stemmed indexical
# discoverys not in vocab
# discoverys not in vocab
# selfdiscovery not in vocab
# intercommunicate not in vocab
# nondescripts not in vocab
# !!found stemmed nondescripts
# uncreative not in vocab
# !!found antonym creative for uncreative
# schnauzer not in vocab
# !!found 1st level hypernym terrier
# microbalance not in vocab
# !!found 1st level hypernym balance
# subjoined not in vocab
# !!found hypernym tack for subjoined
# append not in vocab
# transfused not in vocab
# transfused not in vocab
# interchanging not in vocab
# interchanging not in vocab
# displeases not in vocab
# negociate not in vocab
# postdates not in vocab
# !!found hypernym date for postdates
# postdates not in vocab
# !!found hypernym date for postdates
# chronologize not in vocab
#  not in vocab
# stockers not in vocab
# !!found stemmed stockers
# hydrolysed not in vocab
# !!found 1st level hypernym change
# standin not in vocab
# !!found stemmed standin
# riskless not in vocab
# incombustible not in vocab
# !!found syn noncombustible
# rareness not in vocab
# !!found stemmed rareness
# algebraic not in vocab
# !!found stemmed algebraic
# quadratics not in vocab
# roosted not in vocab
# !!found stemmed roosted
# roosted not in vocab
# !!found stemmed roosted
# employments not in vocab
# !!found stemmed employments
# employments not in vocab
# !!found stemmed employments
# transposable not in vocab
# protractors not in vocab
# !!found hypernym instrument for protractors
# religiousness not in vocab
# religiousness not in vocab
# postholes not in vocab
# !!found 1st level hypernym hole
# irregardless not in vocab
# irregardless not in vocab
# subtend not in vocab
# !!found 1st level hypernym be
# subtend not in vocab
# !!found 1st level hypernym be
# inapplicability not in vocab
# desiccating not in vocab
# desiccating not in vocab
# transubstantiate not in vocab
# !!found syn transform
# internee not in vocab
# !!found syn intern
# preheating not in vocab
# !!found stemmed preheating
# unploughed not in vocab
# !!found syn unplowed
# untilled not in vocab
# syntaxes not in vocab
# !!found stemmed syntaxes
# syntaxes not in vocab
# !!found stemmed syntaxes
# ganging not in vocab
# !!found stemmed ganging
# reconstructs not in vocab
# !!found stemmed reconstructs
# inexpedient not in vocab
# !!found antonym expedient for inexpedient
# predetermination not in vocab
# destabilization not in vocab
# lusterware not in vocab
# !!found 1st level hypernym pottery
# enslaves not in vocab
# subjugate not in vocab
# carburettors not in vocab
# !!found stemmed carburettors
# perfectible not in vocab
# !!found stemmed perfectible
# concurrencies not in vocab
# concurrencies not in vocab
# internationalisms not in vocab
# internationalisms not in vocab
# cylindric not in vocab
# animalism not in vocab
# !!found stemmed animalism
# animalism not in vocab
# !!found stemmed animalism
# incised not in vocab
# incised not in vocab
# perfective not in vocab
# !!found stemmed perfective
# perfective not in vocab
# !!found stemmed perfective
# houseful not in vocab
# containerful not in vocab
# !!found stemmed containerful
# unostentatious not in vocab
# !!found syn understated
# combatted not in vocab
# !!found stemmed combatted
# eavesdropper not in vocab
# !!found 1st level hyponym tapper
# fieldworker not in vocab
# !!found stemmed fieldworker
# micrometer not in vocab
# !!found stemmed micrometer
# micrometer not in vocab
# !!found stemmed micrometer
# undissolved not in vocab
# refuels not in vocab
# !!found stemmed refuels
# sidewinder not in vocab
# sidewinder not in vocab
# federalize not in vocab
# !!found stemmed federalize
# casteless not in vocab
# animalize not in vocab
# !!found stemmed animalize
# reproves not in vocab
# !!found syn admonish
#  not in vocab
# allurement not in vocab
# allurement not in vocab
# binging not in vocab
# !!found stemmed binging
# trilogies not in vocab
# bobbers not in vocab
# !!found syn bob
# portrayer not in vocab
# !!found stemmed portrayer
# hardandfast not in vocab
# !!found stemmed hardandfast
# astringe not in vocab
# remounted not in vocab
# !!found stemmed remounted
# remounted not in vocab
# !!found stemmed remounted
# reviles not in vocab
# discountenance not in vocab
# !!found 1st level hypernym shame
# subspaces not in vocab
# congruity not in vocab
# !!found 1st level hypernym harmony
# insurrectionist not in vocab
# !!found syn insurgent
# triclinic not in vocab
# monoclinic not in vocab
# concurrency not in vocab
# concurrency not in vocab
# antitoxic not in vocab
# intragroup not in vocab
# !!found syn internal
# inconvertible not in vocab
# !!found antonym convertible for inconvertible

# %%
def get_reduced_embedding_wordnet(embed_path, output_path):
    def read_embedding(path):
        embedding = {}
        stemmed_embedding = {}
        dim = None
        for row in open(path):
            word, *vector = row.split()
            embedding[word] = [float(x) for x in vector]

            stemmed_word = ps.stem(word)
            stemmed_embedding[stemmed_word] = [float(x) for x in vector]

            if dim and len(vector) != dim:

                print("Inconsistent embedding dimensions!", file = sys.stderr)
                sys.exit(1)

            dim = len(vector)

        return embedding, stemmed_embedding,dim
    

    E, stemmedE, dim = read_embedding(embed_path)
    added_words = []
    vocab = {}
    unk_vector = ""
    for row in open(embed_path):

        word, *vec = row.split()
        vocab[word] = ' '.join(vec)

        if word in words:
            added_words.append(word)
        elif word == '<UNK>':
            unk_vector = row
    outfile = open(output_path, 'w')
    for word in words:
        w1 = preprocess_word(word)
        cur1 = get_word_vector_wordnet(w1, added_words,E,stemmedE,vocab)
        temp = "".join(word.split()) + ' '
        for value in cur1:
            temp = temp + str(value) + ' '
        temp += '\n'
        outfile.write(temp)
        
    outfile.close()

# %%
get_reduced_embedding_wordnet("embedding_4.txt", "adjusted_reduced_embedding_4.txt")
# Out:
# bobbers not in vocab
# !!found syn bob
# falsifier not in vocab
# crossindex not in vocab
# magnetize not in vocab
# !!found stemmed magnetize
# causative not in vocab
# microfiche not in vocab
# !!found 1st level hypernym microfilm
# synthetical not in vocab
# unfasten not in vocab
# anticyclones not in vocab
# depopulate not in vocab
# cofactor not in vocab
# !!found 1st level hypernym compound
# hypertexts not in vocab
# !!found stemmed hypertexts
# unskillfulness not in vocab
# blurting not in vocab
# !!found stemmed blurting
# amazings not in vocab
# standin not in vocab
# !!found stemmed standin
# translocate not in vocab
# dispersive not in vocab
# heterosexism not in vocab
# !!found 1st level hypernym discrimination
# interlaces not in vocab
# antonymous not in vocab
# !!found stemmed antonymous
# bestowal not in vocab
# !!found stemmed bestowal
# purchasable not in vocab
# outshout not in vocab
# chronologize not in vocab
# heartlessness not in vocab
# !!found stemmed heartlessness
# imbedding not in vocab
# remounted not in vocab
# !!found stemmed remounted
#  not in vocab
# macroevolution not in vocab
# !!found 1st level hypernym evolution
# inapplicability not in vocab
# encamping not in vocab
# !!found stemmed encamping
# undatable not in vocab
# expensiveness not in vocab
# internee not in vocab
# !!found syn intern
# syphons not in vocab
# !!found syn siphon
#  not in vocab
# binging not in vocab
# !!found stemmed binging
# churchs not in vocab
# !!found stemmed churchs
# embroideress not in vocab
# !!found 1st level hyponym faggot
# cultist not in vocab
# enunciating not in vocab
# federalize not in vocab
# !!found stemmed federalize
# postholes not in vocab
# !!found 1st level hypernym hole
# corruptive not in vocab
# !!found stemmed corruptive
# suspiciousness not in vocab
# independences not in vocab
# transmigrating not in vocab
# !!found syn reincarnate
# infolding not in vocab
# !!found hypernym process for infolding
# eruptive not in vocab
# !!found stemmed eruptive
# animalize not in vocab
# !!found stemmed animalize
# fruiterer not in vocab
# transvestitism not in vocab
# employments not in vocab
# !!found stemmed employments
# incorrupt not in vocab
# unmentionables not in vocab
# consubstantial not in vocab
# unshaped not in vocab
# intermingles not in vocab
# repulses not in vocab
# untilled not in vocab
# congruity not in vocab
# !!found 1st level hypernym harmony
# snookered not in vocab
# !!found stemmed snookered
# hypercoaster not in vocab
# !!found hypernym elevated for hypercoaster
# monarchic not in vocab
# !!found stemmed monarchic
# subtend not in vocab
# !!found 1st level hypernym be
# decompositions not in vocab
# premisses not in vocab
# !!found syn premise
# autobiographer not in vocab
# literalness not in vocab
# !!found stemmed literalness
# warmness not in vocab
# !!found stemmed warmness
# interrelationship not in vocab
# !!found 1st level hypernym relation
# interlinks not in vocab
# intermarry not in vocab
# !!found 1st level hypernym marry
# contrarily not in vocab
# !!found syn perversely
# ungraceful not in vocab
# !!found syn graceless
# incombustible not in vocab
# !!found syn noncombustible
# conscripting not in vocab
# !!found stemmed conscripting
# amethysts not in vocab
# !!found stemmed amethysts
# algebras not in vocab
# !!found stemmed algebras
# contrastive not in vocab
# !!found stemmed contrastive
# protractors not in vocab
# !!found hypernym instrument for protractors
# contrabands not in vocab
# !!found stemmed contrabands
# wednesday not in vocab
# !!found stemmed wednesday
# bastardize not in vocab
# !!found stemmed bastardize
# tricolours not in vocab
# !!found stemmed tricolours
# schnauzer not in vocab
# !!found 1st level hypernym terrier
# vocalism not in vocab
# !!found stemmed vocalism
# managership not in vocab
# !!found 1st level hypernym position
# innovativeness not in vocab
# unicyclist not in vocab
# !!found hypernym pedal for unicyclist
# traversals not in vocab
# !!found stemmed traversals
# inheritable not in vocab
# !!found stemmed inheritable
# inconvertible not in vocab
# !!found antonym convertible for inconvertible
# preservers not in vocab
# interlinking not in vocab
# selffulfillment not in vocab
# extravert not in vocab
# talkativeness not in vocab
# !!found stemmed talkativeness
# dissatisfying not in vocab
# embroiderers not in vocab
# !!found 1st level hyponym faggot
# reclassifications not in vocab
# venders not in vocab
# !!found syn seller
# sternness not in vocab
# !!found stemmed sternness
# translocating not in vocab
# postdates not in vocab
# !!found hypernym date for postdates
# transubstantiate not in vocab
# !!found syn transform
# unzipping not in vocab
# !!found stemmed unzipping
# defecation not in vocab
# interlink not in vocab
# sermonize not in vocab
# !!found stemmed sermonize
# autobuses not in vocab
# !!found syn bus
# internationality not in vocab
# protectiveness not in vocab
# !!found stemmed protectiveness
# disinvestment not in vocab
# !!found syn divest
# momentousness not in vocab
# !!found stemmed momentousness
# unassertiveness not in vocab
# !!found 1st level hypernym diffidence
# localise not in vocab
# consultive not in vocab
# !!found stemmed consultive
# cd not in vocab
# !!found stemmed cd
# provisionary not in vocab
# !!found syn probationary
#  not in vocab
# assistances not in vocab
# !!found stemmed assistances
# merchantable not in vocab
# !!found stemmed merchantable
#  not in vocab
# unspecialised not in vocab
# !!found syn unspecialized
# protectorship not in vocab
# !!found 1st level hypernym position
# recreate not in vocab
# perfectible not in vocab
# !!found stemmed perfectible
# wrongdoer not in vocab
# preliterate not in vocab
# sensualist not in vocab
# !!found 1st level hyponym bisexual
# presuppose not in vocab
# excitations not in vocab
# gracefulness not in vocab
# !!found stemmed gracefulness
# leagued not in vocab
# abstractionist not in vocab
# precociously not in vocab
# !!found manually stemmed precocious for precociously
# displeases not in vocab
# interlace not in vocab
# conformism not in vocab
# !!found stemmed conformism
# narrowmindedness not in vocab
# !!found stemmed narrowmindedness
# rooters not in vocab
# !!found 1st level hyponym aficionado
# jerusalem not in vocab
# !!found stemmed jerusalem
# disarranged not in vocab
# !!found 1st level hyponym muss
# algebraic not in vocab
# !!found stemmed algebraic
# capitation not in vocab
# mercifulness not in vocab
# !!found stemmed mercifulness
# nonconscious not in vocab
# formalisms not in vocab
# !!found stemmed formalisms
# transposable not in vocab
# conductance not in vocab
# !!found stemmed conductance
# attributions not in vocab
# american not in vocab
# !!found stemmed american
# unrealizable not in vocab
# !!found syn unachievable
# bluejacket not in vocab
# !!found 1st level hyponym striker
# nanosecond not in vocab
# !!found hypernym measure for nanosecond
# monocultures not in vocab
# replications not in vocab
# cognizance not in vocab
# reformism not in vocab
# !!found stemmed reformism
# transalpine not in vocab
# !!found 1st level hypernym foreigner
# antifeminist not in vocab
# !!found 1st level hypernym bigot
# illimitable not in vocab
# singe not in vocab
# !!found stemmed singe
# absorbance not in vocab
# !!found stemmed absorbance
# inelasticity not in vocab
# transmutes not in vocab
# !!found syn transform
# postdated not in vocab
# !!found hypernym date for postdated
# clericalism not in vocab
# !!found stemmed clericalism
#  not in vocab
# alarmism not in vocab
# !!found stemmed alarmism
# fleshiness not in vocab
# fictitiously not in vocab
# !!found manually stemmed fictitious for fictitiously
# microphallus not in vocab
# !!found 1st level hypernym penis
# discipleship not in vocab
# !!found 1st level hypernym position
# enslaves not in vocab
# entombment not in vocab
# !!found stemmed entombment
# retrying not in vocab
# constitutive not in vocab
# !!found stemmed constitutive
# deceiver not in vocab
# squishing not in vocab
# !!found stemmed squishing
# defiles not in vocab
# unparented not in vocab
# !!found antonym parented for unparented
# confluent not in vocab
# !!found syn feeder
# criticality not in vocab
# !!found stemmed criticality
# macrocosmic not in vocab
# !!found syn universe
# annihilator not in vocab
# knightly not in vocab
# !!found manually stemmed knight for knightly
# autographic not in vocab
# !!found stemmed autographic
# discontinuance not in vocab
# prostatic not in vocab
# combusted not in vocab
# !!found stemmed combusted
# synchronic not in vocab
# monoclinic not in vocab
# unstuff not in vocab
# !!found 1st level hyponym unblock
# carburettors not in vocab
# !!found stemmed carburettors
# concreteness not in vocab
# !!found stemmed concreteness
# reconstructs not in vocab
# !!found stemmed reconstructs
# copulate not in vocab
# irresolution not in vocab
# !!found syn indecision
# unfledged not in vocab
# !!found syn fledgling
# insurrectionist not in vocab
# !!found syn insurgent
# undefinable not in vocab
# rascality not in vocab
# !!found stemmed rascality
# smoothen not in vocab
# regionalisms not in vocab
# !!found stemmed regionalisms
# combatted not in vocab
# !!found stemmed combatted
# manacles not in vocab
# separationist not in vocab
# despoil not in vocab
# disassociates not in vocab
# crosslink not in vocab
# !!found stemmed crosslink
# inharmonious not in vocab
# !!found antonym harmonious for inharmonious
# initialise not in vocab
# !!found syn format
# microcircuit not in vocab
# !!found hypernym circuit for microcircuit
# partible not in vocab
# aspirate not in vocab
# intragroup not in vocab
# !!found syn internal
# immobilization not in vocab
# irremovable not in vocab
# !!found antonym removable for irremovable
# censorships not in vocab
# !!found stemmed censorships
# emotionalism not in vocab
# !!found stemmed emotionalism
# incoordination not in vocab
# !!found hypernym inability for incoordination
# unisons not in vocab
# !!found stemmed unisons
# algebraist not in vocab
# !!found 1st level hypernym mathematician
# conjurors not in vocab
# !!found stemmed conjurors
# viscometry not in vocab
# !!found 1st level hypernym measurement
# impulsion not in vocab
# embroiderer not in vocab
# !!found 1st level hyponym faggot
# microcircuits not in vocab
# !!found hypernym circuit for microcircuits
# auditive not in vocab
# !!found stemmed auditive
# spangle not in vocab
# flimflam not in vocab
# !!found stemmed flimflam
# anamorphosis not in vocab
# !!found 1st level hypernym evolution
# companionships not in vocab
# !!found stemmed companionships
# ulcerate not in vocab
# !!found stemmed ulcerate
# commandership not in vocab
# !!found 1st level hypernym position
# bibliographies not in vocab
# !!found 1st level hypernym list
# psychodynamics not in vocab
# significances not in vocab
# rhymers not in vocab
# !!found 1st level hypernym writer
# concurrency not in vocab
# emulsifying not in vocab
# inelegance not in vocab
# pedaler not in vocab
# !!found stemmed pedaler
# brandnewness not in vocab
# !!found stemmed brandnewness
# concurrencies not in vocab
# disestablishing not in vocab
# procurators not in vocab
# sheikhdoms not in vocab
# !!found syn sheikdom
# interrelate not in vocab
# enforcements not in vocab
# antitoxic not in vocab
# harvard not in vocab
# !!found stemmed harvard
# ingroup not in vocab
# dissociable not in vocab
# profitless not in vocab
# impossibilities not in vocab
# procreated not in vocab
# acronymic not in vocab
# !!found stemmed acronymic
# baseness not in vocab
# !!found stemmed baseness
# undissolved not in vocab
# postposition not in vocab
# !!found 1st level hypernym place
# scandalize not in vocab
# !!found stemmed scandalize
# baste not in vocab
# !!found stemmed baste
# ganging not in vocab
# !!found stemmed ganging
# posthole not in vocab
# !!found 1st level hypernym hole
# autograft not in vocab
# !!found 1st level hypernym graft
# autosuggestion not in vocab
# !!found hypernym improvement for autosuggestion
# incommensurable not in vocab
# florescence not in vocab
# !!found syn blossoming
# cylindric not in vocab
# circularize not in vocab
# !!found stemmed circularize
# rearrangements not in vocab
# calcify not in vocab
# obtainment not in vocab
# !!found stemmed obtainment
# lusterware not in vocab
# !!found 1st level hypernym pottery
# predetermination not in vocab
# rectorate not in vocab
# !!found stemmed rectorate
# vegetational not in vocab
# interlayers not in vocab
# !!found 1st level hypernym layer
# endurable not in vocab
# importances not in vocab
# !!found stemmed importances
# interwove not in vocab
# !!found syn weave
# representable not in vocab
# !!found stemmed representable
# repositions not in vocab
# clozapine not in vocab
# !!found hypernym antipsychotic for clozapine
# analogize not in vocab
# !!found stemmed analogize
# preheating not in vocab
# !!found stemmed preheating
# indirectness not in vocab
# !!found stemmed indirectness
# spiritualize not in vocab
# slaughterers not in vocab
# !!found stemmed slaughterers
# conformations not in vocab
# !!found stemmed conformations
# trilogies not in vocab
# insecureness not in vocab
# balminess not in vocab
# naturalise not in vocab
# liverpools not in vocab
# !!found stemmed liverpools
# thermonuclear not in vocab
# ruralist not in vocab
# !!found syn countryman
# condescended not in vocab
# animalism not in vocab
# !!found stemmed animalism
# interchanging not in vocab
# ropewalker not in vocab
# !!found 1st level hypernym aerialist
# subhead not in vocab
# !!found 1st level hyponym title
# objectifying not in vocab
# interlingua not in vocab
# !!found hypernym language for interlingua
# mexico not in vocab
# !!found stemmed mexico
# bendability not in vocab
# inexpedient not in vocab
# !!found antonym expedient for inexpedient
# circumnavigations not in vocab
# nondescripts not in vocab
# !!found stemmed nondescripts
# evangelicalism not in vocab
# perfective not in vocab
# !!found stemmed perfective
# sufferance not in vocab
# !!found stemmed sufferance
# desiccating not in vocab
# comfortless not in vocab
# microbalance not in vocab
# !!found 1st level hypernym balance
# hybridise not in vocab
# circumferential not in vocab
# yale not in vocab
# !!found stemmed yale
# ascendence not in vocab
# !!found stemmed ascendence
# noncivilized not in vocab
# !!found antonym civilized for noncivilized
# bewitchment not in vocab
# adjustor not in vocab
# !!found syn adjuster
# unmarketable not in vocab
# freud not in vocab
# !!found stemmed freud
# nurturance not in vocab
# uncreative not in vocab
# !!found antonym creative for uncreative
# subspaces not in vocab
# undisputable not in vocab
#  not in vocab
# seasonable not in vocab
# !!found stemmed seasonable
# animality not in vocab
# !!found stemmed animality
# uptodate not in vocab
# rhythmicity not in vocab
# !!found stemmed rhythmicity
# prayerful not in vocab
# !!found stemmed prayerful
# append not in vocab
# greengrocery not in vocab
# discoverys not in vocab
# embracement not in vocab
# portrayer not in vocab
# !!found stemmed portrayer
# depictive not in vocab
# !!found stemmed depictive
# delimitations not in vocab
# !!found syn specify
# religionist not in vocab
# inexpert not in vocab
# !!found syn amateurish
# spiritize not in vocab
# !!found stemmed spiritize
# microvolts not in vocab
# !!found stemmed microvolts
# intramolecular not in vocab
# regularize not in vocab
# !!found stemmed regularize
# contraries not in vocab
# demureness not in vocab
# !!found stemmed demureness
# unploughed not in vocab
# !!found syn unplowed
# microfossils not in vocab
# !!found 1st level hypernym fossil
# princedom not in vocab
# !!found syn principality
# inversions not in vocab
# rediscovery not in vocab
# !!found 1st level hypernym discovery
# trichloride not in vocab
# !!found 1st level hypernym chloride
# monoplanes not in vocab
# odorize not in vocab
# !!found stemmed odorize
# interweaved not in vocab
# estrogenic not in vocab
# !!found stemmed estrogenic
# copartnership not in vocab
# !!found 1st level hypernym partnership
# sanctify not in vocab
# circumvolution not in vocab
# !!found 1st level hypernym rotation
# intentionality not in vocab
# !!found stemmed intentionality
# retrials not in vocab
# !!found stemmed retrials
# antecedent not in vocab
# palestinian not in vocab
# !!found stemmed palestinian
# unostentatious not in vocab
# !!found syn understated
# hallucinating not in vocab
# antedating not in vocab
# !!found syn predate
# speculativeness not in vocab
# semiconducting not in vocab
# protraction not in vocab
# anterooms not in vocab
# !!found 1st level hypernym room
# colorblind not in vocab
# !!found stemmed colorblind
# civilise not in vocab
# roosted not in vocab
# !!found stemmed roosted
# unionise not in vocab
# transponder not in vocab
# intraspecific not in vocab
# !!found syn intraspecies
# unattainableness not in vocab
# promotive not in vocab
# relinquishment not in vocab
# !!found stemmed relinquishment
# needleworker not in vocab
# !!found stemmed needleworker
# duplicable not in vocab
# subroutines not in vocab
# !!found syn routine
# indexical not in vocab
# !!found stemmed indexical
# internationalisms not in vocab
# heraldist not in vocab
# !!found syn heraldic
# discontinuous not in vocab
# delimited not in vocab
# !!found syn specify
# territorials not in vocab
# princedoms not in vocab
# !!found syn principality
# fieldworker not in vocab
# !!found stemmed fieldworker
# affectional not in vocab
# !!found stemmed affectional
# overshoe not in vocab
# !!found 1st level hyponym arctic
# spatiality not in vocab
# !!found stemmed spatiality
# evangelistic not in vocab
# !!found stemmed evangelistic
# instructorship not in vocab
# !!found 1st level hypernym position
# restrainer not in vocab
# !!found stemmed restrainer
# insurrectional not in vocab
# transmissible not in vocab
# homophony not in vocab
# !!found 1st level hypernym pronunciation
# carbonic not in vocab
# !!found stemmed carbonic
# undeviating not in vocab
# preposed not in vocab
# !!found 1st level hypernym put
# wreathe not in vocab
# !!found stemmed wreathe
# transmigrated not in vocab
# !!found syn reincarnate
# parallelism not in vocab
# !!found stemmed parallelism
# insatiate not in vocab
# disfavoring not in vocab
# !!found stemmed disfavoring
# antifeminism not in vocab
# !!found 1st level hypernym sexism
# autoregulation not in vocab
# !!found hypernym process for autoregulation
# prehistorical not in vocab
# incensing not in vocab
# rundown not in vocab
# !!found stemmed rundown
# subserving not in vocab
# expounding not in vocab
# !!found stemmed expounding
# maradona not in vocab
# !!found stemmed maradona
# vindictively not in vocab
# !!found manually stemmed vindictive for vindictively
# witchhunt not in vocab
# !!found stemmed witchhunt
# predetermine not in vocab
# gladness not in vocab
# !!found stemmed gladness
# skillfulness not in vocab
# !!found stemmed skillfulness
# depressor not in vocab
# subserve not in vocab
# extroversive not in vocab
# asteroidal not in vocab
# !!found stemmed asteroidal
# cardinality not in vocab
# !!found stemmed cardinality
# concavity not in vocab
# corespondent not in vocab
# !!found 1st level hypernym codefendant
# ecclesiastic not in vocab
# unicycles not in vocab
# walloper not in vocab
# !!found stemmed walloper
# casteless not in vocab
# librarianship not in vocab
# !!found 1st level hypernym position
# resistor not in vocab
# positioners not in vocab
# !!found stemmed positioners
# autopilots not in vocab
# !!found stemmed autopilots
# transfused not in vocab
# refuels not in vocab
# !!found stemmed refuels
# pastorship not in vocab
# !!found 1st level hypernym position
# nonperformance not in vocab
# excretion not in vocab
# eavesdropper not in vocab
# !!found 1st level hyponym tapper
# subjoined not in vocab
# !!found hypernym tack for subjoined
# syntaxes not in vocab
# !!found stemmed syntaxes
# subsequences not in vocab
# therapeutical not in vocab
# rareness not in vocab
# !!found stemmed rareness
# encrust not in vocab
# instrumentality not in vocab
# !!found stemmed instrumentality
# asphaltic not in vocab
# !!found stemmed asphaltic
# carefreeness not in vocab
# academicism not in vocab
# !!found stemmed academicism
# dwarfish not in vocab
# !!found manually stemmed dwarf for dwarfish
# unaccessible not in vocab
# !!found syn inaccessible
# reburial not in vocab
# businessperson not in vocab
# !!found 1st level hyponym accountant
# incised not in vocab
# unchaste not in vocab
# !!found antonym chaste for unchaste
# intercommunicate not in vocab
# hydrolysed not in vocab
# !!found 1st level hypernym change
# brazil not in vocab
# !!found stemmed brazil
# randomize not in vocab
# !!found stemmed randomize
# interpenetrate not in vocab
# !!found syn permeate
# transfusing not in vocab
# aqueous not in vocab
# kindergarteners not in vocab
# !!found stemmed kindergarteners
# romanic not in vocab
# !!found stemmed romanic
# unvariedness not in vocab
# !!found stemmed unvariedness
# eldership not in vocab
# !!found 1st level hypernym position
# immoderate not in vocab
# !!found antonym moderate for immoderate
# impotently not in vocab
# !!found manually stemmed impotent for impotently
# conspicuousness not in vocab
# cofactors not in vocab
# !!found 1st level hypernym compound
# condescend not in vocab
# remitting not in vocab
# !!found stemmed remitting
# incurved not in vocab
# riskless not in vocab
# entraps not in vocab
# !!found stemmed entraps
# autografts not in vocab
# !!found 1st level hypernym graft
# japanese not in vocab
# !!found stemmed japanese
# lustrate not in vocab
# !!found 1st level hypernym purify
# shortchange not in vocab
# reargue not in vocab
# convector not in vocab
# !!found 1st level hypernym heater
# nonindulgent not in vocab
# !!found antonym indulgent for nonindulgent
# caramelize not in vocab
# !!found stemmed caramelize
# excitation not in vocab
# ideality not in vocab
# !!found stemmed ideality
# microwaving not in vocab
# destabilization not in vocab
# houseful not in vocab
# incommutable not in vocab
# !!found antonym commutable for incommutable
# dreadnought not in vocab
# !!found 1st level hypernym battleship
# enlarger not in vocab
# opec not in vocab
# !!found stemmed opec
# associational not in vocab
# irreproducible not in vocab
# !!found antonym reproducible for irreproducible
# concerti not in vocab
# !!found syn concerto
# monogenesis not in vocab
# !!found hypernym reproduction for monogenesis
# autoloading not in vocab
# sportive not in vocab
# discountenance not in vocab
# !!found 1st level hypernym shame
# maildrop not in vocab
# !!found 1st level hypernym drop
# spiritless not in vocab
# !!found syn meek
# selfdiscovery not in vocab
# triclinic not in vocab
# unisexual not in vocab
# fractionate not in vocab
# !!found stemmed fractionate
# hyperextension not in vocab
# !!found 1st level hypernym extension
# religiousness not in vocab
# changeableness not in vocab
# univocal not in vocab
# !!found syn unequivocal
# autoimmunity not in vocab
# entreaty not in vocab
# unilluminated not in vocab
# urbanize not in vocab
# !!found stemmed urbanize
# synoptic not in vocab
# subjugate not in vocab
# selfimprovement not in vocab
# disjunct not in vocab
# abbreviate not in vocab
# sightedness not in vocab
# !!found stemmed sightedness
# christianise not in vocab
# !!found 1st level hypernym convert
# adventism not in vocab
# !!found stemmed adventism
# summonings not in vocab
# !!found stemmed summonings
# vaporise not in vocab
# americanize not in vocab
# !!found stemmed americanize
# baptistic not in vocab
# !!found stemmed baptistic
# quadratics not in vocab
# wholeheartedness not in vocab
# !!found stemmed wholeheartedness
# engorge not in vocab
# !!found syn gorge
# circumscribes not in vocab
# hardandfast not in vocab
# !!found stemmed hardandfast
# transmuted not in vocab
# !!found syn transform
# expressible not in vocab
# !!found stemmed expressible
# mars not in vocab
# !!found stemmed mars
# bestowals not in vocab
# !!found stemmed bestowals
# humanness not in vocab
# !!found stemmed humanness
# jackson not in vocab
# !!found stemmed jackson
# implicational not in vocab
# swooshing not in vocab
# !!found stemmed swooshing
# pathless not in vocab
# hypermarket not in vocab
# negociate not in vocab
# implantations not in vocab
# !!found stemmed implantations
#  not in vocab
# narrowminded not in vocab
# microflora not in vocab
# !!found 1st level hypernym microorganism
# communicativeness not in vocab
# totalism not in vocab
# !!found stemmed totalism
# unfeathered not in vocab
# !!found antonym feathered for unfeathered
# micrometer not in vocab
# !!found stemmed micrometer
# covariant not in vocab
# reviles not in vocab
# impoliteness not in vocab
# opalescence not in vocab
# deflowering not in vocab
# !!found syn mar
# exaction not in vocab
# !!found stemmed exaction
# stockers not in vocab
# !!found stemmed stockers
# internationaler not in vocab
# !!found stemmed internationaler
# commingle not in vocab
# secluding not in vocab
# sidewinder not in vocab
# highjacking not in vocab
# !!found syn commandeer
# unwaveringly not in vocab
# !!found manually stemmed unwavering for unwaveringly
# differentia not in vocab
# !!found 1st level hypernym difference
# denominate not in vocab
# prophetical not in vocab
# !!found stemmed prophetical
# intensions not in vocab
# deviationism not in vocab
# !!found stemmed deviationism
# inscribe not in vocab
# dissociations not in vocab
# disinheritance not in vocab
# !!found stemmed disinheritance
# sanctifying not in vocab
# allurement not in vocab
# reenactor not in vocab
# combusting not in vocab
# !!found stemmed combusting
# fbi not in vocab
# !!found stemmed fbi
# virginals not in vocab
# !!found stemmed virginals
# shortish not in vocab
# !!found manually stemmed short for shortish
# infeasible not in vocab
# !!found syn impracticable
# selfdiscipline not in vocab
# syntactic not in vocab
# israel not in vocab
# !!found stemmed israel
# monsignori not in vocab
# !!found 1st level hypernym priest
# arafat not in vocab
# !!found stemmed arafat
# reproves not in vocab
# !!found syn admonish
# democratize not in vocab
# !!found stemmed democratize
# containerful not in vocab
# !!found stemmed containerful
# disjoined not in vocab
# !!found 1st level hypernym separate
# scarceness not in vocab
# cession not in vocab
# !!found 1st level hyponym recession
# astringe not in vocab
# deposes not in vocab
# provincialism not in vocab
# inroad not in vocab
# irregardless not in vocab
# transgress not in vocab
# moderatorship not in vocab
# !!found 1st level hypernym position
# actuator not in vocab
# organismal not in vocab
# !!found stemmed organismal
# monoatomic not in vocab
# dematerialised not in vocab
# knowhow not in vocab
# !!found stemmed knowhow
# trioxide not in vocab
# !!found 1st level hyponym arsenic
# inclosure not in vocab
# !!found syn enclosure
# disgruntle not in vocab
# receiverships not in vocab
# !!found stemmed receiverships
# inadvertence not in vocab
# unsubdivided not in vocab
# !!found syn simple
# reckoner not in vocab
# !!found stemmed reckoner
